# %% [markdown]
# Approach 1: treat all rows independently
# Approach 2: keep posts and comments separate
# Approach 3: combine posts and comments

# %%
import pandas as pd
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.decomposition import LatentDirichletAllocation
import re
import matplotlib.pyplot as plt
from wordcloud import WordCloud
import gensim
from gensim.utils import simple_preprocess
import gensim.corpora as corpora
import nltk
from nltk.corpus import stopwords
import spacy
from gensim.models import CoherenceModel
import pyLDAvis.gensim
import pyLDAvis
import warnings
import matplotlib.pyplot as plt

nltk.download('stopwords')
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\fahad\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# True

# %%
file_path = 'C:/Users/fahad/OneDrive - Oulun yliopisto/Documents/suomi24/Data/suomi24.csv'
df = pd.read_csv(file_path)
df
# Out:
#             msg_type             datetime  \
# 0       thread_start  2001-01-18 17:18:00
# 1            comment  2001-01-19 01:28:00
# 2            comment  2001-01-19 06:21:00
# 3            comment  2001-01-19 16:27:00
# 4            comment  2001-01-20 12:49:00
# ...              ...                  ...
# 273299       comment  2020-12-31 17:08:00
# 273300  thread_start  2020-12-30 17:58:00
# 273301       comment  2020-12-31 06:34:00
# 273302       comment  2020-12-31 13:27:00
# 273303       comment  2020-12-30 22:16:00
#
#                                                     title  thread_id  \
# 0                                 Questions about Estonia      89742
# 1                                 Questions about Estonia      89742
# 2                                 Questions about Estonia      89742
# 3                                 Questions about Estonia      89742
# 4                                 Questions about Estonia      89742
# ...                                                   ...        ...
# 273299                                     Thai rice dogs   16711386
# 273300                                Surveillance camera   16711801
# 273301                                Surveillance camera   16711801
# 273302                                Surveillance camera   16711801
# 273303  What it's like to work in a parking control co...   12445902
#
#         comment_id          topic_name_top                topic_name_leaf  \
# 0                0                 Society       # The world's going on #
# 1           386913                 Society       # The world's going on #
# 2           386914                 Society       # The world's going on #
# 3           386915                 Society       # The world's going on #
# 4           386916                 Society       # The world's going on #
# ...            ...                     ...                            ...
# 273299   105838676                 Tourism                        Pattaya
# 273300           0   Home and construction  Lighting and electrical works
# 273301   105829873   Home and construction  Lighting and electrical works
# 273302   105835154   Home and construction  Lighting and electrical works
# 273303   105826384  Vehicles and transport                  Parking fines
#
#                                               thread_text  \
# 0       - Why did an important piece of evidence (from...
# 1       I think they had other things to do. - First o...
# 2       - Not the bow gate, but its SARANA- &gt; a str...
# 3       I'll tell you what's going on. I'll tell you w...
# 4       Let the cause of the sinking of any ship be li...
# ...                                                   ...
# 273299  as if these omega- "men" were taken there. The...
# 273300  Surveillance camera Is there a human next outs...
# 273301  Pretty sure the camera will follow you. Put th...
# 273302  please see online if you have Internet access ...
# 273303  which is pretty rare, when youre working in a ...
#
#                                            processed_text  topic  \
# 0       important piece evidence front gate fall depth...     -1
# 1       think thing first kin demanded sepulchre would...     -1
# 2       bow gate sarana strange coincidence fell resea...     -1
# 3               ill tell whats going ill tell whatll news    350
# 4       let cause sinking ship lifted away wreckage le...     -1
# ...                                                   ...    ...
# 273299  omega men taken comedian claim nasumarttaamal ...     -1
# 273300      surveillance camera human next outside camera     55
# 273301  pretty sure camera follow put security camera ...     -1
# 273302  please see online internet access baron kepele...    136
# 273303  pretty rare youre working house come work minu...     -1
#
#                                               probability
# 0       important piece evidence front gate fall depth...
# 1       think thing first kin demanded sepulchre would...
# 2       bow gate sarana gt strange coincidence fell re...
# 3               ill tell whats going ill tell whatll news
# 4       let cause sinking ship lifted away wreckage le...
# ...                                                   ...
# 273299  omega men taken comedian claim nasumarttaamal ...
# 273300    surveillance camera human next outside camera g
# 273301  pretty sure camera follow put security camera ...
# 273302  please see online internet access baron kepele...
# 273303  pretty rare youre working house come work minu...
#
# [273304 rows x 11 columns]

# %% [markdown]
# Preprocess

# %%
# Basic text preprocessing function
stop_words = set(stopwords.words('english'))
stop_words.add('s')
stop_words.add('ve')
stop_words.add('re')
stop_words.add('m')
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()  # Convert to lower case
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with single space
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\b\w{1,2}\b', '', text) # Remove single and double character words
    text = text.lower()  # Convert to lower case
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]
    return ' '.join(tokens)

# Apply preprocessing to the 'thread_text' column
df['processed_text'] = df['thread_text'].astype(str).apply(preprocess_text)

# %%
df['processed_text'][0]
# Out:
# ' why did an important piece of evidence from the front gate  fall down into the depths of the sea from the helicopter that carried it questions about estonia  why isnt estonia the only ship in the world that immediately held up the peace of the grave  why did the border guard prevent investigations by an independent tv company before the area was protected  why is the socalled burial peace repeatedly invoked even though most of the relatives wanted to study the matter  why only one theory of sinking even though it is very controversial  flashed into the public domain as truth  didnt anyone get saved from the bridge of command even though they were in the advantage  why were no other images given to the public when they had a couple of stormy images'

# %%
# Define a function to filter relevant rows
def is_relevant(text):
    # Example criterion: contains certain keywords
    keywords = ['camera', 'public', 'privacy', 'cctv', 'surveillance', 'security', 'safety', 'concern', 'protect', 'monitoring', 'footage', 'personal', 'cameras', 'concerns', 'protection', 'monitor']
    return any(keyword in text for keyword in keywords)

# Apply the function to filter rows
df_relevant = df[df['processed_text'].apply(is_relevant)]

# %%
df_relevant
# Out:
#             msg_type             datetime  \
# 0       thread_start  2001-01-18 17:18:00
# 15           comment  2001-01-22 11:16:00
# 27      thread_start  2001-01-19 12:15:00
# 28           comment  2001-01-19 12:59:00
# 31           comment  2001-01-19 17:05:00
# ...              ...                  ...
# 274498       comment  2020-12-31 10:33:44
# 274502       comment  2020-12-31 13:32:47
# 274507       comment  2020-12-31 14:34:39
# 274515  thread_start  2020-12-30 17:58:06
# 274516       comment  2020-12-31 06:34:39
#
#                                              title thread_id comment_id  \
# 0                          Questions about Estonia     89742          0
# 15                         Questions about Estonia     89742     386927
# 27      automatic control is just money laundering     32552          0
# 28      automatic control is just money laundering     32552     162166
# 31      automatic control is just money laundering     32552     162170
# ...                                            ...       ...        ...
# 274498                              Thai rice dogs  16711386  105832145
# 274502                              Thai rice dogs  16711386  105835231
# 274507                              Thai rice dogs  16711386  105836278
# 274515                         Surveillance camera  16711801          0
# 274516                         Surveillance camera  16711801  105829873
#
#                 topic_name_top                 topic_name_leaf  \
# 0                      Society        # The world's going on #
# 15                     Society        # The world's going on #
# 27      Vehicles and transport  General information on driving
# 28      Vehicles and transport  General information on driving
# 31      Vehicles and transport  General information on driving
# ...                        ...                             ...
# 274498                 Tourism                         Pattaya
# 274502                 Tourism                         Pattaya
# 274507                 Tourism                         Pattaya
# 274515   Home and construction   Lighting and electrical works
# 274516   Home and construction   Lighting and electrical works
#
#                                               thread_text  \
# 0       - Why did an important piece of evidence (from...
# 15      intutorytutkimus. fi and there MV Estonia. The...
# 27      car thieves and so on. But when speed restrict...
# 28      how can you teach your children to walk throug...
# 31      even though I don't have a radar detector or e...
# ...                                                   ...
# 274498  quiet area, but now I have a house at three me...
# 274502  At that time they were expensive devices. Well...
# 274507  someone doesn't match. . Earlier, you told me ...
# 274515  Surveillance camera Is there a human next outs...
# 274516  Pretty sure the camera will follow you. Put th...
#
#                                            processed_text
# 0        why did an important piece of evidence from t...
# 15      intutorytutkimus fi and there mv estonia the f...
# 27      car thieves and so on but when speed restricti...
# 28      how can you teach your children to walk throug...
# 31      even though i dont have a radar detector or ev...
# ...                                                   ...
# 274498  quiet area but now i have a house at three met...
# 274502  at that time they were expensive devices well ...
# 274507  someone doesnt match  earlier you told me you ...
# 274515  surveillance camera is there a human next outs...
# 274516  pretty sure the camera will follow you put the...
#
# [43383 rows x 9 columns]

# %% [markdown]
# Topic Modeling

# %%
def sent_to_words(texts):
    for text in texts:
        yield(simple_preprocess(str(text),deacc=True))  # deacc=True removes the punctuation marks
        
data_words=list(sent_to_words(df['processed_text']))
# data_words=list(sent_to_words(df_relevant['processed_text']))

# %%
data_words
# Out:
# [['important',
#   'piece',
#   'evidence',
#   'front',
#   'gate',
#   'fall',
#   'depth',
#   'sea',
#   'helicopter',
#   'carried',
#   'question',
#   'estonia',
#   'isnt',
#   'estonia',
#   'ship',
#   'world',
#   'immediately',
#   'held',
#   'peace',
#   'grave',
#   'border',
#   'guard',
#   'prevent',
#   'investigation',
#   'independent',
#   'company',
#   'area',
#   'protected',
#   'socalled',
#   'burial',
#   'peace',
#   'repeatedly',
#   'invoked',
#   'even',
#   'though',
#   'relative',
#   'wanted',
#   'study',
#   'matter',
#   'one',
#   'theory',
#   'sinking',
#   'even',
#   'though',
#   'controversial',
#   'flashed',
#   'public',
#   'domain',
#   'truth',
#   'didnt',
#   'anyone',
#   'get',
#   'saved',
#   'bridge',
#   'command',
#   'even',
#   'though',
#   'advantage',
#   'image',
#   'given',
#   'public',
#   'couple',
#   'stormy',
#   'image'],
#  ['think',
#   'thing',
#   'first',
#   'kin',
#   'demanded',
#   'sepulchre',
#   'would',
#   'rejected',
#   'independent',
#   'picture',
#   'bottom',
#   'wreck',
#   'taken',
#   'lightning',
#   'light',
#   'fear',
#   'scuba',
#   'dive',
#   'invasion',
#   'wreckage',
#   'would',
#   'able',
#   'save',
#   'accident',
#   'first',
#   'investigating',
#   'authority',
#   'television',
#   'company',
#   'dont',
#   'wonder',
#   'gate',
#   'raised',
#   'thing',
#   'stormy',
#   'thing',
#   'thing',
#   'stormy',
#   'thing',
#   'small',
#   'group',
#   'would',
#   'keep',
#   'sound',
#   'suggest',
#   'amazing',
#   'theory',
#   'thing',
#   'argument',
#   'thing',
#   'stormy',
#   'thing',
#   'many',
#   'night',
#   'excited',
#   'describe',
#   'would',
#   'still',
#   'continue',
#   'part',
#   'addition'],
#  ['bow',
#   'gate',
#   'sarana',
#   'strange',
#   'coincidence',
#   'fell',
#   'research',
#   'helicopter',
#   'deep',
#   'sea',
#   'couldnt',
#   'saved',
#   'reason',
#   'thing',
#   'storm',
#   'world',
#   'reason',
#   'ordeal',
#   'reason',
#   'ordeal',
#   'loved',
#   'one',
#   'wanted',
#   'proper',
#   'burial',
#   'peace',
#   'per',
#   'cent',
#   'want',
#   'proper',
#   'study',
#   'wanted',
#   'first',
#   'body',
#   'hyly',
#   'lifting',
#   'holding',
#   'small',
#   'river',
#   'actually',
#   'per',
#   'caput',
#   'look',
#   'leaf',
#   'without',
#   'chewing',
#   'touch',
#   'want',
#   'believe',
#   'mus',
#   'wanted',
#   'believe',
#   'grave',
#   'peace',
#   'several',
#   'oath',
#   'staff',
#   'tell',
#   'reason',
#   'thing',
#   'storm',
#   'reason',
#   'thing',
#   'storm',
#   'middle',
#   'year',
#   'didnt',
#   'give',
#   'good',
#   'picture',
#   'happened'],
#  ['ill', 'tell', 'whats', 'going', 'ill', 'tell', 'whatll', 'news'],
#  ['let',
#   'cause',
#   'sinking',
#   'ship',
#   'lifted',
#   'away',
#   'wreckage',
#   'left',
#   'sea'],
#  ['therell',
#   'lot',
#   'ill',
#   'bet',
#   'youll',
#   'bet',
#   'concrete',
#   'thats',
#   'going',
#   'look',
#   'ill',
#   'lot',
#   'therell',
#   'lot',
#   'said',
#   'ill',
#   'tell',
#   'ill',
#   'bet',
#   'youll',
#   'lot',
#   'itll',
#   'lot',
#   'ill',
#   'bet',
#   'youll',
#   'bet'],
#  ['there',
#   'reason',
#   'ill',
#   'bet',
#   'there',
#   'nothing',
#   'else',
#   'ill',
#   'bet',
#   'therell',
#   'ill',
#   'bet',
#   'therell',
#   'lot',
#   'thing',
#   'ill',
#   'bet',
#   'therell',
#   'ill',
#   'bet',
#   'therell',
#   'lot',
#   'thing',
#   'ill',
#   'bet',
#   'therell',
#   'lot',
#   'thing',
#   'ill',
#   'bet',
#   'therell',
#   'ill',
#   'bet',
#   'therell',
#   'ill',
#   'bet',
#   'therell',
#   'ill',
#   'bet',
#   'therell',
#   'ill',
#   'betll',
#   'bet',
#   'therell',
#   'ill',
#   'bet',
#   'ill',
#   'bet',
#   'therell',
#   'lot',
#   'ill',
#   'bet'],
#  ['whats', 'big', 'deal'],
#  ['there',
#   'reason',
#   'going',
#   'lot',
#   'thats',
#   'going',
#   'happen',
#   'like',
#   'thats',
#   'going',
#   'happen',
#   'there',
#   'reason',
#   'going',
#   'lot'],
#  ['look',
#   'look',
#   'road',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'much',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'going',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'going',
#   'look',
#   'whats',
#   'going',
#   'front',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'whats',
#   'going',
#   'look',
#   'going',
#   'front',
#   'short',
#   'ago',
#   'thats',
#   'look',
#   'bit',
#   'accident',
#   'look',
#   'look',
#   'road'],
#  ['dont',
#   'know',
#   'lehtola',
#   'missed',
#   'fact',
#   'estonia',
#   'built',
#   'iron',
#   'filled',
#   'water',
#   'model',
#   'carpenter',
#   'wood',
#   'soaking',
#   'water',
#   'long',
#   'time',
#   'went',
#   'bottom',
#   'lehtola',
#   'told',
#   'made',
#   'model',
#   'wood',
#   'estonia',
#   'prove',
#   'suspicion',
#   'reason',
#   'estonia',
#   'sinking',
#   'least',
#   'dont',
#   'believe',
#   'trust',
#   'result',
#   'research',
#   'group',
#   'lehtola',
#   'leader',
#   'old',
#   'man',
#   'full',
#   'toilet'],
#  ['give',
#   'right',
#   'idea',
#   'perspective',
#   'might',
#   'want',
#   'vtt',
#   'laugh',
#   'theyre',
#   'going',
#   'ashamed',
#   'planning',
#   'research',
#   'also',
#   'excellent',
#   'idea',
#   'knock',
#   'everyone',
#   'doesnt',
#   'like',
#   'face'],
#  ['would',
#   'point',
#   'accident',
#   'would',
#   'result',
#   'accident',
#   'read',
#   'read',
#   'exciting',
#   'thing',
#   'believe',
#   'however',
#   'many',
#   'rabe',
#   'activity',
#   'following',
#   'small',
#   'boat',
#   'think',
#   'telakka',
#   'official',
#   'matter',
#   'million',
#   'people',
#   'already',
#   'read',
#   'perhaps',
#   'want',
#   'hide',
#   'would',
#   'result',
#   'would',
#   'happened',
#   'panic',
#   'point',
#   'sinking',
#   'estonia',
#   'nothing',
#   'ashamed',
#   'lie',
#   'wall',
#   'would',
#   'point',
#   'would',
#   'result',
#   'would',
#   'happened',
#   'tour',
#   'trip',
#   'away',
#   'one',
#   'far',
#   'made',
#   'guess',
#   'various',
#   'interest',
#   'group',
#   'evidence',
#   'would',
#   'investigated',
#   'already',
#   'germany',
#   'official',
#   'position'],
#  ['etc',
#   'believe',
#   'explanation',
#   'much',
#   'simpler',
#   'could',
#   'short',
#   'time',
#   'could',
#   'developed',
#   'decaying',
#   'gas',
#   'odor',
#   'explosion',
#   'silenced',
#   'there',
#   'way',
#   'bomber',
#   'fence',
#   'bomber',
#   'car',
#   'still',
#   'way',
#   'could',
#   'even',
#   'something',
#   'would',
#   'happen',
#   'thing',
#   'bomber',
#   'there',
#   'nothing',
#   'look',
#   'several',
#   'passenger',
#   'crew',
#   'member',
#   'saved',
#   'mentioned',
#   'psychological',
#   'crisis',
#   'group',
#   'sinking',
#   'spot',
#   'dark',
#   'smell',
#   'terrorism',
#   'terrorist',
#   'even',
#   'single',
#   'madman',
#   'blew',
#   'bomb',
#   'car',
#   'deck',
#   'many',
#   'people',
#   'claimed',
#   'nuclear',
#   'weapon',
#   'plutonium',
#   'agent',
#   'large',
#   'drug',
#   'load',
#   'sunk'],
#  ['there',
#   'nothing',
#   'look',
#   'saying',
#   'there',
#   'nothing',
#   'look',
#   'there',
#   'big',
#   'deal',
#   'whats',
#   'going',
#   'mean',
#   'million',
#   'people',
#   'would',
#   'come',
#   'long',
#   'time',
#   'evidence',
#   'far',
#   'point',
#   'view',
#   'would',
#   'investigated',
#   'sure',
#   'whats',
#   'going',
#   'there',
#   'big',
#   'deal',
#   'whats',
#   'going',
#   'rabens',
#   'activity',
#   'followed',
#   'water',
#   'sure',
#   'whats',
#   'going',
#   'whats',
#   'going',
#   'already',
#   'million',
#   'people',
#   'read',
#   'there',
#   'big',
#   'deal',
#   'maybe',
#   'theyre',
#   'wanting',
#   'keep',
#   'matter',
#   'holding'],
#  ['estonia',
#   'file',
#   'report',
#   'downloaded',
#   'pdf',
#   'finnish',
#   'safety',
#   'investigation',
#   'authority',
#   'website',
#   'attachment',
#   'missing',
#   'www',
#   'unfortunately',
#   'also',
#   'obtained',
#   'location',
#   'ask'],
#  ['charge',
#   'commission',
#   'remainder',
#   'uno',
#   'laur',
#   'finnish',
#   'member',
#   'commission',
#   'kari',
#   'lehtola',
#   'director',
#   'accident',
#   'investigation',
#   'centre',
#   'whose',
#   'madness',
#   'cannot',
#   'say',
#   'anything',
#   'estonian',
#   'initially',
#   'andi',
#   'meister',
#   'second'],
#  ['telling',
#   'youm',
#   'telling',
#   'telling',
#   'youm',
#   'telling',
#   'youm',
#   'telling',
#   'itm',
#   'telling',
#   'itre',
#   'gonna',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'youre',
#   'gonna',
#   'itre',
#   'gonna',
#   'something',
#   'gonna',
#   'gonna',
#   'gonna',
#   'something',
#   'thats',
#   'gonna',
#   'something',
#   'thats',
#   'gonna',
#   'gonna',
#   'something',
#   'thats',
#   'gonna',
#   'something',
#   'thats',
#   'gonna',
#   'something',
#   'thats',
#   'gonna',
#   'gonna',
#   'going',
#   'happen',
#   'something',
#   'something',
#   'something',
#   'thats',
#   'going',
#   'happen',
#   'going',
#   'get',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'else',
#   'going',
#   'something',
#   'thats',
#   'going',
#   'something',
#   'thats',
#   'going',
#   'something',
#   'thats',
#   'going',
#   'something',
#   'something',
#   'something',
#   'else',
#   'going',
#   'going',
#   'going',
#   'something',
#   'something',
#   'something',
#   'going',
#   'something',
#   'thing',
#   'saying',
#   'telling',
#   'telling',
#   'telling'],
#  ['evidence',
#   'found',
#   'there',
#   'sense',
#   'estonia',
#   'leaf',
#   'sea',
#   'pressure',
#   'left',
#   'behind',
#   'ramp',
#   'broke',
#   'bow',
#   'gate',
#   'behind',
#   'smell',
#   'brittle',
#   'stuff',
#   'also',
#   'worth',
#   'noting',
#   'experience',
#   'narrator',
#   'brittle',
#   'smell',
#   'ship',
#   'corsts',
#   'still',
#   'long',
#   'main',
#   'engine',
#   'stopped',
#   'really',
#   'strange',
#   'bomb',
#   'ive',
#   'said',
#   'hand',
#   'knowledge',
#   'youth',
#   'year',
#   'came',
#   'smell',
#   'smelled',
#   'corstene',
#   'painting',
#   'blast',
#   'vest',
#   'manual',
#   'lock',
#   'left',
#   'behind',
#   'would',
#   'blown',
#   'keulaport',
#   'closed',
#   'left',
#   'behind',
#   'hydraulics',
#   'locking',
#   'hook'],
#  ['good', 'tip', 'interested', 'people'],
#  ['telling',
#   'something',
#   'telling',
#   'something',
#   'else',
#   'telling',
#   'something',
#   'else',
#   'telling',
#   'something',
#   'else',
#   'telling',
#   'something',
#   'telling',
#   'something',
#   'telling',
#   'something',
#   'else',
#   'telling',
#   'something',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'telling'],
#  ['there',
#   'reference',
#   'evidence',
#   'thing',
#   'could',
#   'different',
#   'report',
#   'youre',
#   'going',
#   'youre',
#   'going',
#   'long',
#   'time',
#   'basic',
#   'concept',
#   'investigation',
#   'court',
#   'based',
#   'event',
#   'reliably',
#   'explained',
#   'there',
#   'lot',
#   'report',
#   'contrast',
#   'theory',
#   'thrown',
#   'way',
#   'youve',
#   'read',
#   'report',
#   'already',
#   'mentioned',
#   'strange',
#   'bomb',
#   'breaking',
#   'front',
#   'door',
#   'ramp',
#   'front',
#   'komporomist',
#   'report',
#   'dont',
#   'comment',
#   'staff',
#   'say',
#   'comment',
#   'nice',
#   'laugh',
#   'first',
#   'look',
#   'guilty',
#   'youre',
#   'looking',
#   'something'],
#  ['believe',
#   'there',
#   'organization',
#   'behind',
#   'thats',
#   'taken',
#   'there',
#   'reference',
#   'evidence',
#   'could',
#   'different',
#   'report',
#   'dont',
#   'sink',
#   'truck',
#   'stamp',
#   'participant',
#   'secretor',
#   'information',
#   'there',
#   'lot',
#   'done',
#   'long',
#   'time',
#   'there',
#   'indiscretion',
#   'youre',
#   'looking',
#   'guilty',
#   'youre',
#   'looking',
#   'guilty',
#   'youre',
#   'today',
#   'theyve',
#   'sunk',
#   'inconceivable',
#   'reason',
#   'hey',
#   'boy',
#   'yes',
#   'there',
#   'evidence',
#   'report',
#   'tiij'],
#  ['wonder',
#   'many',
#   'explosive',
#   'use',
#   'sulfur',
#   'make',
#   'bow',
#   'port',
#   'fail',
#   'truckloads',
#   'black',
#   'powder',
#   'driven',
#   'car',
#   'deck',
#   'smell',
#   'rotten',
#   'egg',
#   'theory',
#   'suggests',
#   'bowgate',
#   'blown',
#   'black',
#   'powder'],
#  ['yes', 'dirt', 'thrown', 'side', 'way', 'around', 'win'],
#  ['there',
#   'thing',
#   'ostststre',
#   'here',
#   'ostrich',
#   'there',
#   'thing',
#   'ostrich',
#   'thing',
#   'there',
#   'thing',
#   'ostrich',
#   'therest',
#   'there',
#   'there',
#   'ost',
#   'thing',
#   'there',
#   'there',
#   'thing',
#   'ostrich',
#   'thing',
#   'there',
#   'ostrich',
#   'there',
#   'ostrich',
#   'there',
#   'thing',
#   'ostrich',
#   'there',
#   'thing',
#   'ostrich',
#   'thing'],
#  ['ill', 'tell', 'ill', 'tell', 'ill', 'tell', 'ill', 'tell', 'ill', 'tell'],
#  ['car',
#   'thief',
#   'speed',
#   'restriction',
#   'calculated',
#   'tolerance',
#   'tightened',
#   'need',
#   'car',
#   'model',
#   'speeding',
#   'driver',
#   'able',
#   'catch',
#   'lot',
#   'drunk',
#   'driver',
#   'majority',
#   'road',
#   'user',
#   'think',
#   'meaningful',
#   'anymore',
#   'honest',
#   'control',
#   'preferably',
#   'visibly',
#   'another',
#   'thing',
#   'automatic',
#   'control',
#   'cashing',
#   'automatic',
#   'speed',
#   'control',
#   'contribute',
#   'road',
#   'safety',
#   'extent',
#   'acceptable',
#   'noticed',
#   'police',
#   'even',
#   'look',
#   'reasonable',
#   'speed',
#   'see',
#   'situation',
#   'allowing',
#   'without',
#   'risk',
#   'remember',
#   'counterfeit',
#   'dollar',
#   'thing',
#   'went',
#   'year',
#   'ago',
#   'villain',
#   'ran',
#   'radar',
#   'car',
#   'load',
#   'fake',
#   'police',
#   'enough',
#   'fine',
#   'large',
#   'number',
#   'road',
#   'user',
#   'personally'],
#  ['teach',
#   'child',
#   'walk',
#   'traffic',
#   'light',
#   'anymore',
#   'automonitoring',
#   'increased',
#   'urban',
#   'area',
#   'road',
#   'especially',
#   'necessary',
#   'useful',
#   'would',
#   'traffic',
#   'light',
#   'driving',
#   'red',
#   'become',
#   'way',
#   'country'],
#  ['risk',
#   'speeding',
#   'ticket',
#   'minimized',
#   'course',
#   'automatic',
#   'speed',
#   'control',
#   'addition',
#   'dangerous',
#   'unnecessary',
#   'constant',
#   'speed',
#   'control',
#   'safe',
#   'well',
#   'run',
#   'legal',
#   'every',
#   'pas',
#   'requires',
#   'speeding',
#   'succeed',
#   'safely',
#   'unnecessary',
#   'many',
#   'marmattatas',
#   'fact',
#   'range',
#   'run',
#   'illegal'],
#  ['afford',
#   'drive',
#   'speeding',
#   'would',
#   'lead',
#   'fine',
#   'kmh',
#   'speed',
#   'limit',
#   'nobody',
#   'drive',
#   'kmh',
#   'time',
#   'difference',
#   'distance',
#   'minute',
#   'exactly',
#   'time',
#   'kmh',
#   'kmh',
#   'really',
#   'understand',
#   'current',
#   'speed',
#   'control',
#   'tax',
#   'burden',
#   'others',
#   'reduced',
#   'accordingly',
#   'even',
#   'small',
#   'speeding',
#   'fuel',
#   'saved',
#   'cost',
#   'safer',
#   'everyone',
#   'studied',
#   'zero',
#   'tolerance',
#   'afford',
#   'pay',
#   'fine'],
#  ['even',
#   'though',
#   'dont',
#   'radar',
#   'detector',
#   'even',
#   'scanner',
#   'otherwise',
#   'know',
#   'way',
#   'cop',
#   'cost',
#   'nice',
#   'feeling',
#   'get',
#   'little',
#   'bit',
#   'dim',
#   'camera',
#   'tear',
#   'slowly',
#   'case',
#   'cross',
#   'get',
#   'least',
#   'kmh',
#   'high',
#   'speed',
#   'see',
#   'red',
#   'lower',
#   'lens',
#   'know',
#   'there',
#   'camera',
#   'place',
#   'there',
#   'change',
#   'place',
#   'least',
#   'expense',
#   'surveillance',
#   'dont',
#   'get',
#   'many',
#   'speeding',
#   'ticket',
#   'cant',
#   'easily',
#   'let',
#   'dont',
#   'drive',
#   'much',
#   'away',
#   'know',
#   'camera',
#   'could',
#   'add',
#   'there',
#   'camera',
#   'every',
#   'case'],
#  ['real', 'apig', 'expert', 'funny', 'thing'],
#  ['there',
#   'nothing',
#   'else',
#   'wheel',
#   'look',
#   'meter',
#   'youre',
#   'ride',
#   'force',
#   'look',
#   'meter',
#   'scream',
#   'start',
#   'going',
#   'limit',
#   'mean'],
#  ['comment', 'fuck', 'youll', 'get', 'as', 'kicked', 'walk'],
#  ['pay',
#   'driver',
#   'made',
#   'commitment',
#   'traffic',
#   'offence',
#   'signing',
#   'licence',
#   'application',
#   'got',
#   'automatic',
#   'fine',
#   'police',
#   'officer',
#   'every',
#   'villain',
#   'long',
#   'demand',
#   'harm',
#   'would',
#   'automatic',
#   'control',
#   'money',
#   'probably',
#   'bad',
#   'guy',
#   'would',
#   'caught',
#   'faster',
#   'speed',
#   'control',
#   'much',
#   'know',
#   'automatic',
#   'speed',
#   'control',
#   'improve',
#   'road',
#   'safety',
#   'enough',
#   'scarce',
#   'resource',
#   'company',
#   'handicrafted',
#   'extreme',
#   'end',
#   'day',
#   'automatic',
#   'fine',
#   'also',
#   'offered',
#   'agreed',
#   'rule',
#   'game',
#   'cannot',
#   'complied'],
#  ['mostly',
#   'due',
#   'heavy',
#   'hop',
#   'time',
#   'got',
#   'ticket',
#   'driving',
#   'five',
#   'year',
#   'ago',
#   'human',
#   'labour',
#   'high',
#   'sleep',
#   'rate',
#   'according',
#   'report',
#   'majority',
#   'accident',
#   'caused',
#   'loss',
#   'driver',
#   'driving',
#   'ability',
#   'parking',
#   'supervisor',
#   'price',
#   'fim',
#   'agerelated',
#   'disease',
#   'sometimes',
#   'also',
#   'drug',
#   'drug',
#   'abuse',
#   'also',
#   'lot',
#   'suicide',
#   'traffic',
#   'le',
#   'hundred',
#   'case',
#   'per',
#   'year',
#   'claim',
#   'accident',
#   'would',
#   'sufficiently',
#   'reduced',
#   'due',
#   'report',
#   'research',
#   'board',
#   'investigator',
#   'read',
#   'fatal',
#   'accident',
#   'case',
#   'accident',
#   'really',
#   'considered',
#   'caused',
#   'much',
#   'speed',
#   'left',
#   'minority'],
#  ['swedish',
#   'give',
#   'people',
#   'broke',
#   'spree',
#   'cameraslenses',
#   'repair',
#   'became',
#   'expensive',
#   'hiring',
#   'real',
#   'police',
#   'officer'],
#  ['high',
#   'speed',
#   'controlled',
#   'drunk',
#   'taken',
#   'jail',
#   'traffic',
#   'offence',
#   'tackled',
#   'mention',
#   'minor',
#   'traffic',
#   'offence',
#   'police',
#   'lazy',
#   'police',
#   'lot',
#   'money',
#   'pay',
#   'job',
#   'take',
#   'hour',
#   'police',
#   'get',
#   'taxi',
#   'already',
#   'available',
#   'minute',
#   'pizza',
#   'le',
#   'hour',
#   'mobile',
#   'police',
#   'replaced',
#   'camera',
#   'drunk',
#   'delegated',
#   'security',
#   'store'],
#  ['dont', 'know', 'sure', 'always', 'come', 'taxi', 'pizza'],
#  ['probably',
#   'five',
#   'time',
#   'ride',
#   'least',
#   'chased',
#   'riding',
#   'moped',
#   'sometimes',
#   'middle',
#   'ride',
#   'came',
#   'sudden',
#   'departure'],
#  ['necessarily',
#   'bad',
#   'imagined',
#   'wrong',
#   'control',
#   'citizen',
#   'far',
#   'concerned',
#   'actual',
#   'police',
#   'state',
#   'people',
#   'crowd',
#   'stupid',
#   'group',
#   'dynamic',
#   'devilish',
#   'people',
#   'happy',
#   'totalitarian',
#   'system',
#   'wondered',
#   'would',
#   'rigorously',
#   'controlled',
#   'suppose',
#   'social',
#   'system',
#   'looked',
#   'tolerance',
#   'debate',
#   'singapore',
#   'though',
#   'course',
#   'little',
#   'modified',
#   'direct',
#   'democracy',
#   'certainly',
#   'seem',
#   'playing',
#   'cannot',
#   'offend',
#   'human',
#   'right',
#   'hand',
#   'socalled',
#   'totalitarian',
#   'society',
#   'better',
#   'solution',
#   'liberal',
#   'system',
#   'almost',
#   'agree',
#   'orwellian',
#   'society',
#   'communist',
#   'utopia',
#   'would',
#   'also',
#   'nice',
#   'place',
#   'live'],
#  ['live',
#   'democracy',
#   'people',
#   'representative',
#   'represent',
#   'political',
#   'state',
#   'control',
#   'feel',
#   'well',
#   'citizen',
#   'man',
#   'happiness',
#   'society',
#   'depends',
#   'system',
#   'surely',
#   'soviet',
#   'union',
#   'happy',
#   'today',
#   'yes',
#   'dont',
#   'live',
#   'totalitarian',
#   'society',
#   'said',
#   'person',
#   'happy',
#   'society',
#   'think',
#   'people',
#   'society',
#   'survival',
#   'secure',
#   'police',
#   'given',
#   'right',
#   'listen',
#   'people',
#   'cell',
#   'phone',
#   'phone',
#   'call',
#   'given',
#   'permission',
#   'steal',
#   'people',
#   'surveillance',
#   'greatly',
#   'facilitated',
#   'yes',
#   'come',
#   'much',
#   'closer',
#   'feel',
#   'drive',
#   'there',
#   'police',
#   'camera',
#   'city',
#   'video',
#   'camera',
#   'every',
#   'corner',
#   'least',
#   'hole',
#   'raid',
#   'end',
#   'road',
#   'feel',
#   'safe',
#   'environment',
#   'feel',
#   'safer',
#   'finland',
#   'youve',
#   'already',
#   'noticed'],
#  ['soviet',
#   'union',
#   'incredible',
#   'amount',
#   'unhappy',
#   'people',
#   'precisely',
#   'didnt',
#   'say',
#   'society',
#   'proposed',
#   'would',
#   'perfect',
#   'happier',
#   'reason',
#   'curse',
#   'security',
#   'camera',
#   'mean',
#   'control',
#   'monitoring',
#   'reduce',
#   'satisfaction',
#   'course',
#   'there',
#   'reason',
#   'overboard',
#   'idea',
#   'expressed',
#   'besides',
#   'havent',
#   'done',
#   'anything',
#   'wrong',
#   'said',
#   'would',
#   'work',
#   'well',
#   'today',
#   'used',
#   'wrong',
#   'purpose',
#   'protect',
#   'public',
#   'sense',
#   'security',
#   'decrease',
#   'see',
#   'camera',
#   'staring',
#   'window',
#   'car'],
#  ['human',
#   'life',
#   'work',
#   'education',
#   'different',
#   'thought',
#   'put',
#   'opposed',
#   'theory',
#   'part',
#   'thought',
#   'happy',
#   'society',
#   'except',
#   'ideal',
#   'society',
#   'affect',
#   'dutch',
#   'line',
#   'never',
#   'work',
#   'center',
#   'hole',
#   'put',
#   'camera',
#   'surveillance',
#   'within',
#   'couple',
#   'week',
#   'almost',
#   'kind',
#   'society',
#   'work',
#   'catch',
#   'relationship',
#   'problem',
#   'surely',
#   'uncomfortable',
#   'talked',
#   'forced',
#   'labour',
#   'camp',
#   'soviet',
#   'union',
#   'many',
#   'fight',
#   'would',
#   'prevented',
#   'policeman',
#   'police',
#   'uniform',
#   'foot',
#   'patrol',
#   'according',
#   'press',
#   'report',
#   'police',
#   'prevented',
#   'two',
#   'fight'],
#  ['wrong',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'dont',
#   'know',
#   'whats',
#   'going',
#   'telling',
#   'thats',
#   'reason',
#   'youre',
#   'telling',
#   'thats',
#   'reason',
#   'youre',
#   'telling',
#   'thats',
#   'whats',
#   'going',
#   'telling',
#   'thats',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'wrong',
#   'way',
#   'going',
#   'going'],
#  ['nonsense', 'analysis', 'dont', 'live', 'cuba', 'month'],
#  ['strange',
#   'go',
#   'nick',
#   'uriellukku',
#   'strange',
#   'see',
#   'year',
#   'time',
#   'youll',
#   'long',
#   'write',
#   'nick',
#   'like',
#   'christmas',
#   'christmas',
#   'ended',
#   'little',
#   'boy',
#   'personally',
#   'havent',
#   'written',
#   'anything',
#   'long',
#   'time',
#   'tsippe',
#   'le',
#   'often',
#   'even',
#   'visit',
#   'miss',
#   'past',
#   'old',
#   'crowd',
#   'heinis',
#   'ramon',
#   'love',
#   'ill',
#   'try',
#   'remember',
#   'people',
#   'arethusa',
#   'pseudo',
#   'hippi',
#   'oplev',
#   'dark',
#   'light',
#   'feeling',
#   'longing',
#   'nostalgia',
#   'whats',
#   'forgotten',
#   'com',
#   'wonder',
#   'anyones',
#   'anymore'],
#  ['came',
#   'today',
#   'whisper',
#   'quote',
#   'like',
#   'highest',
#   'lead',
#   'happened',
#   'read',
#   'message'],
#  ['bit',
#   'jumble',
#   'jing',
#   'jingle',
#   'jingle',
#   'jing',
#   'bit',
#   'fuss',
#   'bit',
#   'fuss',
#   'telling',
#   'bit',
#   'fuss',
#   'jumble'],
#  ['little',
#   'mistake',
#   'havent',
#   'heal',
#   'wound',
#   'balsam',
#   'even',
#   'invented',
#   'superior',
#   'life',
#   'product',
#   'night',
#   'ive',
#   'away',
#   'home',
#   'week',
#   'long',
#   'enough',
#   'look',
#   'start',
#   'analysis',
#   'column',
#   'state',
#   'back',
#   'case',
#   'bit',
#   'money',
#   'thats',
#   'going',
#   'spent',
#   'going',
#   'way',
#   'time',
#   'money',
#   'money',
#   'money',
#   'money',
#   'time',
#   'month',
#   'going',
#   'thing',
#   'unlike',
#   'last',
#   'time',
#   'ive',
#   'claimed',
#   'ive',
#   'thing',
#   'ive',
#   'terrible',
#   'thing',
#   'yous',
#   'sake',
#   'sake',
#   'ive',
#   'kind',
#   'thinking',
#   'unlike',
#   'pseudo',
#   'last',
#   'claim',
#   'money',
#   'month',
#   'ive',
#   'spending',
#   'much',
#   'money',
#   'morning',
#   'thought',
#   'greet',
#   'jumania',
#   'teretere',
#   'got',
#   'silver',
#   'skied',
#   'gold',
#   'jumped',
#   'going',
#   'sake',
#   'youre',
#   'getting',
#   'ahead',
#   'take',
#   'victory',
#   'home',
#   'almost',
#   'identically',
#   'going',
#   'morning',
#   'money',
#   'month',
#   'sake',
#   'sake',
#   'sake',
#   'going',
#   'thing',
#   'going',
#   'month',
#   'money',
#   'month',
#   'ive',
#   'kind',
#   'thinking',
#   'going',
#   'thing',
#   'money',
#   'money',
#   'month',
#   'time',
#   'money',
#   'month',
#   'going',
#   'money',
#   'month',
#   'money',
#   'going',
#   'thing',
#   'going',
#   'going',
#   'time',
#   'month',
#   'going',
#   'time',
#   'time',
#   'month',
#   'sake',
#   'going',
#   'going',
#   'month'],
#  ['distracted',
#   'fact',
#   'new',
#   'headline',
#   'flooding',
#   'cloud',
#   'good',
#   'conversation',
#   'left',
#   'behind',
#   'many',
#   'column',
#   'problem',
#   'see',
#   'lot',
#   'people',
#   'coming',
#   'trying',
#   'provoke',
#   'others',
#   'throw',
#   'many',
#   'time',
#   'lake',
#   'maybe',
#   'new',
#   'user',
#   'column',
#   'many',
#   'column',
#   'past',
#   'mean',
#   'mostly',
#   'column',
#   'also',
#   'crowd',
#   'knowingly',
#   'want',
#   'disturb',
#   'column',
#   'action',
#   'theyll',
#   'enough',
#   'miss',
#   'column',
#   'theyre',
#   'always',
#   'showing',
#   'conversation',
#   'start',
#   'interesting',
#   'even',
#   'useful',
#   'hand',
#   'whose',
#   'topic',
#   'profound',
#   'whose',
#   'purpose',
#   'maybe',
#   'mainly',
#   'entertain',
#   'maintain',
#   'light',
#   'conversation',
#   'text',
#   'level',
#   'conversation',
#   'sometimes',
#   'theyll',
#   'get',
#   'quick',
#   'hit',
#   'however'],
#  ['lot',
#   'overjumps',
#   'collide',
#   'many',
#   'front',
#   'page',
#   'easier',
#   'skip',
#   'back',
#   'time',
#   'take',
#   'look',
#   'something',
#   'old',
#   'kind',
#   'conversationor',
#   'summary',
#   'review',
#   'good',
#   'small',
#   'number',
#   'give',
#   'good',
#   'tip',
#   'whose',
#   'nickname',
#   'open',
#   'deepen',
#   'comment'],
#  ['good',
#   'flash',
#   'sun',
#   'yesterday',
#   'day',
#   'something',
#   'expected',
#   'ive',
#   'spent',
#   'half',
#   'day',
#   'front',
#   'page',
#   'landscape',
#   'beginning',
#   'think',
#   'often',
#   'market',
#   'filling',
#   'column',
#   'mostly',
#   'rubbish',
#   'take',
#   'time',
#   'energy',
#   'screen',
#   'pearl',
#   'sitting',
#   'around',
#   'computer',
#   'never',
#   'completely',
#   'useless',
#   'ill',
#   'keep',
#   'curiosity',
#   'space',
#   'weather',
#   'side',
#   'rest',
#   'eye',
#   'name',
#   'ill',
#   'write',
#   'something',
#   'follow',
#   'animal',
#   'story',
#   'god',
#   'sake',
#   'sake',
#   'word',
#   'easier',
#   'find',
#   'machine',
#   'search',
#   'book',
#   'bookcase',
#   'secondly',
#   'could',
#   'used',
#   'usefully',
#   'there',
#   'going',
#   'time',
#   'evening',
#   'always',
#   'sought',
#   'piece',
#   'information',
#   'interesting',
#   'thing',
#   'come'],
#  ['write',
#   'something',
#   'follow',
#   'animal',
#   'story',
#   'animal',
#   'page',
#   'curiosity',
#   'space',
#   'weather',
#   'page',
#   'still',
#   'mostly',
#   'peaceful',
#   'starting',
#   'get',
#   'phrase',
#   'get',
#   'time',
#   'evening',
#   'bead',
#   'screening',
#   'take',
#   'time',
#   'energy',
#   'lot',
#   'discussion',
#   'exapina',
#   'scribe'],
#  ['everything',
#   'exists',
#   'borncreated',
#   'point',
#   'take',
#   'evothan',
#   'creationism',
#   'theyre',
#   'even',
#   'reading',
#   'purpose',
#   'would',
#   'best',
#   'live',
#   'moment',
#   'idems',
#   'give',
#   'answer',
#   'sorry',
#   'wandering',
#   'around',
#   'like',
#   'following',
#   'front',
#   'page',
#   'full',
#   'crap',
#   'religion',
#   'philosophy',
#   'nothing',
#   'born',
#   'chance',
#   'eternal',
#   'problem',
#   'ive',
#   'always',
#   'still',
#   'wondered',
#   'eternal',
#   'question',
#   'humanity'],
#  ['therefore',
#   'foundation',
#   'existence',
#   'god',
#   'immobilizer',
#   'theology',
#   'doctrine',
#   'god',
#   'philosophy',
#   'theology',
#   'versus',
#   'christian',
#   'theology',
#   'western',
#   'philosophy',
#   'christian',
#   'tone',
#   'atheist',
#   'claim',
#   'know',
#   'god',
#   'teist',
#   'know',
#   'god',
#   'agnostic',
#   'claim',
#   'traditional',
#   'proof',
#   'existence',
#   'god',
#   'definition',
#   'god',
#   'talking',
#   'agnostic',
#   'yet',
#   'conscious',
#   'world',
#   'causal',
#   'testimony',
#   'every',
#   'event',
#   'consequence',
#   'beginning',
#   'chain',
#   'consequence',
#   'first',
#   'reason',
#   'god',
#   'quote',
#   'slice',
#   'theoretical',
#   'philosophy',
#   'philosophical',
#   'theology',
#   'cosmic',
#   'proof',
#   'thing',
#   'thing',
#   'either',
#   'exist',
#   'conditional',
#   'existence',
#   'absolute'],
#  ['add',
#   'prewritten',
#   'almost',
#   'triggering',
#   'reflection',
#   'answer',
#   'written',
#   'backscapes',
#   'active',
#   'conversation',
#   'page',
#   'jesus',
#   'metaphys',
#   'announcement',
#   'miet',
#   'creator',
#   'perhaps',
#   'sand',
#   'star'],
#  ['thats',
#   'dont',
#   'accept',
#   'dont',
#   'know',
#   'there',
#   'life',
#   'death',
#   'god',
#   'create',
#   'world',
#   'want',
#   'experience',
#   'otherness',
#   'dont',
#   'know',
#   'answer',
#   'dont',
#   'know',
#   'everything',
#   'created',
#   'born',
#   'entity',
#   'always',
#   'question',
#   'front',
#   'page',
#   'heading',
#   'there',
#   'much',
#   'sense',
#   'mind',
#   'doesnt',
#   'understand'],
#  ['waited',
#   'answer',
#   'would',
#   'speak',
#   'cause',
#   'creation',
#   'lord',
#   'created',
#   'firstborn',
#   'work',
#   'beginning',
#   'age',
#   'yet',
#   'earth',
#   'depth',
#   'born',
#   'born',
#   'depth',
#   'age',
#   'born',
#   'given',
#   'answer',
#   'god',
#   'created',
#   'universe',
#   'men',
#   'plaything',
#   'son',
#   'scripture',
#   'explore',
#   'matter',
#   'proverb',
#   'chapter',
#   'gtgt',
#   'would',
#   'able',
#   'answer',
#   'front',
#   'page',
#   'raging',
#   'born',
#   'beginning',
#   'depth',
#   'earth',
#   'question',
#   'valid',
#   'answer',
#   'found',
#   'bible',
#   'heaven',
#   'hill',
#   'answer',
#   'harsh',
#   'mountain',
#   'immersed',
#   'place',
#   'first',
#   'work',
#   'born',
#   'searching',
#   'bible',
#   'back',
#   'forth',
#   'praying',
#   'answer'],
#  ['speed',
#   'magnetic',
#   'field',
#   'jumped',
#   'well',
#   'intensity',
#   'scale',
#   'northern',
#   'light',
#   'hopeless',
#   'week',
#   'ago',
#   'keep',
#   'curiosity',
#   'space',
#   'weather',
#   'side',
#   'good',
#   'splash',
#   'sun',
#   'yesterday',
#   'something',
#   'expected',
#   'full',
#   'cloud',
#   'density',
#   'flash',
#   'hit',
#   'ball',
#   'hour',
#   'ago',
#   'solar',
#   'wind',
#   'temperature'],
#  ['atetms',
#   'give',
#   'answer',
#   'question',
#   'column',
#   'ask',
#   'question',
#   'eternal',
#   'problem',
#   'thought',
#   'revolved',
#   'around',
#   'question',
#   'enough',
#   'pain',
#   'decade',
#   'matter',
#   'mystery',
#   'existence',
#   'eternal',
#   'question',
#   'humanity',
#   'religion',
#   'never',
#   'occurs',
#   'would',
#   'thought',
#   'deeply',
#   'tried',
#   'remember',
#   'thought',
#   'past',
#   'philosophy'],
#  ['ive',
#   'ive',
#   'probably',
#   'writing',
#   'ive',
#   'long',
#   'time',
#   'ive',
#   'long',
#   'time',
#   'ive',
#   'long',
#   'time',
#   'ive',
#   'long',
#   'time',
#   'ive',
#   'writing',
#   'ive',
#   'writing',
#   'couple',
#   'day',
#   'ive',
#   'writing',
#   'ive',
#   'long',
#   'time',
#   'ive',
#   'writing',
#   'ive',
#   'long',
#   'time',
#   'ive',
#   'long',
#   'time',
#   'dont',
#   'know',
#   'ive',
#   'writing'],
#  ['waiting',
#   'find',
#   'golden',
#   'pasture',
#   'memory',
#   'didnt',
#   'time',
#   'write',
#   'day',
#   'flashy',
#   'life',
#   'hard',
#   'winter',
#   'treated',
#   'hard',
#   'keyboard',
#   'machine',
#   'said',
#   'poks',
#   'threw',
#   'virtuality',
#   'jne',
#   'back',
#   'closet',
#   'talking',
#   'come',
#   'mind',
#   'november',
#   'moominvalley',
#   'everyone',
#   'gathered',
#   'moomin',
#   'house',
#   'came',
#   'terrible',
#   'hemuli',
#   'well',
#   'welldiscovered',
#   'conversationist',
#   'could',
#   'anyone',
#   'else',
#   'secretly',
#   'lured',
#   'interior',
#   'history',
#   'got',
#   'tired',
#   'waiting',
#   'front',
#   'page',
#   'stuff',
#   'disturbed',
#   'everyone',
#   'people',
#   'retreated',
#   'dark',
#   'interior',
#   'moomin',
#   'house',
#   'spend',
#   'quiet',
#   'night'],
#  ['sounded',
#   'one',
#   'nature',
#   'father',
#   'son',
#   'holy',
#   'spirit',
#   'holy',
#   'spirit',
#   'therefore',
#   'represents',
#   'feminine',
#   'side',
#   'deity',
#   'god',
#   'create',
#   'order',
#   'experience',
#   'must',
#   'asked',
#   'somewhere',
#   'come',
#   'son',
#   'god',
#   'remembering',
#   'question',
#   'find',
#   'difficult',
#   'triunity',
#   'therefore',
#   'difficult',
#   'believe',
#   'god',
#   'created',
#   'universe',
#   'sake',
#   'game'],
#  ['consider',
#   'bible',
#   'book',
#   'requires',
#   'lot',
#   'interpretation',
#   'familiarity',
#   'layman',
#   'know',
#   'believe',
#   'sure',
#   'context',
#   'several',
#   'case',
#   'called',
#   'heretic',
#   'agnostic',
#   'bold',
#   'agnostic',
#   'perhaps',
#   'seeker',
#   'would',
#   'best',
#   'name'],
#  ['vaguely',
#   'something',
#   'column',
#   'clear',
#   'answer',
#   'took',
#   'printtewe',
#   'read',
#   'cant',
#   'really',
#   'describe',
#   'found',
#   'first',
#   'visit',
#   'april',
#   'evo',
#   'thank',
#   'went',
#   'apology',
#   'creationism',
#   'way',
#   'replied',
#   'article',
#   'faith',
#   'internal',
#   'experience'],
#  ['going',
#   'look',
#   'afraid',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look'],
#  ['reminds',
#   'william',
#   'carver',
#   'chosen',
#   'piece',
#   'ancient',
#   'case',
#   'name',
#   'place',
#   'may',
#   'also',
#   'wrong',
#   'remembered',
#   'prayed',
#   'god',
#   'reveal',
#   'secret',
#   'universe',
#   'triune',
#   'whereinss',
#   'answer',
#   'thing',
#   'william',
#   'took',
#   'job',
#   'cookie',
#   'god',
#   'help',
#   'rest',
#   'life',
#   'question',
#   'difficult',
#   'dont',
#   'believe',
#   'god',
#   'play',
#   'created',
#   'universe',
#   'explaining',
#   'universe',
#   'cause',
#   'pretty',
#   'big',
#   'slice',
#   'one',
#   'person',
#   'plate',
#   'answer',
#   'best',
#   'thing',
#   'say',
#   'god',
#   'replied',
#   'big',
#   'thing',
#   'kemistins',
#   'hundred',
#   'useful',
#   'usable',
#   'compound',
#   'substance'],
#  ['ill',
#   'tell',
#   'whats',
#   'wrong',
#   'ill',
#   'tell',
#   'whatll',
#   'tell',
#   'whatll',
#   'tell',
#   'ill',
#   'tell',
#   'whatll',
#   'tell',
#   'ill',
#   'tell',
#   'whatll',
#   'tell',
#   'whatll',
#   'tell',
#   'ill',
#   'tell',
#   'whats',
#   'wrong',
#   'ill',
#   'tell',
#   'whatll',
#   'tell',
#   'whatll',
#   'tell',
#   'itll',
#   'like',
#   'ill',
#   'tell',
#   'something',
#   'else',
#   'ill',
#   'tell',
#   'whatll',
#   'tell',
#   'itll'],
#  ['unfortunately',
#   'didnt',
#   'start',
#   'proper',
#   'conversation',
#   'dont',
#   'know',
#   'whats',
#   'going',
#   'sure',
#   'whats',
#   'going',
#   'ill',
#   'hardly',
#   'come',
#   'back',
#   'often',
#   'decide',
#   'ill',
#   'take',
#   'look',
#   'headline',
#   'going',
#   'talking',
#   'often',
#   'decide',
#   'ill',
#   'take',
#   'look',
#   'title',
#   'mostly',
#   'reading',
#   'rarely',
#   'opened',
#   'ill',
#   'take',
#   'part',
#   'subject',
#   'fresh',
#   'ill',
#   'barely',
#   'come',
#   'back',
#   'book',
#   'expensive',
#   'rarely',
#   'get',
#   'bought',
#   'even',
#   'youre',
#   'interested',
#   'well'],
#  ['havent',
#   'busy',
#   'looking',
#   'anything',
#   'else',
#   'window',
#   'show',
#   'pale',
#   'star',
#   'star',
#   'cant',
#   'look',
#   'ive',
#   'settle',
#   'lookout',
#   'sky',
#   'usually',
#   'lookout',
#   'star',
#   'lookout',
#   'muck',
#   'lookout',
#   'muck',
#   'know',
#   'starry',
#   'sky',
#   'look',
#   'like',
#   'dark',
#   'autumn',
#   'cant',
#   'imagine',
#   'living',
#   'anywhere',
#   'else'],
#  ['star',
#   'see',
#   'little',
#   'went',
#   'buy',
#   'panora',
#   'price',
#   'never',
#   'thought',
#   'binoculars',
#   'could',
#   'useful',
#   'city',
#   'year',
#   'ago',
#   'star',
#   'map',
#   'attached',
#   'magazine',
#   'ota',
#   'course',
#   'moment',
#   'thick',
#   'cloud',
#   'seems',
#   'worth',
#   'sometimes',
#   'didnt',
#   'get',
#   'sense',
#   'well',
#   'ive',
#   'read',
#   'book',
#   'see',
#   'map',
#   'wrong',
#   'direction',
#   'left',
#   'one',
#   'spinning',
#   'puck',
#   'group',
#   'star',
#   'recognize',
#   'seemed',
#   'wrong',
#   'place',
#   'look',
#   'forward',
#   'sky',
#   'clear',
#   'applied',
#   'library',
#   'map',
#   'star',
#   'bare',
#   'eye'],
#  ['star',
#   'see',
#   'little',
#   'went',
#   'buy',
#   'panora',
#   'price',
#   'never',
#   'thought',
#   'binoculars',
#   'could',
#   'useful',
#   'city',
#   'year',
#   'ago',
#   'star',
#   'map',
#   'attached',
#   'magazine',
#   'ota',
#   'course',
#   'moment',
#   'thick',
#   'cloud',
#   'seems',
#   'worth',
#   'sometimes',
#   'didnt',
#   'get',
#   'sense',
#   'well',
#   'ive',
#   'read',
#   'book',
#   'see',
#   'map',
#   'wrong',
#   'direction',
#   'left',
#   'one',
#   'spinning',
#   'puck',
#   'group',
#   'star',
#   'recognize',
#   'seemed',
#   'wrong',
#   'place',
#   'look',
#   'forward',
#   'sky',
#   'clear',
#   'applied',
#   'library',
#   'map',
#   'star',
#   'bare',
#   'eye'],
#  ['somewhere',
#   'something',
#   'interesting',
#   'going',
#   'get',
#   'geimes',
#   'time',
#   'page',
#   'wrote',
#   'playful',
#   'mind',
#   'xenon',
#   'paradox',
#   'subject',
#   'heading',
#   'question',
#   'columnist',
#   'participated',
#   'subject',
#   'fresh',
#   'unfortunately',
#   'didnt',
#   'start',
#   'proper',
#   'discussion',
#   'read',
#   'chain',
#   'started',
#   'turning',
#   'comment',
#   'subject',
#   'einstein',
#   'old',
#   'mold',
#   'ear',
#   'would',
#   'gotten',
#   'ride',
#   'superstring',
#   'planck',
#   'ten',
#   'thousand',
#   'calabs',
#   'mirror',
#   'beam',
#   'would',
#   'solved',
#   'problem',
#   'tearing',
#   'whole',
#   'space',
#   'continuum',
#   'apart',
#   'came',
#   'head',
#   'mind',
#   'estimated',
#   'event',
#   'would',
#   'week',
#   'late',
#   'change',
#   'name',
#   'would',
#   'returned',
#   'past',
#   'conversation',
#   'actual',
#   'koita',
#   'hint'],
#  ['spinable',
#   'puck',
#   'even',
#   'better',
#   'empty',
#   'spinable',
#   'puck',
#   'top',
#   'transparent',
#   'impelable',
#   'rotating',
#   'scale',
#   'star',
#   'map',
#   'planispheric',
#   'extremely',
#   'useful',
#   'star',
#   'appear',
#   'see',
#   'one',
#   'grasp',
#   'one',
#   'sometimes',
#   'added',
#   'science',
#   'image',
#   'magazine',
#   'slice',
#   'winter',
#   'sky',
#   'slice',
#   'extends',
#   'horizon',
#   'middle',
#   'sky',
#   'ursa',
#   'least',
#   'ever',
#   'sold',
#   'star',
#   'dont',
#   'see',
#   'large',
#   'slice',
#   'heaven',
#   'home',
#   'year',
#   'ago',
#   'star',
#   'map',
#   'attached',
#   'magazine'],
#  ['transparency',
#   'practice',
#   'basically',
#   'university',
#   'lecture',
#   'open',
#   'interested',
#   'within',
#   'premise',
#   'course',
#   'think',
#   'youre',
#   'get',
#   'know',
#   'star',
#   'sit',
#   'listen',
#   'first',
#   'time',
#   'bright',
#   'sky',
#   'many',
#   'day',
#   'went',
#   'listen',
#   'university',
#   'lecture',
#   'least',
#   'basic',
#   'astronomy',
#   'class',
#   'sit',
#   'interested',
#   'people',
#   'elementary',
#   'school',
#   'senior',
#   'grandmother',
#   'least',
#   'even',
#   'youre',
#   'student',
#   'university',
#   'book',
#   'today',
#   'thought',
#   'thing',
#   'since',
#   'youre',
#   'eager',
#   'take',
#   'information',
#   'book'],
#  ['binoculars',
#   'beginning',
#   'evening',
#   'star',
#   'stood',
#   'vague',
#   'vibrating',
#   'spot',
#   'couple',
#   'hour',
#   'clear',
#   'cluster',
#   'star',
#   'wouldnt',
#   'separated',
#   'first',
#   'theyd',
#   'got',
#   'disappointed',
#   'eye',
#   'scattered',
#   'itd',
#   'shame',
#   'cloud',
#   'gathered',
#   'apparently',
#   'planet',
#   'yesterday',
#   'playing',
#   'streak',
#   'star',
#   'bright',
#   'shining',
#   'star',
#   'even',
#   'though',
#   'star',
#   'map',
#   'pretty',
#   'sure',
#   'cluster',
#   'belonged',
#   'could',
#   'didnt',
#   'get',
#   'reference',
#   'point',
#   'woke',
#   'three',
#   'oclock',
#   'night',
#   'happened',
#   'look',
#   'window',
#   'open',
#   'east'],
#  ['almost',
#   'view',
#   'ten',
#   'time',
#   'cloud',
#   'pitched',
#   'left',
#   'perseus',
#   'left',
#   'northeast',
#   'side',
#   'road',
#   'whole',
#   'time',
#   'landscape',
#   'essence',
#   'binoculars',
#   'normal',
#   'touch',
#   'right',
#   'forefinger',
#   'little',
#   'bit',
#   'different',
#   'fold',
#   'right',
#   'side',
#   'minus',
#   'window',
#   'computer',
#   'star',
#   'stood',
#   'beginning',
#   'binoculars',
#   'vague',
#   'vibrating',
#   'spot',
#   'adjustment',
#   'binocular',
#   'refine',
#   'image',
#   'least',
#   'one',
#   'thing',
#   'come',
#   'eye',
#   'spin',
#   'around',
#   'left',
#   'always',
#   'small',
#   'motion',
#   'rotate',
#   'back',
#   'forth',
#   'find',
#   'best',
#   'precision'],
#  ['havent',
#   'opened',
#   'discussion',
#   'since',
#   'like',
#   'place',
#   'afterwards',
#   'remembered',
#   'watched',
#   'himalaya',
#   'mountain',
#   'wrapped',
#   'blanket',
#   'starry',
#   'sky',
#   'something',
#   'interesting',
#   'travel',
#   'story',
#   'read',
#   'expedition',
#   'write',
#   'sometimes',
#   'shall',
#   'look',
#   'away',
#   'almost',
#   'june'],
#  ['continue',
#   'page',
#   'arethusa',
#   'quickly',
#   'opleville',
#   'force',
#   'return',
#   'night',
#   'struck',
#   'stomach',
#   'bug',
#   'also',
#   'dream',
#   'cant',
#   'remember',
#   'whether',
#   'interesting',
#   'discussion',
#   'spiteful',
#   'racism',
#   'debate',
#   'june',
#   'force',
#   'veks',
#   'harald',
#   'kettunen',
#   'ill',
#   'start',
#   'exchanging',
#   'message',
#   'page',
#   'there',
#   'bit',
#   'indian',
#   'experience',
#   'ill',
#   'return',
#   'title',
#   'arethusa',
#   'right',
#   'next',
#   'religion',
#   'issue',
#   'moment',
#   'brain',
#   'like',
#   'cotton'],
#  ['keep',
#   'binocular',
#   'hand',
#   'sky',
#   'go',
#   'narrow',
#   'strip',
#   'blue',
#   'sky',
#   'see',
#   'star',
#   'two',
#   'happen',
#   'read',
#   'within',
#   'hour'],
#  ['height',
#   'changing',
#   'climate',
#   'could',
#   'think',
#   'imagine',
#   'himalaya',
#   'dreaming',
#   'home',
#   'rock',
#   'bottom',
#   'book',
#   'travel',
#   'photographer',
#   'able',
#   'remember',
#   'looked',
#   'mountain',
#   'himalaya',
#   'wrapped',
#   'starry',
#   'sky',
#   'seafront',
#   'track',
#   'different',
#   'height',
#   'time',
#   'trail',
#   'would',
#   'found',
#   'outer',
#   'island',
#   'gulf',
#   'finland',
#   'great',
#   'flora',
#   'finland',
#   'travel',
#   'busy',
#   'important',
#   'hill',
#   'finland',
#   'perhaps',
#   'bit',
#   'mountain',
#   'fan',
#   'today',
#   'net',
#   'vegetation',
#   'book',
#   'found',
#   'everything',
#   'related',
#   'good',
#   'hill',
#   'numbered',
#   'hill',
#   'everything'],
#  ['red',
#   'color',
#   'top',
#   'south',
#   'english',
#   'show',
#   'clear',
#   'air',
#   'even',
#   'city',
#   'dark',
#   'time',
#   'even',
#   'point',
#   'binoculars',
#   'star',
#   'tip',
#   'evening',
#   'looking',
#   'illuminated',
#   'screen',
#   'computer',
#   'show',
#   'bright',
#   'star',
#   'northeast',
#   'eye',
#   'air',
#   'swept',
#   'rain',
#   'extremely',
#   'bright',
#   'northern',
#   'light',
#   'observation',
#   'page',
#   'httpsec',
#   'gif',
#   'show',
#   'ten',
#   'minute',
#   'le',
#   'back',
#   'northern',
#   'hemisphere',
#   'northern',
#   'northern',
#   'northern',
#   'light',
#   'election',
#   'noa',
#   'govpmapgifpmapn',
#   'activity',
#   'level',
#   'left',
#   'side',
#   'ten',
#   'happen',
#   'read',
#   'good',
#   'seeing',
#   'far',
#   'cloud',
#   'increasingly',
#   'opening'],
#  ['along',
#   'route',
#   'local',
#   'guide',
#   'watching',
#   'tourist',
#   'gorge',
#   'samaria',
#   'although',
#   'good',
#   'view',
#   'himalaya',
#   'mountain',
#   'peak',
#   'terrain',
#   'place',
#   'difficulty',
#   'bad',
#   'stopped',
#   'look',
#   'around',
#   'walker',
#   'hania',
#   'posted',
#   'story',
#   'foot',
#   'himalaya',
#   'mountain',
#   'tourist',
#   'group',
#   'side',
#   'waiting',
#   'ferry',
#   'take',
#   'hiker',
#   'one',
#   'interesting',
#   'place',
#   'walked',
#   'crete',
#   'guide',
#   'immediately',
#   'rushing',
#   'along',
#   'route',
#   'telling',
#   'place',
#   'rest',
#   'bit',
#   'mistake',
#   'northern',
#   'india',
#   'route',
#   'long',
#   'although',
#   'tried',
#   'walk',
#   'privacy'],
#  ['keeping', 'eye', 'situation', 'much', 'sky', 'crack', 'cloud'],
#  ['previous',
#   'one',
#   'tried',
#   'lure',
#   'background',
#   'let',
#   'see',
#   'bait',
#   'bite',
#   'get',
#   'caught',
#   'away',
#   'intended',
#   'tobacco',
#   'man',
#   'iiwar',
#   'oplev',
#   'first',
#   'side',
#   'tip',
#   'quite',
#   'right',
#   'one'],
#  ['room',
#   'performance',
#   'refer',
#   'directly',
#   'message',
#   'end',
#   'address',
#   'line',
#   'removing',
#   'character',
#   'ampofsxxx',
#   'regardless',
#   'distance',
#   'front',
#   'page',
#   'suomi',
#   'example',
#   'thought',
#   'mention',
#   'one',
#   'thing',
#   'make',
#   'easier',
#   'find',
#   'message',
#   'acshowampefefag',
#   'suomi',
#   'chat',
#   'software',
#   'functionally',
#   'fine',
#   'xxx',
#   'serial',
#   'number',
#   'message',
#   'chain',
#   'since',
#   'latest',
#   'ive',
#   'noticed',
#   'people',
#   'usually',
#   'refer',
#   'chain',
#   'sequence',
#   'problem',
#   'constantly',
#   'growing',
#   'new',
#   'chain',
#   'time',
#   'opened',
#   'ive',
#   'always',
#   'used',
#   'kanid',
#   'long',
#   'number',
#   'series',
#   'message',
#   'message',
#   'found',
#   'address',
#   'message',
#   'httpdebate',
#   'youre',
#   'archive'],
#  ['like',
#   'httpdebate',
#   'suomi',
#   'pixel',
#   'letter',
#   'character',
#   'address',
#   'line',
#   'small',
#   'one',
#   'cant',
#   'really',
#   'read',
#   'individual',
#   'letter',
#   'acshow',
#   'ampidefceeg',
#   'httpdebate',
#   'httpdebate',
#   'problem',
#   'appear',
#   'come',
#   'accuracy',
#   'screen',
#   'used'],
#  ['see',
#   'dim',
#   'spot',
#   'see',
#   'degree',
#   'high',
#   'oclock',
#   'evening',
#   'yesterday',
#   'looked',
#   'window',
#   'binoculars',
#   'saw',
#   'map',
#   'map',
#   'page',
#   'right',
#   'upper',
#   'corner',
#   'point',
#   'reference',
#   'andromeda',
#   'constellation',
#   'mirach',
#   'sky',
#   'binocular',
#   'field',
#   'window',
#   'east',
#   'could',
#   'see',
#   'core',
#   'andromeda',
#   'galaxy',
#   'straight',
#   'east',
#   'quite',
#   'high',
#   'million',
#   'year',
#   'ago',
#   'time',
#   'foot',
#   'away',
#   'show',
#   'even',
#   'better',
#   'degree',
#   'twice',
#   'right'],
#  ['watch',
#   'cloud',
#   'away',
#   'read',
#   'message',
#   'sky',
#   'full',
#   'look',
#   'like',
#   'youre',
#   'cracking'],
#  ['next',
#   'page',
#   'title',
#   'age',
#   'survey',
#   'noticed',
#   'guerrilla',
#   'strike',
#   'plan',
#   'change',
#   'behind',
#   'title'],
#  ['hand',
#   'speak',
#   'dont',
#   'think',
#   'ill',
#   'ever',
#   'ready',
#   'attempt',
#   'better',
#   'finding',
#   'superior',
#   'dimension',
#   'faith',
#   'constant',
#   'quest',
#   'faith',
#   'stumbling',
#   'block',
#   'rocky',
#   'path',
#   'mountain',
#   'mean',
#   'word',
#   'monster',
#   'inner',
#   'peace',
#   'thats',
#   'youre',
#   'trying',
#   'dont',
#   'even',
#   'know',
#   'matter',
#   'death',
#   'otherwise',
#   'believe',
#   'isnt',
#   'scary',
#   'dont',
#   'even',
#   'know',
#   'matter',
#   'death',
#   'life',
#   'mystery'],
#  ['ive',
#   'almost',
#   'answered',
#   'interrupted',
#   'threw',
#   'text',
#   'somewhere',
#   'open',
#   'window',
#   'youll',
#   'see',
#   'headline',
#   'main',
#   'page',
#   'grow',
#   'page',
#   'twenty',
#   'important',
#   'thing',
#   'long',
#   'youre',
#   'looking',
#   'top',
#   'discussion',
#   'headline',
#   'main',
#   'page',
#   'number',
#   'here',
#   'text',
#   'relevant',
#   'correction',
#   'thats',
#   'instruction',
#   'page',
#   'referred',
#   'page',
#   'didnt',
#   'even',
#   'whole',
#   'thats',
#   'circle',
#   'line',
#   'know',
#   'like',
#   'say',
#   'today',
#   'end',
#   'story',
#   'ive',
#   'using',
#   'long',
#   'time'],
#  ['already',
#   'pointed',
#   'valuation',
#   'still',
#   'essence',
#   'jesusman',
#   'god',
#   'strange',
#   'knowledge',
#   'appeared',
#   'exegetic',
#   'text',
#   'read',
#   'like',
#   'little',
#   'piece',
#   'dont',
#   'understand',
#   'dual',
#   'concept',
#   'godman',
#   'thank',
#   'much',
#   'hint',
#   'thank',
#   'much',
#   'resitative',
#   'performance',
#   'also',
#   'find',
#   'thanks',
#   'original',
#   'page',
#   'mother',
#   'much',
#   'familiar',
#   'bible',
#   'research'],
#  ['rule',
#   'inhis',
#   'onwards',
#   'calg',
#   'according',
#   'humanscale',
#   'logic',
#   'rationality',
#   'jesus',
#   'chromosome',
#   'genetic',
#   'problem',
#   'point',
#   'aside',
#   'explanation',
#   'called',
#   'son',
#   'god',
#   'lmil',
#   'hand',
#   'impossible',
#   'could',
#   'finite',
#   'man',
#   'side',
#   'creation',
#   'include',
#   'infinity',
#   'creator',
#   'deity',
#   'power',
#   'high',
#   'cover',
#   'shadow',
#   'basis',
#   'degree',
#   'logic',
#   'deity',
#   'scholar',
#   'come',
#   'conclusion',
#   'necessary',
#   'justice',
#   'godbased',
#   'men',
#   'unite',
#   'perfect',
#   'man',
#   'perfect',
#   'god',
#   'person',
#   'jesus',
#   'therefore',
#   'also',
#   'child',
#   'born',
#   'holy',
#   'jesus',
#   'born',
#   'man',
#   'originated',
#   'divine',
#   'mystic',
#   'conception',
#   'mother',
#   'full',
#   'divinity',
#   'always',
#   'hidden',
#   'angel',
#   'answered',
#   'holy',
#   'spirit',
#   'come',
#   'upon'],
#  ['wise',
#   'listenedbut',
#   'always',
#   'came',
#   'back',
#   'door',
#   'short',
#   'piece',
#   'omar',
#   'khaijams',
#   'work',
#   'tentmaker',
#   'wise',
#   'wine',
#   'would',
#   'love',
#   'get',
#   'know',
#   'pyski',
#   'young'],
#  ['setting',
#   'controlpanel',
#   'future',
#   'close',
#   'keep',
#   'amount',
#   'power',
#   'work',
#   'window',
#   'display',
#   'setup',
#   'move',
#   'outer',
#   'edge',
#   'screen',
#   'area',
#   'left',
#   'side',
#   'lower',
#   'row',
#   'either',
#   'get',
#   'enough',
#   'firepower',
#   'point',
#   'focus',
#   'destruction',
#   'couple',
#   'time',
#   'yes',
#   'explore',
#   'screen',
#   'see',
#   'find',
#   'anything',
#   'help',
#   'may',
#   'unnecessary',
#   'already',
#   'manage',
#   'business',
#   'without',
#   'advice',
#   'try',
#   'open',
#   'still',
#   'new',
#   'window',
# ...
#   'wonder',
#   'would',
#   'interest',
#   'ideology',
#   'grab',
#   'clothes',
#   'comrade',
#   'position',
#   'socialist',
#   'finland',
#   'leading',
#   'position',
#   'fabricated',
#   'near',
#   'future',
#   'thing',
#   'various',
#   'ministry',
#   'health',
#   'authority',
#   'defence',
#   'agency',
#   'etc',
#   'industry'],
#  ['independent',
#   'air',
#   'direction',
#   'ideology',
#   'according',
#   'latest',
#   'information',
#   'form',
#   'espionage',
#   'cause',
#   'lot',
#   'damage',
#   'addition',
#   'readily',
#   'kept',
#   'quiet',
#   'tried',
#   'deal',
#   'matter',
#   'secretly',
#   'possible',
#   'suffer',
#   'harm',
#   'quietly',
#   'skin',
#   'industrial',
#   'espionage',
#   'much',
#   'greater',
#   'political',
#   'espionage',
#   'embarrassment',
#   'target',
#   'company'],
#  ['dont',
#   'mind',
#   'shes',
#   'teacher',
#   'university',
#   'oulu',
#   'indeed',
#   'time',
#   'year',
#   'learn',
#   'something',
#   'wise',
#   'seem',
#   'really',
#   'need'],
#  ['turn',
#   'secret',
#   'police',
#   'take',
#   'money',
#   'service',
#   'yet',
#   'today',
#   'turn',
#   'liar',
#   'talking',
#   'thing',
#   'longer',
#   'authority',
#   'teacher',
#   'history',
#   'taught',
#   'today',
#   'world',
#   'class',
#   'enemy',
#   'beaten',
#   'take',
#   'advantage',
#   'gullible',
#   'comrade',
#   'morally',
#   'appropriate',
#   'teacher',
#   'young',
#   'people',
#   'person',
#   'eight',
#   'year',
#   'life',
#   'double',
#   'life',
#   'use',
#   'student',
#   'gone',
#   'world',
#   'doctrine',
#   'mug',
#   'begging',
#   'money',
#   'west',
#   'everything',
#   'possible',
#   'typical',
#   'time',
#   'proletariat',
#   'dictatorship',
#   'win',
#   'progressive',
#   'force',
#   'together',
#   'security',
#   'agency',
#   'job',
#   'furthermore'],
#  ['destroyed',
#   'medical',
#   'educational',
#   'archive',
#   'etc',
#   'date',
#   'idf',
#   'announced',
#   'investigating',
#   'six',
#   'soldier',
#   'committed',
#   'unauthorised',
#   'looting',
#   'general',
#   'httpwww',
#   'httpwww',
#   'htm',
#   'httpwww',
#   'idf',
#   'vandal',
#   'thief',
#   'systematically',
#   'vandalised',
#   'premise',
#   'palestinian',
#   'authority',
#   'military',
#   'aimed',
#   'paralyse',
#   'fully',
#   'possible',
#   'palestinian',
#   'authority',
#   'violated',
#   'stole',
#   'computer',
#   'office',
#   'material'],
#  ['opposite',
#   'party',
#   'would',
#   'exactly',
#   'access',
#   'israel',
#   'file',
#   'wonder',
#   'israel',
#   'investigate',
#   'everything',
#   'possible',
#   'find',
#   'exactly',
#   'planned',
#   'terrorism',
#   'would',
#   'every',
#   'country',
#   'similar',
#   'situation',
#   'would',
#   'better',
#   'destruction',
#   'take',
#   'place',
#   'office',
#   'terrorist',
#   'killing',
#   'people',
#   'wouldnt'],
#  ['money',
#   'video',
#   'money',
#   'private',
#   'home',
#   'systematic',
#   'determination',
#   'data',
#   'bank',
#   'matter',
#   'personal',
#   'weakness',
#   'officer',
#   'soliders',
#   'let',
#   'write',
#   'mission',
#   'search',
#   'destroy',
#   'terror',
#   'read',
#   'money'],
#  ['ill',
#   'tell',
#   'whats',
#   'going',
#   'ill',
#   'tell',
#   'whats',
#   'going',
#   'ill',
#   'tell',
#   'whats',
#   'going',
#   'whats',
#   'matter'],
#  ['look',
#   'hard',
#   'knuckle',
#   'didnt',
#   'get',
#   'strength',
#   'kick',
#   'turned',
#   'head',
#   'looked',
#   'guy',
#   'socalled',
#   'madman',
#   'eye',
#   'ive',
#   'lot',
#   'experience',
#   'really',
#   'hard',
#   'place',
#   'avoid',
#   'guy',
#   'around',
#   'far',
#   'away',
#   'laughed',
#   'boy',
#   'went',
#   'away',
#   'got',
#   'cornered',
#   'guy',
#   'kicked',
#   'head',
#   'worked',
#   'year',
#   'get',
#   'little',
#   'bit',
#   'hand',
#   'take',
#   'revenge',
#   'kind',
#   'thing',
#   'going',
#   'around',
#   'long',
#   'way',
#   'maybe',
#   'get',
#   'couple',
#   'friend',
#   'shed',
#   'thing',
#   'happened',
#   'cant',
#   'seen'],
#  ['there',
#   'lot',
#   'people',
#   'would',
#   'happy',
#   'dont',
#   'think',
#   'black',
#   'wouldnt',
#   'cheap',
#   'rather',
#   'around',
#   'sometimes',
#   'itd',
#   'come',
#   'know',
#   'couple',
#   'familiar',
#   'russian',
#   'couple',
#   'hell',
#   'angel',
#   'could',
#   'feel',
#   'like',
#   'dont',
#   'think',
#   'worth',
#   'looking',
#   'like',
#   'get',
#   'loose',
#   'one',
#   'sure',
#   'ill',
#   'get',
#   'look',
#   'surveillance',
#   'tape',
#   'even',
#   'didnt',
#   'look',
#   'like',
#   'itt',
#   'look',
#   'like',
#   'going',
#   'guess',
#   'got',
#   'away',
#   'could',
#   'get',
#   'away',
#   'didnt',
#   'get',
#   'away'],
#  ['next',
#   'time',
#   'shoot',
#   'top',
#   'get',
#   'pepper',
#   'spray',
#   'something',
#   'like',
#   'hardly',
#   'sober'],
#  ['time',
#   'maybe',
#   'mild',
#   'one',
#   'public',
#   'prosecutor',
#   'job',
#   'really',
#   'shitty',
#   'job',
#   'youll',
#   'court',
#   'year',
#   'time',
#   'youll',
#   'see',
#   'guy',
#   'travel',
#   'pain',
#   'pain',
#   'pain',
#   'youll',
#   'able',
#   'claim',
#   'compensation',
#   'medical',
#   'expense',
#   'wont',
#   'matter',
#   'practice',
#   'youll',
#   'able',
#   'apply',
#   'restraining',
#   'judge',
#   'end',
#   'game',
#   'determine',
#   'otherwise',
#   'cant',
#   'say',
#   'anything',
#   'report',
#   'matter',
#   'police',
#   'considered',
#   'prosecutor',
#   'want',
#   'press',
#   'charge',
#   'cant',
#   'make',
#   'much',
#   'theret',
#   'much',
#   'protection',
#   'police',
#   'justice',
#   'case',
#   'need',
#   'doctor',
#   'certificate',
#   'injury',
#   'wouldnt',
#   'bad',
#   'witness',
#   'happened',
#   'youve',
#   'assaulted',
#   'public',
#   'place',
#   'youll',
#   'completely'],
#  ['threshold',
#   'pain',
#   'may',
#   'numb',
#   'gas',
#   'spray',
#   'effect',
#   'red',
#   'garment',
#   'bull',
#   'perhaps',
#   'personal',
#   'alarm',
#   'might',
#   'useful',
#   'keep',
#   'involved',
#   'best',
#   'thing',
#   'would',
#   'move',
#   'around',
#   'map',
#   'friend',
#   'take',
#   'foot',
#   'shout',
#   'devilishly',
#   'draw',
#   'attention',
#   'people',
#   'problem',
#   'use',
#   'handgun',
#   'gas',
#   'spray',
#   'reemerge',
#   'similar',
#   'situation',
#   'use',
#   'weapon',
#   'example',
#   'assault',
#   'bodily',
#   'injury',
#   'necessary',
#   'course',
#   'possession',
#   'first',
#   'influence',
#   'drug',
#   'killing',
#   'gas',
#   'spray',
#   'would',
#   'pawboard',
#   'exaggerating',
#   'emergency',
#   'guard',
#   'depending',
#   'situation'],
#  ['shortened', 'selfdefence', 'criminalized', 'finland'],
#  ['dont',
#   'think',
#   'going',
#   'bad',
#   'think',
#   'going',
#   'get',
#   'little',
#   'bit',
#   'even',
#   'dont',
#   'think',
#   'going',
#   'bad',
#   'guy',
#   'ought',
#   'able',
#   'get',
#   'line'],
#  ['youll',
#   'probably',
#   'try',
#   'settle',
#   'even',
#   'case',
#   'doesnt',
#   'youll',
#   'hardly',
#   'even',
#   'involved',
#   'investigation',
#   'least',
#   'next',
#   'time',
#   'youll',
#   'find',
#   'evidence',
#   'guy',
#   'complained',
#   'might',
#   'bit',
#   'question',
#   'boy',
#   'father',
#   'police',
#   'officer',
#   'always',
#   'leave',
#   'request',
#   'investigation',
#   'happens',
#   'well',
#   'going',
#   'cheap',
#   'start',
#   'taking',
#   'case',
#   'forward',
#   'want',
#   'move',
#   'forward',
#   'youd',
#   'like',
#   'report',
#   'police',
#   'might',
#   'protect',
#   'son',
#   'investigation',
#   'carried',
#   'painier',
#   'stand',
#   'way'],
#  ['funny',
#   'case',
#   'reflection',
#   'way',
#   'masa',
#   'took',
#   'neighbor',
#   'tire',
#   'garbage',
#   'explanation',
#   'style',
#   'seems',
#   'similar',
#   'liked',
#   'rubber',
#   'conversation',
#   'better'],
#  ['probably',
#   'something',
#   'get',
#   'trouble',
#   'done',
#   'also',
#   'say',
#   'thing',
#   'kind',
#   'interesting',
#   'mind',
#   'would',
#   'blackmail',
#   'nice',
#   'decision',
#   'boy',
#   'one',
#   'found',
#   'tire',
#   'let',
#   'blackmail',
#   'seems',
#   'reasonable',
#   'doubt',
#   'isnt',
#   'true',
#   'youre',
#   'wrong',
#   'yeah'],
#  ['abroad', 'dont', 'get', 'nose', 'easily'],
#  ['bilge',
#   'bilge',
#   'bilest',
#   'bilest',
#   'billy',
#   'bilest',
#   'bilest',
#   'billy',
#   'billy',
#   'bilest',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilest',
#   'bilge',
#   'bilge',
#   'daniel',
#   'took',
#   'away',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilest',
#   'bilest',
#   'bilest'],
#  ['youre',
#   'even',
#   'naive',
#   'stupid',
#   'expected',
#   'really',
#   'believe',
#   'urban',
#   'legend'],
#  ['mikkos', 'leaving', 'body'],
#  ['life', 'jesus', 'christ', 'yesterday', 'today', 'forever'],
#  ['christianity',
#   'saying',
#   'different',
#   'magic',
#   'mystic',
#   'strong',
#   'part',
#   'johan',
#   'steamheads',
#   'tried',
#   'refresh',
#   'boy',
#   'drowned',
#   'nokia',
#   'dont',
#   'know',
#   'one',
#   'could',
#   'expect',
#   'contributed',
#   'nnekas',
#   'stable',
#   'faith',
#   'daniel',
#   'come',
#   'life',
#   'whole',
#   'idea',
#   'seems',
#   'resisting',
#   'say',
#   'luckily',
#   'finland',
#   'trying',
#   'overturn',
#   'law',
#   'nature',
#   'original',
#   'religion',
#   'africa'],
#  ['example',
#   'medium',
#   'urban',
#   'legend',
#   'admissible',
#   'evidence',
#   'would',
#   'believe',
#   'awakening',
#   'dead',
#   'would',
#   'greater',
#   'interest',
#   'medium',
#   'evidence',
#   'story',
#   'mikko',
#   'death',
#   'certificate',
#   'breathed',
#   'old',
#   'man',
#   'story',
#   'given',
#   'greater',
#   'publicity',
#   'yes'],
#  ['terrible',
#   'time',
#   'different',
#   'alarm',
#   'placed',
#   'coffin',
#   'express',
#   'accident',
#   'body',
#   'dead',
#   'simply',
#   'medical',
#   'science',
#   'could',
#   'accurately',
#   'detect',
#   'death',
#   'wise',
#   'many',
#   'case',
#   'man',
#   'died',
#   'judgment',
#   'wrong'],
#  ['loan',
#   'olympus',
#   'camedia',
#   'cant',
#   'stupid',
#   'move',
#   'picture',
#   'machine',
#   'someone',
#   'give',
#   'advice',
#   'detail',
#   'quickly',
#   'really',
#   'grateful',
#   'even',
#   'little',
#   'tip',
#   'could',
#   'help',
#   'transfer',
#   'picture',
#   'take',
#   'place'],
#  ['power',
#   'camera',
#   'install',
#   'end',
#   'cable',
#   'camera',
#   'cfm',
#   'result',
#   'put',
#   'cable',
#   'machine',
#   'machine',
#   'first',
#   'install',
#   'program',
#   'open',
#   'program',
#   'image',
#   'appear',
#   'monitor',
#   'download',
#   'program',
#   'yet',
#   'httpcf',
#   'olympuseuropa'],
#  ['need',
#   'image',
#   'processing',
#   'feature',
#   'easy',
#   'download',
#   'image',
#   'digital',
#   'camera',
#   'computer',
#   'good',
#   'free',
#   'download',
#   'software',
#   'exists'],
#  ['get',
#   'driver',
#   'camera',
#   'home',
#   'page',
#   'tucows',
#   'get',
#   'downloaded',
#   'manufacturer',
#   'website',
#   'www',
#   'come',
#   'camera',
#   'window',
#   'also',
#   'recognizes',
#   'device',
#   'downloads',
#   'driver',
#   'camera',
#   'attached',
#   'machine',
#   'top',
#   'computer',
#   'good',
#   'convenient',
#   'viewing',
#   'program',
#   'irfanview',
#   'message'],
#  ['compact',
#   'flash',
#   'smartmedia',
#   'also',
#   'others',
#   'resource',
#   'management',
#   'drag',
#   'desired',
#   'image',
#   'machine',
#   'hard',
#   'drive',
#   'fit',
#   'different',
#   'card',
#   'jack',
#   'card',
#   'appears',
#   'hard',
#   'drive',
#   'easy',
#   'buy',
#   'card',
#   'reader',
#   'hybrid',
#   'reader'],
#  ['face',
#   'face',
#   'bof',
#   'unemployment',
#   'take',
#   'skill',
#   'arrogant',
#   'dare',
#   'claim',
#   'lazy',
#   'unemployed',
#   'people',
#   'bother',
#   'look',
#   'work',
#   'see',
#   'www',
#   'imf',
#   'report',
#   'pdfformaths',
#   'web',
#   'page',
#   'tyovoima',
#   'office',
#   'dare'],
#  ['head',
#   'delegation',
#   'finland',
#   'told',
#   'information',
#   'conference',
#   'imf',
#   'published',
#   'annual',
#   'country',
#   'report',
#   'finland',
#   'imf',
#   'concerned',
#   'rise',
#   'public',
#   'expenditure',
#   'finland',
#   'year',
#   'next',
#   'year',
#   'quickly',
#   'robert',
#   'feldman',
#   'monday',
#   'exacerbate',
#   'fiscal',
#   'policy',
#   'increase',
#   'expenditure',
#   'finland',
#   'return',
#   'strict',
#   'spending',
#   'policy',
#   'course',
#   'tax',
#   'reduction',
#   'mind',
#   'imf'],
#  ['part',
#   'statistic',
#   'statistic',
#   'statistic',
#   'development',
#   'cooperation',
#   'finland',
#   'finlandthe',
#   'article',
#   'consultation',
#   'written',
#   'copy',
#   'mail',
#   'mission',
#   'confucing',
#   'report',
#   'finland',
#   'imf',
#   'email',
#   'notification',
#   'subscribe',
#   'modify',
#   'subscription',
#   'discribes',
#   'preliminary',
#   'finding',
#   'imf',
#   'staff',
#   'understanding',
#   'certain',
#   'mission',
#   'official',
#   'staff',
#   'visit',
#   'member',
#   'country',
#   'mission',
#   'undertake',
#   'part',
#   'regular',
#   'usually',
#   'annual',
#   'consultation',
#   'article',
#   'imf',
#   'article',
#   'agreement',
#   'context',
#   'request',
#   'use',
#   'imf',
#   'resource',
#   'imf'],
#  ['exist',
#   'afford',
#   'phone',
#   'call',
#   'job',
#   'heh',
#   'imf',
#   'say',
#   'rich',
#   'unemployed',
#   'person',
#   'bother',
#   'look',
#   'job',
#   'rent',
#   'le',
#   'euro'],
#  ['take', 'labour', 'abroad', 'hehehe'],
#  ['poor',
#   'old',
#   'people',
#   'dying',
#   'young',
#   'likely',
#   'remain',
#   'rich',
#   'move',
#   'abroad',
#   'demand',
#   'fall',
#   'retire',
#   'le',
#   'worker',
#   'needed',
#   'production',
#   'product',
#   'service',
#   'unemployment',
#   'increasing',
#   'recession',
#   'deepening',
#   'country',
#   'bankrupting'],
#  ['true', 'working', 'party', 'sprayed'],
#  ['sdp',
#   'party',
#   'pyrists',
#   'even',
#   'short',
#   'term',
#   'child',
#   'care',
#   'long',
#   'accumulate',
#   'much',
#   'pocket',
#   'nothing',
#   'good',
#   'say',
#   'others',
#   'well',
#   'others',
#   'government',
#   'interested',
#   'power',
#   'personal',
#   'merit'],
#  ['cause',
#   'damage',
#   'spending',
#   'money',
#   'several',
#   'hundred',
#   'time',
#   'pay',
#   'even',
#   'several',
#   'hundred',
#   'time',
#   'superior',
#   'several',
#   'thousand',
#   'time',
#   'worker',
#   'state',
#   'municipality',
#   'even',
#   'work',
#   'much',
#   'unemployed'],
#  ['poor',
#   'wage',
#   'often',
#   'absurd',
#   'workload',
#   'true',
#   'worker',
#   'actually',
#   'working',
#   'result',
#   'municipal',
#   'consultant',
#   'expert',
#   'run',
#   'project',
#   'often',
#   'employ',
#   'many',
#   'people',
#   'long',
#   'time',
#   'tasan',
#   'yes',
#   'state',
#   'municipality'],
#  ['example',
#   'lot',
#   'work',
#   'municipality',
#   'need',
#   'done',
#   'distribution',
#   'social',
#   'security',
#   'money',
#   'everyone',
#   'exception',
#   'care',
#   'nurse',
#   'elderly',
#   'need',
#   'worker',
#   'visit',
#   'month',
#   'municipality',
#   'jep',
#   'connection',
#   'housing',
#   'allowance'],
#  ['real',
#   'unemployment',
#   'double',
#   'official',
#   'lie',
#   'would',
#   'paid',
#   'would',
#   'paid',
#   'unemployed',
#   'accordance',
#   'imf',
#   'financial',
#   'policy',
#   'also',
#   'taken',
#   'away',
#   'course',
#   'monetary',
#   'fund',
#   'forced',
#   'training',
#   'unemployed',
#   'emptyday',
#   'school',
#   'teacher',
#   'cant',
#   'stay',
#   'sober',
#   'hour',
#   'instruction',
#   'owner',
#   'make',
#   'large',
#   'sum',
#   'state',
#   'money',
#   'pocket',
#   'unpaid',
#   'forced',
#   'labour'],
#  ['part',
#   'statistic',
#   'statistic',
#   'statistic',
#   'development',
#   'cooperation',
#   'finland',
#   'finlandthe',
#   'article',
#   'consultation',
#   'written',
#   'copy',
#   'mail',
#   'mission',
#   'confucing',
#   'report',
#   'finland',
#   'imf',
#   'email',
#   'notification',
#   'subscribe',
#   'modify',
#   'subscription',
#   'discribes',
#   'preliminary',
#   'finding',
#   'imf',
#   'staff',
#   'understanding',
#   'certain',
#   'mission',
#   'official',
#   'staff',
#   'visit',
#   'member',
#   'country',
#   'mission',
#   'undertake',
#   'part',
#   'regular',
#   'usually',
#   'annual',
#   'consultation',
#   'article',
#   'imf',
#   'article',
#   'agreement',
#   'context',
#   'request',
#   'use',
#   'imf',
#   'resource',
#   'imf'],
#  ['sudden',
#   'forgotten',
#   'without',
#   'getting',
#   'increase',
#   'pension',
#   'interest',
#   'follow',
#   'missing',
#   'part',
#   'putter',
#   'emerges',
#   'lahti',
#   'however',
#   'wonderful',
#   'saving',
#   'line',
#   'necessary',
#   'benefit',
#   'law',
#   'given',
#   'denied',
#   'one',
#   'watch',
#   'care',
#   'city',
#   'save',
#   'completely',
#   'ridiculous',
#   'arbitrariness',
#   'based',
#   'social',
#   'benefit',
#   'faceass',
#   'licking',
#   'coefficient',
#   'example'],
#  ['would',
#   'made',
#   'would',
#   'paid',
#   'according',
#   'international',
#   'monetary',
#   'school',
#   'according',
#   'imf',
#   'financial',
#   'policy',
#   'finland',
#   'going',
#   'sucking',
#   'away',
#   'course',
#   'current',
#   'financial',
#   'year',
#   'increase',
#   'amount',
#   'money',
#   'spent',
#   'imf',
#   'would',
#   'reported',
#   'huge',
#   'increase',
#   'amount',
#   'money',
#   'spent',
#   'government',
#   'pocket',
#   'unpaid',
#   'forced',
#   'labour'],
#  ...]

# %%
stop_words=stopwords.words('english')
stop_words.append('s')
stop_words.append('ve')
stop_words.append('re')
stop_words.append('m')
print(stop_words)
# remove stopwords
def remove_stopwords(texts):
    return [[word for word in text if word not in stop_words] for text in texts]

data_words_nostops=remove_stopwords(data_words)
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't", 's', 've', 're', 'm']

# %%
len(data_words_nostops)
# Out:
# 273304

# %%
data_words_nostops
# Out:
# [['important',
#   'piece',
#   'evidence',
#   'front',
#   'gate',
#   'fall',
#   'depth',
#   'sea',
#   'helicopter',
#   'carried',
#   'question',
#   'estonia',
#   'isnt',
#   'estonia',
#   'ship',
#   'world',
#   'immediately',
#   'held',
#   'peace',
#   'grave',
#   'border',
#   'guard',
#   'prevent',
#   'investigation',
#   'independent',
#   'company',
#   'area',
#   'protected',
#   'socalled',
#   'burial',
#   'peace',
#   'repeatedly',
#   'invoked',
#   'even',
#   'though',
#   'relative',
#   'wanted',
#   'study',
#   'matter',
#   'one',
#   'theory',
#   'sinking',
#   'even',
#   'though',
#   'controversial',
#   'flashed',
#   'public',
#   'domain',
#   'truth',
#   'didnt',
#   'anyone',
#   'get',
#   'saved',
#   'bridge',
#   'command',
#   'even',
#   'though',
#   'advantage',
#   'image',
#   'given',
#   'public',
#   'couple',
#   'stormy',
#   'image'],
#  ['think',
#   'thing',
#   'first',
#   'kin',
#   'demanded',
#   'sepulchre',
#   'would',
#   'rejected',
#   'independent',
#   'picture',
#   'bottom',
#   'wreck',
#   'taken',
#   'lightning',
#   'light',
#   'fear',
#   'scuba',
#   'dive',
#   'invasion',
#   'wreckage',
#   'would',
#   'able',
#   'save',
#   'accident',
#   'first',
#   'investigating',
#   'authority',
#   'television',
#   'company',
#   'dont',
#   'wonder',
#   'gate',
#   'raised',
#   'thing',
#   'stormy',
#   'thing',
#   'thing',
#   'stormy',
#   'thing',
#   'small',
#   'group',
#   'would',
#   'keep',
#   'sound',
#   'suggest',
#   'amazing',
#   'theory',
#   'thing',
#   'argument',
#   'thing',
#   'stormy',
#   'thing',
#   'many',
#   'night',
#   'excited',
#   'describe',
#   'would',
#   'still',
#   'continue',
#   'part',
#   'addition'],
#  ['bow',
#   'gate',
#   'sarana',
#   'strange',
#   'coincidence',
#   'fell',
#   'research',
#   'helicopter',
#   'deep',
#   'sea',
#   'couldnt',
#   'saved',
#   'reason',
#   'thing',
#   'storm',
#   'world',
#   'reason',
#   'ordeal',
#   'reason',
#   'ordeal',
#   'loved',
#   'one',
#   'wanted',
#   'proper',
#   'burial',
#   'peace',
#   'per',
#   'cent',
#   'want',
#   'proper',
#   'study',
#   'wanted',
#   'first',
#   'body',
#   'hyly',
#   'lifting',
#   'holding',
#   'small',
#   'river',
#   'actually',
#   'per',
#   'caput',
#   'look',
#   'leaf',
#   'without',
#   'chewing',
#   'touch',
#   'want',
#   'believe',
#   'mus',
#   'wanted',
#   'believe',
#   'grave',
#   'peace',
#   'several',
#   'oath',
#   'staff',
#   'tell',
#   'reason',
#   'thing',
#   'storm',
#   'reason',
#   'thing',
#   'storm',
#   'middle',
#   'year',
#   'didnt',
#   'give',
#   'good',
#   'picture',
#   'happened'],
#  ['ill', 'tell', 'whats', 'going', 'ill', 'tell', 'whatll', 'news'],
#  ['let',
#   'cause',
#   'sinking',
#   'ship',
#   'lifted',
#   'away',
#   'wreckage',
#   'left',
#   'sea'],
#  ['therell',
#   'lot',
#   'ill',
#   'bet',
#   'youll',
#   'bet',
#   'concrete',
#   'thats',
#   'going',
#   'look',
#   'ill',
#   'lot',
#   'therell',
#   'lot',
#   'said',
#   'ill',
#   'tell',
#   'ill',
#   'bet',
#   'youll',
#   'lot',
#   'itll',
#   'lot',
#   'ill',
#   'bet',
#   'youll',
#   'bet'],
#  ['reason',
#   'ill',
#   'bet',
#   'nothing',
#   'else',
#   'ill',
#   'bet',
#   'therell',
#   'ill',
#   'bet',
#   'therell',
#   'lot',
#   'thing',
#   'ill',
#   'bet',
#   'therell',
#   'ill',
#   'bet',
#   'therell',
#   'lot',
#   'thing',
#   'ill',
#   'bet',
#   'therell',
#   'lot',
#   'thing',
#   'ill',
#   'bet',
#   'therell',
#   'ill',
#   'bet',
#   'therell',
#   'ill',
#   'bet',
#   'therell',
#   'ill',
#   'bet',
#   'therell',
#   'ill',
#   'betll',
#   'bet',
#   'therell',
#   'ill',
#   'bet',
#   'ill',
#   'bet',
#   'therell',
#   'lot',
#   'ill',
#   'bet'],
#  ['whats', 'big', 'deal'],
#  ['reason',
#   'going',
#   'lot',
#   'thats',
#   'going',
#   'happen',
#   'like',
#   'thats',
#   'going',
#   'happen',
#   'reason',
#   'going',
#   'lot'],
#  ['look',
#   'look',
#   'road',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'much',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'going',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'look',
#   'going',
#   'look',
#   'whats',
#   'going',
#   'front',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'whats',
#   'going',
#   'look',
#   'going',
#   'front',
#   'short',
#   'ago',
#   'thats',
#   'look',
#   'bit',
#   'accident',
#   'look',
#   'look',
#   'road'],
#  ['dont',
#   'know',
#   'lehtola',
#   'missed',
#   'fact',
#   'estonia',
#   'built',
#   'iron',
#   'filled',
#   'water',
#   'model',
#   'carpenter',
#   'wood',
#   'soaking',
#   'water',
#   'long',
#   'time',
#   'went',
#   'bottom',
#   'lehtola',
#   'told',
#   'made',
#   'model',
#   'wood',
#   'estonia',
#   'prove',
#   'suspicion',
#   'reason',
#   'estonia',
#   'sinking',
#   'least',
#   'dont',
#   'believe',
#   'trust',
#   'result',
#   'research',
#   'group',
#   'lehtola',
#   'leader',
#   'old',
#   'man',
#   'full',
#   'toilet'],
#  ['give',
#   'right',
#   'idea',
#   'perspective',
#   'might',
#   'want',
#   'vtt',
#   'laugh',
#   'theyre',
#   'going',
#   'ashamed',
#   'planning',
#   'research',
#   'also',
#   'excellent',
#   'idea',
#   'knock',
#   'everyone',
#   'doesnt',
#   'like',
#   'face'],
#  ['would',
#   'point',
#   'accident',
#   'would',
#   'result',
#   'accident',
#   'read',
#   'read',
#   'exciting',
#   'thing',
#   'believe',
#   'however',
#   'many',
#   'rabe',
#   'activity',
#   'following',
#   'small',
#   'boat',
#   'think',
#   'telakka',
#   'official',
#   'matter',
#   'million',
#   'people',
#   'already',
#   'read',
#   'perhaps',
#   'want',
#   'hide',
#   'would',
#   'result',
#   'would',
#   'happened',
#   'panic',
#   'point',
#   'sinking',
#   'estonia',
#   'nothing',
#   'ashamed',
#   'lie',
#   'wall',
#   'would',
#   'point',
#   'would',
#   'result',
#   'would',
#   'happened',
#   'tour',
#   'trip',
#   'away',
#   'one',
#   'far',
#   'made',
#   'guess',
#   'various',
#   'interest',
#   'group',
#   'evidence',
#   'would',
#   'investigated',
#   'already',
#   'germany',
#   'official',
#   'position'],
#  ['etc',
#   'believe',
#   'explanation',
#   'much',
#   'simpler',
#   'could',
#   'short',
#   'time',
#   'could',
#   'developed',
#   'decaying',
#   'gas',
#   'odor',
#   'explosion',
#   'silenced',
#   'way',
#   'bomber',
#   'fence',
#   'bomber',
#   'car',
#   'still',
#   'way',
#   'could',
#   'even',
#   'something',
#   'would',
#   'happen',
#   'thing',
#   'bomber',
#   'nothing',
#   'look',
#   'several',
#   'passenger',
#   'crew',
#   'member',
#   'saved',
#   'mentioned',
#   'psychological',
#   'crisis',
#   'group',
#   'sinking',
#   'spot',
#   'dark',
#   'smell',
#   'terrorism',
#   'terrorist',
#   'even',
#   'single',
#   'madman',
#   'blew',
#   'bomb',
#   'car',
#   'deck',
#   'many',
#   'people',
#   'claimed',
#   'nuclear',
#   'weapon',
#   'plutonium',
#   'agent',
#   'large',
#   'drug',
#   'load',
#   'sunk'],
#  ['nothing',
#   'look',
#   'saying',
#   'nothing',
#   'look',
#   'big',
#   'deal',
#   'whats',
#   'going',
#   'mean',
#   'million',
#   'people',
#   'would',
#   'come',
#   'long',
#   'time',
#   'evidence',
#   'far',
#   'point',
#   'view',
#   'would',
#   'investigated',
#   'sure',
#   'whats',
#   'going',
#   'big',
#   'deal',
#   'whats',
#   'going',
#   'rabens',
#   'activity',
#   'followed',
#   'water',
#   'sure',
#   'whats',
#   'going',
#   'whats',
#   'going',
#   'already',
#   'million',
#   'people',
#   'read',
#   'big',
#   'deal',
#   'maybe',
#   'theyre',
#   'wanting',
#   'keep',
#   'matter',
#   'holding'],
#  ['estonia',
#   'file',
#   'report',
#   'downloaded',
#   'pdf',
#   'finnish',
#   'safety',
#   'investigation',
#   'authority',
#   'website',
#   'attachment',
#   'missing',
#   'www',
#   'unfortunately',
#   'also',
#   'obtained',
#   'location',
#   'ask'],
#  ['charge',
#   'commission',
#   'remainder',
#   'uno',
#   'laur',
#   'finnish',
#   'member',
#   'commission',
#   'kari',
#   'lehtola',
#   'director',
#   'accident',
#   'investigation',
#   'centre',
#   'whose',
#   'madness',
#   'cannot',
#   'say',
#   'anything',
#   'estonian',
#   'initially',
#   'andi',
#   'meister',
#   'second'],
#  ['telling',
#   'youm',
#   'telling',
#   'telling',
#   'youm',
#   'telling',
#   'youm',
#   'telling',
#   'itm',
#   'telling',
#   'itre',
#   'gonna',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'youre',
#   'gonna',
#   'itre',
#   'gonna',
#   'something',
#   'gonna',
#   'gonna',
#   'gonna',
#   'something',
#   'thats',
#   'gonna',
#   'something',
#   'thats',
#   'gonna',
#   'gonna',
#   'something',
#   'thats',
#   'gonna',
#   'something',
#   'thats',
#   'gonna',
#   'something',
#   'thats',
#   'gonna',
#   'gonna',
#   'going',
#   'happen',
#   'something',
#   'something',
#   'something',
#   'thats',
#   'going',
#   'happen',
#   'going',
#   'get',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'something',
#   'else',
#   'going',
#   'something',
#   'thats',
#   'going',
#   'something',
#   'thats',
#   'going',
#   'something',
#   'thats',
#   'going',
#   'something',
#   'something',
#   'something',
#   'else',
#   'going',
#   'going',
#   'going',
#   'something',
#   'something',
#   'something',
#   'going',
#   'something',
#   'thing',
#   'saying',
#   'telling',
#   'telling',
#   'telling'],
#  ['evidence',
#   'found',
#   'sense',
#   'estonia',
#   'leaf',
#   'sea',
#   'pressure',
#   'left',
#   'behind',
#   'ramp',
#   'broke',
#   'bow',
#   'gate',
#   'behind',
#   'smell',
#   'brittle',
#   'stuff',
#   'also',
#   'worth',
#   'noting',
#   'experience',
#   'narrator',
#   'brittle',
#   'smell',
#   'ship',
#   'corsts',
#   'still',
#   'long',
#   'main',
#   'engine',
#   'stopped',
#   'really',
#   'strange',
#   'bomb',
#   'ive',
#   'said',
#   'hand',
#   'knowledge',
#   'youth',
#   'year',
#   'came',
#   'smell',
#   'smelled',
#   'corstene',
#   'painting',
#   'blast',
#   'vest',
#   'manual',
#   'lock',
#   'left',
#   'behind',
#   'would',
#   'blown',
#   'keulaport',
#   'closed',
#   'left',
#   'behind',
#   'hydraulics',
#   'locking',
#   'hook'],
#  ['good', 'tip', 'interested', 'people'],
#  ['telling',
#   'something',
#   'telling',
#   'something',
#   'else',
#   'telling',
#   'something',
#   'else',
#   'telling',
#   'something',
#   'else',
#   'telling',
#   'something',
#   'telling',
#   'something',
#   'telling',
#   'something',
#   'else',
#   'telling',
#   'something',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'telling',
#   'telling'],
#  ['reference',
#   'evidence',
#   'thing',
#   'could',
#   'different',
#   'report',
#   'youre',
#   'going',
#   'youre',
#   'going',
#   'long',
#   'time',
#   'basic',
#   'concept',
#   'investigation',
#   'court',
#   'based',
#   'event',
#   'reliably',
#   'explained',
#   'lot',
#   'report',
#   'contrast',
#   'theory',
#   'thrown',
#   'way',
#   'youve',
#   'read',
#   'report',
#   'already',
#   'mentioned',
#   'strange',
#   'bomb',
#   'breaking',
#   'front',
#   'door',
#   'ramp',
#   'front',
#   'komporomist',
#   'report',
#   'dont',
#   'comment',
#   'staff',
#   'say',
#   'comment',
#   'nice',
#   'laugh',
#   'first',
#   'look',
#   'guilty',
#   'youre',
#   'looking',
#   'something'],
#  ['believe',
#   'organization',
#   'behind',
#   'thats',
#   'taken',
#   'reference',
#   'evidence',
#   'could',
#   'different',
#   'report',
#   'dont',
#   'sink',
#   'truck',
#   'stamp',
#   'participant',
#   'secretor',
#   'information',
#   'lot',
#   'done',
#   'long',
#   'time',
#   'indiscretion',
#   'youre',
#   'looking',
#   'guilty',
#   'youre',
#   'looking',
#   'guilty',
#   'youre',
#   'today',
#   'theyve',
#   'sunk',
#   'inconceivable',
#   'reason',
#   'hey',
#   'boy',
#   'yes',
#   'evidence',
#   'report',
#   'tiij'],
#  ['wonder',
#   'many',
#   'explosive',
#   'use',
#   'sulfur',
#   'make',
#   'bow',
#   'port',
#   'fail',
#   'truckloads',
#   'black',
#   'powder',
#   'driven',
#   'car',
#   'deck',
#   'smell',
#   'rotten',
#   'egg',
#   'theory',
#   'suggests',
#   'bowgate',
#   'blown',
#   'black',
#   'powder'],
#  ['yes', 'dirt', 'thrown', 'side', 'way', 'around', 'win'],
#  ['thing',
#   'ostststre',
#   'ostrich',
#   'thing',
#   'ostrich',
#   'thing',
#   'thing',
#   'ostrich',
#   'therest',
#   'ost',
#   'thing',
#   'thing',
#   'ostrich',
#   'thing',
#   'ostrich',
#   'ostrich',
#   'thing',
#   'ostrich',
#   'thing',
#   'ostrich',
#   'thing'],
#  ['ill', 'tell', 'ill', 'tell', 'ill', 'tell', 'ill', 'tell', 'ill', 'tell'],
#  ['car',
#   'thief',
#   'speed',
#   'restriction',
#   'calculated',
#   'tolerance',
#   'tightened',
#   'need',
#   'car',
#   'model',
#   'speeding',
#   'driver',
#   'able',
#   'catch',
#   'lot',
#   'drunk',
#   'driver',
#   'majority',
#   'road',
#   'user',
#   'think',
#   'meaningful',
#   'anymore',
#   'honest',
#   'control',
#   'preferably',
#   'visibly',
#   'another',
#   'thing',
#   'automatic',
#   'control',
#   'cashing',
#   'automatic',
#   'speed',
#   'control',
#   'contribute',
#   'road',
#   'safety',
#   'extent',
#   'acceptable',
#   'noticed',
#   'police',
#   'even',
#   'look',
#   'reasonable',
#   'speed',
#   'see',
#   'situation',
#   'allowing',
#   'without',
#   'risk',
#   'remember',
#   'counterfeit',
#   'dollar',
#   'thing',
#   'went',
#   'year',
#   'ago',
#   'villain',
#   'ran',
#   'radar',
#   'car',
#   'load',
#   'fake',
#   'police',
#   'enough',
#   'fine',
#   'large',
#   'number',
#   'road',
#   'user',
#   'personally'],
#  ['teach',
#   'child',
#   'walk',
#   'traffic',
#   'light',
#   'anymore',
#   'automonitoring',
#   'increased',
#   'urban',
#   'area',
#   'road',
#   'especially',
#   'necessary',
#   'useful',
#   'would',
#   'traffic',
#   'light',
#   'driving',
#   'red',
#   'become',
#   'way',
#   'country'],
#  ['risk',
#   'speeding',
#   'ticket',
#   'minimized',
#   'course',
#   'automatic',
#   'speed',
#   'control',
#   'addition',
#   'dangerous',
#   'unnecessary',
#   'constant',
#   'speed',
#   'control',
#   'safe',
#   'well',
#   'run',
#   'legal',
#   'every',
#   'pas',
#   'requires',
#   'speeding',
#   'succeed',
#   'safely',
#   'unnecessary',
#   'many',
#   'marmattatas',
#   'fact',
#   'range',
#   'run',
#   'illegal'],
#  ['afford',
#   'drive',
#   'speeding',
#   'would',
#   'lead',
#   'fine',
#   'kmh',
#   'speed',
#   'limit',
#   'nobody',
#   'drive',
#   'kmh',
#   'time',
#   'difference',
#   'distance',
#   'minute',
#   'exactly',
#   'time',
#   'kmh',
#   'kmh',
#   'really',
#   'understand',
#   'current',
#   'speed',
#   'control',
#   'tax',
#   'burden',
#   'others',
#   'reduced',
#   'accordingly',
#   'even',
#   'small',
#   'speeding',
#   'fuel',
#   'saved',
#   'cost',
#   'safer',
#   'everyone',
#   'studied',
#   'zero',
#   'tolerance',
#   'afford',
#   'pay',
#   'fine'],
#  ['even',
#   'though',
#   'dont',
#   'radar',
#   'detector',
#   'even',
#   'scanner',
#   'otherwise',
#   'know',
#   'way',
#   'cop',
#   'cost',
#   'nice',
#   'feeling',
#   'get',
#   'little',
#   'bit',
#   'dim',
#   'camera',
#   'tear',
#   'slowly',
#   'case',
#   'cross',
#   'get',
#   'least',
#   'kmh',
#   'high',
#   'speed',
#   'see',
#   'red',
#   'lower',
#   'lens',
#   'know',
#   'camera',
#   'place',
#   'change',
#   'place',
#   'least',
#   'expense',
#   'surveillance',
#   'dont',
#   'get',
#   'many',
#   'speeding',
#   'ticket',
#   'cant',
#   'easily',
#   'let',
#   'dont',
#   'drive',
#   'much',
#   'away',
#   'know',
#   'camera',
#   'could',
#   'add',
#   'camera',
#   'every',
#   'case'],
#  ['real', 'apig', 'expert', 'funny', 'thing'],
#  ['nothing',
#   'else',
#   'wheel',
#   'look',
#   'meter',
#   'youre',
#   'ride',
#   'force',
#   'look',
#   'meter',
#   'scream',
#   'start',
#   'going',
#   'limit',
#   'mean'],
#  ['comment', 'fuck', 'youll', 'get', 'kicked', 'walk'],
#  ['pay',
#   'driver',
#   'made',
#   'commitment',
#   'traffic',
#   'offence',
#   'signing',
#   'licence',
#   'application',
#   'got',
#   'automatic',
#   'fine',
#   'police',
#   'officer',
#   'every',
#   'villain',
#   'long',
#   'demand',
#   'harm',
#   'would',
#   'automatic',
#   'control',
#   'money',
#   'probably',
#   'bad',
#   'guy',
#   'would',
#   'caught',
#   'faster',
#   'speed',
#   'control',
#   'much',
#   'know',
#   'automatic',
#   'speed',
#   'control',
#   'improve',
#   'road',
#   'safety',
#   'enough',
#   'scarce',
#   'resource',
#   'company',
#   'handicrafted',
#   'extreme',
#   'end',
#   'day',
#   'automatic',
#   'fine',
#   'also',
#   'offered',
#   'agreed',
#   'rule',
#   'game',
#   'cannot',
#   'complied'],
#  ['mostly',
#   'due',
#   'heavy',
#   'hop',
#   'time',
#   'got',
#   'ticket',
#   'driving',
#   'five',
#   'year',
#   'ago',
#   'human',
#   'labour',
#   'high',
#   'sleep',
#   'rate',
#   'according',
#   'report',
#   'majority',
#   'accident',
#   'caused',
#   'loss',
#   'driver',
#   'driving',
#   'ability',
#   'parking',
#   'supervisor',
#   'price',
#   'fim',
#   'agerelated',
#   'disease',
#   'sometimes',
#   'also',
#   'drug',
#   'drug',
#   'abuse',
#   'also',
#   'lot',
#   'suicide',
#   'traffic',
#   'le',
#   'hundred',
#   'case',
#   'per',
#   'year',
#   'claim',
#   'accident',
#   'would',
#   'sufficiently',
#   'reduced',
#   'due',
#   'report',
#   'research',
#   'board',
#   'investigator',
#   'read',
#   'fatal',
#   'accident',
#   'case',
#   'accident',
#   'really',
#   'considered',
#   'caused',
#   'much',
#   'speed',
#   'left',
#   'minority'],
#  ['swedish',
#   'give',
#   'people',
#   'broke',
#   'spree',
#   'cameraslenses',
#   'repair',
#   'became',
#   'expensive',
#   'hiring',
#   'real',
#   'police',
#   'officer'],
#  ['high',
#   'speed',
#   'controlled',
#   'drunk',
#   'taken',
#   'jail',
#   'traffic',
#   'offence',
#   'tackled',
#   'mention',
#   'minor',
#   'traffic',
#   'offence',
#   'police',
#   'lazy',
#   'police',
#   'lot',
#   'money',
#   'pay',
#   'job',
#   'take',
#   'hour',
#   'police',
#   'get',
#   'taxi',
#   'already',
#   'available',
#   'minute',
#   'pizza',
#   'le',
#   'hour',
#   'mobile',
#   'police',
#   'replaced',
#   'camera',
#   'drunk',
#   'delegated',
#   'security',
#   'store'],
#  ['dont', 'know', 'sure', 'always', 'come', 'taxi', 'pizza'],
#  ['probably',
#   'five',
#   'time',
#   'ride',
#   'least',
#   'chased',
#   'riding',
#   'moped',
#   'sometimes',
#   'middle',
#   'ride',
#   'came',
#   'sudden',
#   'departure'],
#  ['necessarily',
#   'bad',
#   'imagined',
#   'wrong',
#   'control',
#   'citizen',
#   'far',
#   'concerned',
#   'actual',
#   'police',
#   'state',
#   'people',
#   'crowd',
#   'stupid',
#   'group',
#   'dynamic',
#   'devilish',
#   'people',
#   'happy',
#   'totalitarian',
#   'system',
#   'wondered',
#   'would',
#   'rigorously',
#   'controlled',
#   'suppose',
#   'social',
#   'system',
#   'looked',
#   'tolerance',
#   'debate',
#   'singapore',
#   'though',
#   'course',
#   'little',
#   'modified',
#   'direct',
#   'democracy',
#   'certainly',
#   'seem',
#   'playing',
#   'cannot',
#   'offend',
#   'human',
#   'right',
#   'hand',
#   'socalled',
#   'totalitarian',
#   'society',
#   'better',
#   'solution',
#   'liberal',
#   'system',
#   'almost',
#   'agree',
#   'orwellian',
#   'society',
#   'communist',
#   'utopia',
#   'would',
#   'also',
#   'nice',
#   'place',
#   'live'],
#  ['live',
#   'democracy',
#   'people',
#   'representative',
#   'represent',
#   'political',
#   'state',
#   'control',
#   'feel',
#   'well',
#   'citizen',
#   'man',
#   'happiness',
#   'society',
#   'depends',
#   'system',
#   'surely',
#   'soviet',
#   'union',
#   'happy',
#   'today',
#   'yes',
#   'dont',
#   'live',
#   'totalitarian',
#   'society',
#   'said',
#   'person',
#   'happy',
#   'society',
#   'think',
#   'people',
#   'society',
#   'survival',
#   'secure',
#   'police',
#   'given',
#   'right',
#   'listen',
#   'people',
#   'cell',
#   'phone',
#   'phone',
#   'call',
#   'given',
#   'permission',
#   'steal',
#   'people',
#   'surveillance',
#   'greatly',
#   'facilitated',
#   'yes',
#   'come',
#   'much',
#   'closer',
#   'feel',
#   'drive',
#   'police',
#   'camera',
#   'city',
#   'video',
#   'camera',
#   'every',
#   'corner',
#   'least',
#   'hole',
#   'raid',
#   'end',
#   'road',
#   'feel',
#   'safe',
#   'environment',
#   'feel',
#   'safer',
#   'finland',
#   'youve',
#   'already',
#   'noticed'],
#  ['soviet',
#   'union',
#   'incredible',
#   'amount',
#   'unhappy',
#   'people',
#   'precisely',
#   'didnt',
#   'say',
#   'society',
#   'proposed',
#   'would',
#   'perfect',
#   'happier',
#   'reason',
#   'curse',
#   'security',
#   'camera',
#   'mean',
#   'control',
#   'monitoring',
#   'reduce',
#   'satisfaction',
#   'course',
#   'reason',
#   'overboard',
#   'idea',
#   'expressed',
#   'besides',
#   'havent',
#   'done',
#   'anything',
#   'wrong',
#   'said',
#   'would',
#   'work',
#   'well',
#   'today',
#   'used',
#   'wrong',
#   'purpose',
#   'protect',
#   'public',
#   'sense',
#   'security',
#   'decrease',
#   'see',
#   'camera',
#   'staring',
#   'window',
#   'car'],
#  ['human',
#   'life',
#   'work',
#   'education',
#   'different',
#   'thought',
#   'put',
#   'opposed',
#   'theory',
#   'part',
#   'thought',
#   'happy',
#   'society',
#   'except',
#   'ideal',
#   'society',
#   'affect',
#   'dutch',
#   'line',
#   'never',
#   'work',
#   'center',
#   'hole',
#   'put',
#   'camera',
#   'surveillance',
#   'within',
#   'couple',
#   'week',
#   'almost',
#   'kind',
#   'society',
#   'work',
#   'catch',
#   'relationship',
#   'problem',
#   'surely',
#   'uncomfortable',
#   'talked',
#   'forced',
#   'labour',
#   'camp',
#   'soviet',
#   'union',
#   'many',
#   'fight',
#   'would',
#   'prevented',
#   'policeman',
#   'police',
#   'uniform',
#   'foot',
#   'patrol',
#   'according',
#   'press',
#   'report',
#   'police',
#   'prevented',
#   'two',
#   'fight'],
#  ['wrong',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'dont',
#   'know',
#   'whats',
#   'going',
#   'telling',
#   'thats',
#   'reason',
#   'youre',
#   'telling',
#   'thats',
#   'reason',
#   'youre',
#   'telling',
#   'thats',
#   'whats',
#   'going',
#   'telling',
#   'thats',
#   'going',
#   'going',
#   'going',
#   'going',
#   'going',
#   'wrong',
#   'way',
#   'going',
#   'going'],
#  ['nonsense', 'analysis', 'dont', 'live', 'cuba', 'month'],
#  ['strange',
#   'go',
#   'nick',
#   'uriellukku',
#   'strange',
#   'see',
#   'year',
#   'time',
#   'youll',
#   'long',
#   'write',
#   'nick',
#   'like',
#   'christmas',
#   'christmas',
#   'ended',
#   'little',
#   'boy',
#   'personally',
#   'havent',
#   'written',
#   'anything',
#   'long',
#   'time',
#   'tsippe',
#   'le',
#   'often',
#   'even',
#   'visit',
#   'miss',
#   'past',
#   'old',
#   'crowd',
#   'heinis',
#   'ramon',
#   'love',
#   'ill',
#   'try',
#   'remember',
#   'people',
#   'arethusa',
#   'pseudo',
#   'hippi',
#   'oplev',
#   'dark',
#   'light',
#   'feeling',
#   'longing',
#   'nostalgia',
#   'whats',
#   'forgotten',
#   'com',
#   'wonder',
#   'anyones',
#   'anymore'],
#  ['came',
#   'today',
#   'whisper',
#   'quote',
#   'like',
#   'highest',
#   'lead',
#   'happened',
#   'read',
#   'message'],
#  ['bit',
#   'jumble',
#   'jing',
#   'jingle',
#   'jingle',
#   'jing',
#   'bit',
#   'fuss',
#   'bit',
#   'fuss',
#   'telling',
#   'bit',
#   'fuss',
#   'jumble'],
#  ['little',
#   'mistake',
#   'havent',
#   'heal',
#   'wound',
#   'balsam',
#   'even',
#   'invented',
#   'superior',
#   'life',
#   'product',
#   'night',
#   'ive',
#   'away',
#   'home',
#   'week',
#   'long',
#   'enough',
#   'look',
#   'start',
#   'analysis',
#   'column',
#   'state',
#   'back',
#   'case',
#   'bit',
#   'money',
#   'thats',
#   'going',
#   'spent',
#   'going',
#   'way',
#   'time',
#   'money',
#   'money',
#   'money',
#   'money',
#   'time',
#   'month',
#   'going',
#   'thing',
#   'unlike',
#   'last',
#   'time',
#   'ive',
#   'claimed',
#   'ive',
#   'thing',
#   'ive',
#   'terrible',
#   'thing',
#   'yous',
#   'sake',
#   'sake',
#   'ive',
#   'kind',
#   'thinking',
#   'unlike',
#   'pseudo',
#   'last',
#   'claim',
#   'money',
#   'month',
#   'ive',
#   'spending',
#   'much',
#   'money',
#   'morning',
#   'thought',
#   'greet',
#   'jumania',
#   'teretere',
#   'got',
#   'silver',
#   'skied',
#   'gold',
#   'jumped',
#   'going',
#   'sake',
#   'youre',
#   'getting',
#   'ahead',
#   'take',
#   'victory',
#   'home',
#   'almost',
#   'identically',
#   'going',
#   'morning',
#   'money',
#   'month',
#   'sake',
#   'sake',
#   'sake',
#   'going',
#   'thing',
#   'going',
#   'month',
#   'money',
#   'month',
#   'ive',
#   'kind',
#   'thinking',
#   'going',
#   'thing',
#   'money',
#   'money',
#   'month',
#   'time',
#   'money',
#   'month',
#   'going',
#   'money',
#   'month',
#   'money',
#   'going',
#   'thing',
#   'going',
#   'going',
#   'time',
#   'month',
#   'going',
#   'time',
#   'time',
#   'month',
#   'sake',
#   'going',
#   'going',
#   'month'],
#  ['distracted',
#   'fact',
#   'new',
#   'headline',
#   'flooding',
#   'cloud',
#   'good',
#   'conversation',
#   'left',
#   'behind',
#   'many',
#   'column',
#   'problem',
#   'see',
#   'lot',
#   'people',
#   'coming',
#   'trying',
#   'provoke',
#   'others',
#   'throw',
#   'many',
#   'time',
#   'lake',
#   'maybe',
#   'new',
#   'user',
#   'column',
#   'many',
#   'column',
#   'past',
#   'mean',
#   'mostly',
#   'column',
#   'also',
#   'crowd',
#   'knowingly',
#   'want',
#   'disturb',
#   'column',
#   'action',
#   'theyll',
#   'enough',
#   'miss',
#   'column',
#   'theyre',
#   'always',
#   'showing',
#   'conversation',
#   'start',
#   'interesting',
#   'even',
#   'useful',
#   'hand',
#   'whose',
#   'topic',
#   'profound',
#   'whose',
#   'purpose',
#   'maybe',
#   'mainly',
#   'entertain',
#   'maintain',
#   'light',
#   'conversation',
#   'text',
#   'level',
#   'conversation',
#   'sometimes',
#   'theyll',
#   'get',
#   'quick',
#   'hit',
#   'however'],
#  ['lot',
#   'overjumps',
#   'collide',
#   'many',
#   'front',
#   'page',
#   'easier',
#   'skip',
#   'back',
#   'time',
#   'take',
#   'look',
#   'something',
#   'old',
#   'kind',
#   'conversationor',
#   'summary',
#   'review',
#   'good',
#   'small',
#   'number',
#   'give',
#   'good',
#   'tip',
#   'whose',
#   'nickname',
#   'open',
#   'deepen',
#   'comment'],
#  ['good',
#   'flash',
#   'sun',
#   'yesterday',
#   'day',
#   'something',
#   'expected',
#   'ive',
#   'spent',
#   'half',
#   'day',
#   'front',
#   'page',
#   'landscape',
#   'beginning',
#   'think',
#   'often',
#   'market',
#   'filling',
#   'column',
#   'mostly',
#   'rubbish',
#   'take',
#   'time',
#   'energy',
#   'screen',
#   'pearl',
#   'sitting',
#   'around',
#   'computer',
#   'never',
#   'completely',
#   'useless',
#   'ill',
#   'keep',
#   'curiosity',
#   'space',
#   'weather',
#   'side',
#   'rest',
#   'eye',
#   'name',
#   'ill',
#   'write',
#   'something',
#   'follow',
#   'animal',
#   'story',
#   'god',
#   'sake',
#   'sake',
#   'word',
#   'easier',
#   'find',
#   'machine',
#   'search',
#   'book',
#   'bookcase',
#   'secondly',
#   'could',
#   'used',
#   'usefully',
#   'going',
#   'time',
#   'evening',
#   'always',
#   'sought',
#   'piece',
#   'information',
#   'interesting',
#   'thing',
#   'come'],
#  ['write',
#   'something',
#   'follow',
#   'animal',
#   'story',
#   'animal',
#   'page',
#   'curiosity',
#   'space',
#   'weather',
#   'page',
#   'still',
#   'mostly',
#   'peaceful',
#   'starting',
#   'get',
#   'phrase',
#   'get',
#   'time',
#   'evening',
#   'bead',
#   'screening',
#   'take',
#   'time',
#   'energy',
#   'lot',
#   'discussion',
#   'exapina',
#   'scribe'],
#  ['everything',
#   'exists',
#   'borncreated',
#   'point',
#   'take',
#   'evothan',
#   'creationism',
#   'theyre',
#   'even',
#   'reading',
#   'purpose',
#   'would',
#   'best',
#   'live',
#   'moment',
#   'idems',
#   'give',
#   'answer',
#   'sorry',
#   'wandering',
#   'around',
#   'like',
#   'following',
#   'front',
#   'page',
#   'full',
#   'crap',
#   'religion',
#   'philosophy',
#   'nothing',
#   'born',
#   'chance',
#   'eternal',
#   'problem',
#   'ive',
#   'always',
#   'still',
#   'wondered',
#   'eternal',
#   'question',
#   'humanity'],
#  ['therefore',
#   'foundation',
#   'existence',
#   'god',
#   'immobilizer',
#   'theology',
#   'doctrine',
#   'god',
#   'philosophy',
#   'theology',
#   'versus',
#   'christian',
#   'theology',
#   'western',
#   'philosophy',
#   'christian',
#   'tone',
#   'atheist',
#   'claim',
#   'know',
#   'god',
#   'teist',
#   'know',
#   'god',
#   'agnostic',
#   'claim',
#   'traditional',
#   'proof',
#   'existence',
#   'god',
#   'definition',
#   'god',
#   'talking',
#   'agnostic',
#   'yet',
#   'conscious',
#   'world',
#   'causal',
#   'testimony',
#   'every',
#   'event',
#   'consequence',
#   'beginning',
#   'chain',
#   'consequence',
#   'first',
#   'reason',
#   'god',
#   'quote',
#   'slice',
#   'theoretical',
#   'philosophy',
#   'philosophical',
#   'theology',
#   'cosmic',
#   'proof',
#   'thing',
#   'thing',
#   'either',
#   'exist',
#   'conditional',
#   'existence',
#   'absolute'],
#  ['add',
#   'prewritten',
#   'almost',
#   'triggering',
#   'reflection',
#   'answer',
#   'written',
#   'backscapes',
#   'active',
#   'conversation',
#   'page',
#   'jesus',
#   'metaphys',
#   'announcement',
#   'miet',
#   'creator',
#   'perhaps',
#   'sand',
#   'star'],
#  ['thats',
#   'dont',
#   'accept',
#   'dont',
#   'know',
#   'life',
#   'death',
#   'god',
#   'create',
#   'world',
#   'want',
#   'experience',
#   'otherness',
#   'dont',
#   'know',
#   'answer',
#   'dont',
#   'know',
#   'everything',
#   'created',
#   'born',
#   'entity',
#   'always',
#   'question',
#   'front',
#   'page',
#   'heading',
#   'much',
#   'sense',
#   'mind',
#   'doesnt',
#   'understand'],
#  ['waited',
#   'answer',
#   'would',
#   'speak',
#   'cause',
#   'creation',
#   'lord',
#   'created',
#   'firstborn',
#   'work',
#   'beginning',
#   'age',
#   'yet',
#   'earth',
#   'depth',
#   'born',
#   'born',
#   'depth',
#   'age',
#   'born',
#   'given',
#   'answer',
#   'god',
#   'created',
#   'universe',
#   'men',
#   'plaything',
#   'son',
#   'scripture',
#   'explore',
#   'matter',
#   'proverb',
#   'chapter',
#   'gtgt',
#   'would',
#   'able',
#   'answer',
#   'front',
#   'page',
#   'raging',
#   'born',
#   'beginning',
#   'depth',
#   'earth',
#   'question',
#   'valid',
#   'answer',
#   'found',
#   'bible',
#   'heaven',
#   'hill',
#   'answer',
#   'harsh',
#   'mountain',
#   'immersed',
#   'place',
#   'first',
#   'work',
#   'born',
#   'searching',
#   'bible',
#   'back',
#   'forth',
#   'praying',
#   'answer'],
#  ['speed',
#   'magnetic',
#   'field',
#   'jumped',
#   'well',
#   'intensity',
#   'scale',
#   'northern',
#   'light',
#   'hopeless',
#   'week',
#   'ago',
#   'keep',
#   'curiosity',
#   'space',
#   'weather',
#   'side',
#   'good',
#   'splash',
#   'sun',
#   'yesterday',
#   'something',
#   'expected',
#   'full',
#   'cloud',
#   'density',
#   'flash',
#   'hit',
#   'ball',
#   'hour',
#   'ago',
#   'solar',
#   'wind',
#   'temperature'],
#  ['atetms',
#   'give',
#   'answer',
#   'question',
#   'column',
#   'ask',
#   'question',
#   'eternal',
#   'problem',
#   'thought',
#   'revolved',
#   'around',
#   'question',
#   'enough',
#   'pain',
#   'decade',
#   'matter',
#   'mystery',
#   'existence',
#   'eternal',
#   'question',
#   'humanity',
#   'religion',
#   'never',
#   'occurs',
#   'would',
#   'thought',
#   'deeply',
#   'tried',
#   'remember',
#   'thought',
#   'past',
#   'philosophy'],
#  ['ive',
#   'ive',
#   'probably',
#   'writing',
#   'ive',
#   'long',
#   'time',
#   'ive',
#   'long',
#   'time',
#   'ive',
#   'long',
#   'time',
#   'ive',
#   'long',
#   'time',
#   'ive',
#   'writing',
#   'ive',
#   'writing',
#   'couple',
#   'day',
#   'ive',
#   'writing',
#   'ive',
#   'long',
#   'time',
#   'ive',
#   'writing',
#   'ive',
#   'long',
#   'time',
#   'ive',
#   'long',
#   'time',
#   'dont',
#   'know',
#   'ive',
#   'writing'],
#  ['waiting',
#   'find',
#   'golden',
#   'pasture',
#   'memory',
#   'didnt',
#   'time',
#   'write',
#   'day',
#   'flashy',
#   'life',
#   'hard',
#   'winter',
#   'treated',
#   'hard',
#   'keyboard',
#   'machine',
#   'said',
#   'poks',
#   'threw',
#   'virtuality',
#   'jne',
#   'back',
#   'closet',
#   'talking',
#   'come',
#   'mind',
#   'november',
#   'moominvalley',
#   'everyone',
#   'gathered',
#   'moomin',
#   'house',
#   'came',
#   'terrible',
#   'hemuli',
#   'well',
#   'welldiscovered',
#   'conversationist',
#   'could',
#   'anyone',
#   'else',
#   'secretly',
#   'lured',
#   'interior',
#   'history',
#   'got',
#   'tired',
#   'waiting',
#   'front',
#   'page',
#   'stuff',
#   'disturbed',
#   'everyone',
#   'people',
#   'retreated',
#   'dark',
#   'interior',
#   'moomin',
#   'house',
#   'spend',
#   'quiet',
#   'night'],
#  ['sounded',
#   'one',
#   'nature',
#   'father',
#   'son',
#   'holy',
#   'spirit',
#   'holy',
#   'spirit',
#   'therefore',
#   'represents',
#   'feminine',
#   'side',
#   'deity',
#   'god',
#   'create',
#   'order',
#   'experience',
#   'must',
#   'asked',
#   'somewhere',
#   'come',
#   'son',
#   'god',
#   'remembering',
#   'question',
#   'find',
#   'difficult',
#   'triunity',
#   'therefore',
#   'difficult',
#   'believe',
#   'god',
#   'created',
#   'universe',
#   'sake',
#   'game'],
#  ['consider',
#   'bible',
#   'book',
#   'requires',
#   'lot',
#   'interpretation',
#   'familiarity',
#   'layman',
#   'know',
#   'believe',
#   'sure',
#   'context',
#   'several',
#   'case',
#   'called',
#   'heretic',
#   'agnostic',
#   'bold',
#   'agnostic',
#   'perhaps',
#   'seeker',
#   'would',
#   'best',
#   'name'],
#  ['vaguely',
#   'something',
#   'column',
#   'clear',
#   'answer',
#   'took',
#   'printtewe',
#   'read',
#   'cant',
#   'really',
#   'describe',
#   'found',
#   'first',
#   'visit',
#   'april',
#   'evo',
#   'thank',
#   'went',
#   'apology',
#   'creationism',
#   'way',
#   'replied',
#   'article',
#   'faith',
#   'internal',
#   'experience'],
#  ['going',
#   'look',
#   'afraid',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look',
#   'going',
#   'look'],
#  ['reminds',
#   'william',
#   'carver',
#   'chosen',
#   'piece',
#   'ancient',
#   'case',
#   'name',
#   'place',
#   'may',
#   'also',
#   'wrong',
#   'remembered',
#   'prayed',
#   'god',
#   'reveal',
#   'secret',
#   'universe',
#   'triune',
#   'whereinss',
#   'answer',
#   'thing',
#   'william',
#   'took',
#   'job',
#   'cookie',
#   'god',
#   'help',
#   'rest',
#   'life',
#   'question',
#   'difficult',
#   'dont',
#   'believe',
#   'god',
#   'play',
#   'created',
#   'universe',
#   'explaining',
#   'universe',
#   'cause',
#   'pretty',
#   'big',
#   'slice',
#   'one',
#   'person',
#   'plate',
#   'answer',
#   'best',
#   'thing',
#   'say',
#   'god',
#   'replied',
#   'big',
#   'thing',
#   'kemistins',
#   'hundred',
#   'useful',
#   'usable',
#   'compound',
#   'substance'],
#  ['ill',
#   'tell',
#   'whats',
#   'wrong',
#   'ill',
#   'tell',
#   'whatll',
#   'tell',
#   'whatll',
#   'tell',
#   'ill',
#   'tell',
#   'whatll',
#   'tell',
#   'ill',
#   'tell',
#   'whatll',
#   'tell',
#   'whatll',
#   'tell',
#   'ill',
#   'tell',
#   'whats',
#   'wrong',
#   'ill',
#   'tell',
#   'whatll',
#   'tell',
#   'whatll',
#   'tell',
#   'itll',
#   'like',
#   'ill',
#   'tell',
#   'something',
#   'else',
#   'ill',
#   'tell',
#   'whatll',
#   'tell',
#   'itll'],
#  ['unfortunately',
#   'didnt',
#   'start',
#   'proper',
#   'conversation',
#   'dont',
#   'know',
#   'whats',
#   'going',
#   'sure',
#   'whats',
#   'going',
#   'ill',
#   'hardly',
#   'come',
#   'back',
#   'often',
#   'decide',
#   'ill',
#   'take',
#   'look',
#   'headline',
#   'going',
#   'talking',
#   'often',
#   'decide',
#   'ill',
#   'take',
#   'look',
#   'title',
#   'mostly',
#   'reading',
#   'rarely',
#   'opened',
#   'ill',
#   'take',
#   'part',
#   'subject',
#   'fresh',
#   'ill',
#   'barely',
#   'come',
#   'back',
#   'book',
#   'expensive',
#   'rarely',
#   'get',
#   'bought',
#   'even',
#   'youre',
#   'interested',
#   'well'],
#  ['havent',
#   'busy',
#   'looking',
#   'anything',
#   'else',
#   'window',
#   'show',
#   'pale',
#   'star',
#   'star',
#   'cant',
#   'look',
#   'ive',
#   'settle',
#   'lookout',
#   'sky',
#   'usually',
#   'lookout',
#   'star',
#   'lookout',
#   'muck',
#   'lookout',
#   'muck',
#   'know',
#   'starry',
#   'sky',
#   'look',
#   'like',
#   'dark',
#   'autumn',
#   'cant',
#   'imagine',
#   'living',
#   'anywhere',
#   'else'],
#  ['star',
#   'see',
#   'little',
#   'went',
#   'buy',
#   'panora',
#   'price',
#   'never',
#   'thought',
#   'binoculars',
#   'could',
#   'useful',
#   'city',
#   'year',
#   'ago',
#   'star',
#   'map',
#   'attached',
#   'magazine',
#   'ota',
#   'course',
#   'moment',
#   'thick',
#   'cloud',
#   'seems',
#   'worth',
#   'sometimes',
#   'didnt',
#   'get',
#   'sense',
#   'well',
#   'ive',
#   'read',
#   'book',
#   'see',
#   'map',
#   'wrong',
#   'direction',
#   'left',
#   'one',
#   'spinning',
#   'puck',
#   'group',
#   'star',
#   'recognize',
#   'seemed',
#   'wrong',
#   'place',
#   'look',
#   'forward',
#   'sky',
#   'clear',
#   'applied',
#   'library',
#   'map',
#   'star',
#   'bare',
#   'eye'],
#  ['star',
#   'see',
#   'little',
#   'went',
#   'buy',
#   'panora',
#   'price',
#   'never',
#   'thought',
#   'binoculars',
#   'could',
#   'useful',
#   'city',
#   'year',
#   'ago',
#   'star',
#   'map',
#   'attached',
#   'magazine',
#   'ota',
#   'course',
#   'moment',
#   'thick',
#   'cloud',
#   'seems',
#   'worth',
#   'sometimes',
#   'didnt',
#   'get',
#   'sense',
#   'well',
#   'ive',
#   'read',
#   'book',
#   'see',
#   'map',
#   'wrong',
#   'direction',
#   'left',
#   'one',
#   'spinning',
#   'puck',
#   'group',
#   'star',
#   'recognize',
#   'seemed',
#   'wrong',
#   'place',
#   'look',
#   'forward',
#   'sky',
#   'clear',
#   'applied',
#   'library',
#   'map',
#   'star',
#   'bare',
#   'eye'],
#  ['somewhere',
#   'something',
#   'interesting',
#   'going',
#   'get',
#   'geimes',
#   'time',
#   'page',
#   'wrote',
#   'playful',
#   'mind',
#   'xenon',
#   'paradox',
#   'subject',
#   'heading',
#   'question',
#   'columnist',
#   'participated',
#   'subject',
#   'fresh',
#   'unfortunately',
#   'didnt',
#   'start',
#   'proper',
#   'discussion',
#   'read',
#   'chain',
#   'started',
#   'turning',
#   'comment',
#   'subject',
#   'einstein',
#   'old',
#   'mold',
#   'ear',
#   'would',
#   'gotten',
#   'ride',
#   'superstring',
#   'planck',
#   'ten',
#   'thousand',
#   'calabs',
#   'mirror',
#   'beam',
#   'would',
#   'solved',
#   'problem',
#   'tearing',
#   'whole',
#   'space',
#   'continuum',
#   'apart',
#   'came',
#   'head',
#   'mind',
#   'estimated',
#   'event',
#   'would',
#   'week',
#   'late',
#   'change',
#   'name',
#   'would',
#   'returned',
#   'past',
#   'conversation',
#   'actual',
#   'koita',
#   'hint'],
#  ['spinable',
#   'puck',
#   'even',
#   'better',
#   'empty',
#   'spinable',
#   'puck',
#   'top',
#   'transparent',
#   'impelable',
#   'rotating',
#   'scale',
#   'star',
#   'map',
#   'planispheric',
#   'extremely',
#   'useful',
#   'star',
#   'appear',
#   'see',
#   'one',
#   'grasp',
#   'one',
#   'sometimes',
#   'added',
#   'science',
#   'image',
#   'magazine',
#   'slice',
#   'winter',
#   'sky',
#   'slice',
#   'extends',
#   'horizon',
#   'middle',
#   'sky',
#   'ursa',
#   'least',
#   'ever',
#   'sold',
#   'star',
#   'dont',
#   'see',
#   'large',
#   'slice',
#   'heaven',
#   'home',
#   'year',
#   'ago',
#   'star',
#   'map',
#   'attached',
#   'magazine'],
#  ['transparency',
#   'practice',
#   'basically',
#   'university',
#   'lecture',
#   'open',
#   'interested',
#   'within',
#   'premise',
#   'course',
#   'think',
#   'youre',
#   'get',
#   'know',
#   'star',
#   'sit',
#   'listen',
#   'first',
#   'time',
#   'bright',
#   'sky',
#   'many',
#   'day',
#   'went',
#   'listen',
#   'university',
#   'lecture',
#   'least',
#   'basic',
#   'astronomy',
#   'class',
#   'sit',
#   'interested',
#   'people',
#   'elementary',
#   'school',
#   'senior',
#   'grandmother',
#   'least',
#   'even',
#   'youre',
#   'student',
#   'university',
#   'book',
#   'today',
#   'thought',
#   'thing',
#   'since',
#   'youre',
#   'eager',
#   'take',
#   'information',
#   'book'],
#  ['binoculars',
#   'beginning',
#   'evening',
#   'star',
#   'stood',
#   'vague',
#   'vibrating',
#   'spot',
#   'couple',
#   'hour',
#   'clear',
#   'cluster',
#   'star',
#   'wouldnt',
#   'separated',
#   'first',
#   'theyd',
#   'got',
#   'disappointed',
#   'eye',
#   'scattered',
#   'itd',
#   'shame',
#   'cloud',
#   'gathered',
#   'apparently',
#   'planet',
#   'yesterday',
#   'playing',
#   'streak',
#   'star',
#   'bright',
#   'shining',
#   'star',
#   'even',
#   'though',
#   'star',
#   'map',
#   'pretty',
#   'sure',
#   'cluster',
#   'belonged',
#   'could',
#   'didnt',
#   'get',
#   'reference',
#   'point',
#   'woke',
#   'three',
#   'oclock',
#   'night',
#   'happened',
#   'look',
#   'window',
#   'open',
#   'east'],
#  ['almost',
#   'view',
#   'ten',
#   'time',
#   'cloud',
#   'pitched',
#   'left',
#   'perseus',
#   'left',
#   'northeast',
#   'side',
#   'road',
#   'whole',
#   'time',
#   'landscape',
#   'essence',
#   'binoculars',
#   'normal',
#   'touch',
#   'right',
#   'forefinger',
#   'little',
#   'bit',
#   'different',
#   'fold',
#   'right',
#   'side',
#   'minus',
#   'window',
#   'computer',
#   'star',
#   'stood',
#   'beginning',
#   'binoculars',
#   'vague',
#   'vibrating',
#   'spot',
#   'adjustment',
#   'binocular',
#   'refine',
#   'image',
#   'least',
#   'one',
#   'thing',
#   'come',
#   'eye',
#   'spin',
#   'around',
#   'left',
#   'always',
#   'small',
#   'motion',
#   'rotate',
#   'back',
#   'forth',
#   'find',
#   'best',
#   'precision'],
#  ['havent',
#   'opened',
#   'discussion',
#   'since',
#   'like',
#   'place',
#   'afterwards',
#   'remembered',
#   'watched',
#   'himalaya',
#   'mountain',
#   'wrapped',
#   'blanket',
#   'starry',
#   'sky',
#   'something',
#   'interesting',
#   'travel',
#   'story',
#   'read',
#   'expedition',
#   'write',
#   'sometimes',
#   'shall',
#   'look',
#   'away',
#   'almost',
#   'june'],
#  ['continue',
#   'page',
#   'arethusa',
#   'quickly',
#   'opleville',
#   'force',
#   'return',
#   'night',
#   'struck',
#   'stomach',
#   'bug',
#   'also',
#   'dream',
#   'cant',
#   'remember',
#   'whether',
#   'interesting',
#   'discussion',
#   'spiteful',
#   'racism',
#   'debate',
#   'june',
#   'force',
#   'veks',
#   'harald',
#   'kettunen',
#   'ill',
#   'start',
#   'exchanging',
#   'message',
#   'page',
#   'bit',
#   'indian',
#   'experience',
#   'ill',
#   'return',
#   'title',
#   'arethusa',
#   'right',
#   'next',
#   'religion',
#   'issue',
#   'moment',
#   'brain',
#   'like',
#   'cotton'],
#  ['keep',
#   'binocular',
#   'hand',
#   'sky',
#   'go',
#   'narrow',
#   'strip',
#   'blue',
#   'sky',
#   'see',
#   'star',
#   'two',
#   'happen',
#   'read',
#   'within',
#   'hour'],
#  ['height',
#   'changing',
#   'climate',
#   'could',
#   'think',
#   'imagine',
#   'himalaya',
#   'dreaming',
#   'home',
#   'rock',
#   'bottom',
#   'book',
#   'travel',
#   'photographer',
#   'able',
#   'remember',
#   'looked',
#   'mountain',
#   'himalaya',
#   'wrapped',
#   'starry',
#   'sky',
#   'seafront',
#   'track',
#   'different',
#   'height',
#   'time',
#   'trail',
#   'would',
#   'found',
#   'outer',
#   'island',
#   'gulf',
#   'finland',
#   'great',
#   'flora',
#   'finland',
#   'travel',
#   'busy',
#   'important',
#   'hill',
#   'finland',
#   'perhaps',
#   'bit',
#   'mountain',
#   'fan',
#   'today',
#   'net',
#   'vegetation',
#   'book',
#   'found',
#   'everything',
#   'related',
#   'good',
#   'hill',
#   'numbered',
#   'hill',
#   'everything'],
#  ['red',
#   'color',
#   'top',
#   'south',
#   'english',
#   'show',
#   'clear',
#   'air',
#   'even',
#   'city',
#   'dark',
#   'time',
#   'even',
#   'point',
#   'binoculars',
#   'star',
#   'tip',
#   'evening',
#   'looking',
#   'illuminated',
#   'screen',
#   'computer',
#   'show',
#   'bright',
#   'star',
#   'northeast',
#   'eye',
#   'air',
#   'swept',
#   'rain',
#   'extremely',
#   'bright',
#   'northern',
#   'light',
#   'observation',
#   'page',
#   'httpsec',
#   'gif',
#   'show',
#   'ten',
#   'minute',
#   'le',
#   'back',
#   'northern',
#   'hemisphere',
#   'northern',
#   'northern',
#   'northern',
#   'light',
#   'election',
#   'noa',
#   'govpmapgifpmapn',
#   'activity',
#   'level',
#   'left',
#   'side',
#   'ten',
#   'happen',
#   'read',
#   'good',
#   'seeing',
#   'far',
#   'cloud',
#   'increasingly',
#   'opening'],
#  ['along',
#   'route',
#   'local',
#   'guide',
#   'watching',
#   'tourist',
#   'gorge',
#   'samaria',
#   'although',
#   'good',
#   'view',
#   'himalaya',
#   'mountain',
#   'peak',
#   'terrain',
#   'place',
#   'difficulty',
#   'bad',
#   'stopped',
#   'look',
#   'around',
#   'walker',
#   'hania',
#   'posted',
#   'story',
#   'foot',
#   'himalaya',
#   'mountain',
#   'tourist',
#   'group',
#   'side',
#   'waiting',
#   'ferry',
#   'take',
#   'hiker',
#   'one',
#   'interesting',
#   'place',
#   'walked',
#   'crete',
#   'guide',
#   'immediately',
#   'rushing',
#   'along',
#   'route',
#   'telling',
#   'place',
#   'rest',
#   'bit',
#   'mistake',
#   'northern',
#   'india',
#   'route',
#   'long',
#   'although',
#   'tried',
#   'walk',
#   'privacy'],
#  ['keeping', 'eye', 'situation', 'much', 'sky', 'crack', 'cloud'],
#  ['previous',
#   'one',
#   'tried',
#   'lure',
#   'background',
#   'let',
#   'see',
#   'bait',
#   'bite',
#   'get',
#   'caught',
#   'away',
#   'intended',
#   'tobacco',
#   'man',
#   'iiwar',
#   'oplev',
#   'first',
#   'side',
#   'tip',
#   'quite',
#   'right',
#   'one'],
#  ['room',
#   'performance',
#   'refer',
#   'directly',
#   'message',
#   'end',
#   'address',
#   'line',
#   'removing',
#   'character',
#   'ampofsxxx',
#   'regardless',
#   'distance',
#   'front',
#   'page',
#   'suomi',
#   'example',
#   'thought',
#   'mention',
#   'one',
#   'thing',
#   'make',
#   'easier',
#   'find',
#   'message',
#   'acshowampefefag',
#   'suomi',
#   'chat',
#   'software',
#   'functionally',
#   'fine',
#   'xxx',
#   'serial',
#   'number',
#   'message',
#   'chain',
#   'since',
#   'latest',
#   'ive',
#   'noticed',
#   'people',
#   'usually',
#   'refer',
#   'chain',
#   'sequence',
#   'problem',
#   'constantly',
#   'growing',
#   'new',
#   'chain',
#   'time',
#   'opened',
#   'ive',
#   'always',
#   'used',
#   'kanid',
#   'long',
#   'number',
#   'series',
#   'message',
#   'message',
#   'found',
#   'address',
#   'message',
#   'httpdebate',
#   'youre',
#   'archive'],
#  ['like',
#   'httpdebate',
#   'suomi',
#   'pixel',
#   'letter',
#   'character',
#   'address',
#   'line',
#   'small',
#   'one',
#   'cant',
#   'really',
#   'read',
#   'individual',
#   'letter',
#   'acshow',
#   'ampidefceeg',
#   'httpdebate',
#   'httpdebate',
#   'problem',
#   'appear',
#   'come',
#   'accuracy',
#   'screen',
#   'used'],
#  ['see',
#   'dim',
#   'spot',
#   'see',
#   'degree',
#   'high',
#   'oclock',
#   'evening',
#   'yesterday',
#   'looked',
#   'window',
#   'binoculars',
#   'saw',
#   'map',
#   'map',
#   'page',
#   'right',
#   'upper',
#   'corner',
#   'point',
#   'reference',
#   'andromeda',
#   'constellation',
#   'mirach',
#   'sky',
#   'binocular',
#   'field',
#   'window',
#   'east',
#   'could',
#   'see',
#   'core',
#   'andromeda',
#   'galaxy',
#   'straight',
#   'east',
#   'quite',
#   'high',
#   'million',
#   'year',
#   'ago',
#   'time',
#   'foot',
#   'away',
#   'show',
#   'even',
#   'better',
#   'degree',
#   'twice',
#   'right'],
#  ['watch',
#   'cloud',
#   'away',
#   'read',
#   'message',
#   'sky',
#   'full',
#   'look',
#   'like',
#   'youre',
#   'cracking'],
#  ['next',
#   'page',
#   'title',
#   'age',
#   'survey',
#   'noticed',
#   'guerrilla',
#   'strike',
#   'plan',
#   'change',
#   'behind',
#   'title'],
#  ['hand',
#   'speak',
#   'dont',
#   'think',
#   'ill',
#   'ever',
#   'ready',
#   'attempt',
#   'better',
#   'finding',
#   'superior',
#   'dimension',
#   'faith',
#   'constant',
#   'quest',
#   'faith',
#   'stumbling',
#   'block',
#   'rocky',
#   'path',
#   'mountain',
#   'mean',
#   'word',
#   'monster',
#   'inner',
#   'peace',
#   'thats',
#   'youre',
#   'trying',
#   'dont',
#   'even',
#   'know',
#   'matter',
#   'death',
#   'otherwise',
#   'believe',
#   'isnt',
#   'scary',
#   'dont',
#   'even',
#   'know',
#   'matter',
#   'death',
#   'life',
#   'mystery'],
#  ['ive',
#   'almost',
#   'answered',
#   'interrupted',
#   'threw',
#   'text',
#   'somewhere',
#   'open',
#   'window',
#   'youll',
#   'see',
#   'headline',
#   'main',
#   'page',
#   'grow',
#   'page',
#   'twenty',
#   'important',
#   'thing',
#   'long',
#   'youre',
#   'looking',
#   'top',
#   'discussion',
#   'headline',
#   'main',
#   'page',
#   'number',
#   'text',
#   'relevant',
#   'correction',
#   'thats',
#   'instruction',
#   'page',
#   'referred',
#   'page',
#   'didnt',
#   'even',
#   'whole',
#   'thats',
#   'circle',
#   'line',
#   'know',
#   'like',
#   'say',
#   'today',
#   'end',
#   'story',
#   'ive',
#   'using',
#   'long',
#   'time'],
#  ['already',
#   'pointed',
#   'valuation',
#   'still',
#   'essence',
#   'jesusman',
#   'god',
#   'strange',
#   'knowledge',
#   'appeared',
#   'exegetic',
#   'text',
#   'read',
#   'like',
#   'little',
#   'piece',
#   'dont',
#   'understand',
#   'dual',
#   'concept',
#   'godman',
#   'thank',
#   'much',
#   'hint',
#   'thank',
#   'much',
#   'resitative',
#   'performance',
#   'also',
#   'find',
#   'thanks',
#   'original',
#   'page',
#   'mother',
#   'much',
#   'familiar',
#   'bible',
#   'research'],
#  ['rule',
#   'inhis',
#   'onwards',
#   'calg',
#   'according',
#   'humanscale',
#   'logic',
#   'rationality',
#   'jesus',
#   'chromosome',
#   'genetic',
#   'problem',
#   'point',
#   'aside',
#   'explanation',
#   'called',
#   'son',
#   'god',
#   'lmil',
#   'hand',
#   'impossible',
#   'could',
#   'finite',
#   'man',
#   'side',
#   'creation',
#   'include',
#   'infinity',
#   'creator',
#   'deity',
#   'power',
#   'high',
#   'cover',
#   'shadow',
#   'basis',
#   'degree',
#   'logic',
#   'deity',
#   'scholar',
#   'come',
#   'conclusion',
#   'necessary',
#   'justice',
#   'godbased',
#   'men',
#   'unite',
#   'perfect',
#   'man',
#   'perfect',
#   'god',
#   'person',
#   'jesus',
#   'therefore',
#   'also',
#   'child',
#   'born',
#   'holy',
#   'jesus',
#   'born',
#   'man',
#   'originated',
#   'divine',
#   'mystic',
#   'conception',
#   'mother',
#   'full',
#   'divinity',
#   'always',
#   'hidden',
#   'angel',
#   'answered',
#   'holy',
#   'spirit',
#   'come',
#   'upon'],
#  ['wise',
#   'listenedbut',
#   'always',
#   'came',
#   'back',
#   'door',
#   'short',
#   'piece',
#   'omar',
#   'khaijams',
#   'work',
#   'tentmaker',
#   'wise',
#   'wine',
#   'would',
#   'love',
#   'get',
#   'know',
#   'pyski',
#   'young'],
#  ['setting',
#   'controlpanel',
#   'future',
#   'close',
#   'keep',
#   'amount',
#   'power',
#   'work',
#   'window',
#   'display',
#   'setup',
#   'move',
#   'outer',
#   'edge',
#   'screen',
#   'area',
#   'left',
#   'side',
#   'lower',
#   'row',
#   'either',
#   'get',
#   'enough',
#   'firepower',
#   'point',
#   'focus',
#   'destruction',
#   'couple',
#   'time',
#   'yes',
#   'explore',
#   'screen',
#   'see',
#   'find',
#   'anything',
#   'help',
#   'may',
#   'unnecessary',
#   'already',
#   'manage',
#   'business',
#   'without',
#   'advice',
#   'try',
#   'open',
#   'still',
#   'new',
#   'window',
#   'screen',
#   'beginning',
#   'copy',
#   'different',
#   'path',
#   'try',
#   'everything',
#   'focal',
#   'point',
#   'try',
#   'new',
#   'window',
#   'opening',
#   'new',
#   'location'],
#  ['would',
#   'get',
#   'rascal',
#   'control',
#   'better',
#   'thing',
#   'think',
#   'gonna',
#   'miss',
#   'good',
#   'comment'],
#  ['little',
#   'already',
#   'time',
#   'change',
#   'indeed',
#   'aha',
#   'much',
#   'time',
#   'left',
#   'seduce',
#   'today',
#   'lot',
#   'talk',
#   'debate',
#   'thing',
# ...
#   'along',
#   'wonder',
#   'would',
#   'interest',
#   'ideology',
#   'grab',
#   'clothes',
#   'comrade',
#   'position',
#   'socialist',
#   'finland',
#   'leading',
#   'position',
#   'fabricated',
#   'near',
#   'future',
#   'thing',
#   'various',
#   'ministry',
#   'health',
#   'authority',
#   'defence',
#   'agency',
#   'etc',
#   'industry'],
#  ['independent',
#   'air',
#   'direction',
#   'ideology',
#   'according',
#   'latest',
#   'information',
#   'form',
#   'espionage',
#   'cause',
#   'lot',
#   'damage',
#   'addition',
#   'readily',
#   'kept',
#   'quiet',
#   'tried',
#   'deal',
#   'matter',
#   'secretly',
#   'possible',
#   'suffer',
#   'harm',
#   'quietly',
#   'skin',
#   'industrial',
#   'espionage',
#   'much',
#   'greater',
#   'political',
#   'espionage',
#   'embarrassment',
#   'target',
#   'company'],
#  ['dont',
#   'mind',
#   'shes',
#   'teacher',
#   'university',
#   'oulu',
#   'indeed',
#   'time',
#   'year',
#   'learn',
#   'something',
#   'wise',
#   'seem',
#   'really',
#   'need'],
#  ['turn',
#   'secret',
#   'police',
#   'take',
#   'money',
#   'service',
#   'yet',
#   'today',
#   'turn',
#   'liar',
#   'talking',
#   'thing',
#   'longer',
#   'authority',
#   'teacher',
#   'history',
#   'taught',
#   'today',
#   'world',
#   'class',
#   'enemy',
#   'beaten',
#   'take',
#   'advantage',
#   'gullible',
#   'comrade',
#   'morally',
#   'appropriate',
#   'teacher',
#   'young',
#   'people',
#   'person',
#   'eight',
#   'year',
#   'life',
#   'double',
#   'life',
#   'use',
#   'student',
#   'gone',
#   'world',
#   'doctrine',
#   'mug',
#   'begging',
#   'money',
#   'west',
#   'everything',
#   'possible',
#   'typical',
#   'time',
#   'proletariat',
#   'dictatorship',
#   'win',
#   'progressive',
#   'force',
#   'together',
#   'security',
#   'agency',
#   'job',
#   'furthermore'],
#  ['destroyed',
#   'medical',
#   'educational',
#   'archive',
#   'etc',
#   'date',
#   'idf',
#   'announced',
#   'investigating',
#   'six',
#   'soldier',
#   'committed',
#   'unauthorised',
#   'looting',
#   'general',
#   'httpwww',
#   'httpwww',
#   'htm',
#   'httpwww',
#   'idf',
#   'vandal',
#   'thief',
#   'systematically',
#   'vandalised',
#   'premise',
#   'palestinian',
#   'authority',
#   'military',
#   'aimed',
#   'paralyse',
#   'fully',
#   'possible',
#   'palestinian',
#   'authority',
#   'violated',
#   'stole',
#   'computer',
#   'office',
#   'material'],
#  ['opposite',
#   'party',
#   'would',
#   'exactly',
#   'access',
#   'israel',
#   'file',
#   'wonder',
#   'israel',
#   'investigate',
#   'everything',
#   'possible',
#   'find',
#   'exactly',
#   'planned',
#   'terrorism',
#   'would',
#   'every',
#   'country',
#   'similar',
#   'situation',
#   'would',
#   'better',
#   'destruction',
#   'take',
#   'place',
#   'office',
#   'terrorist',
#   'killing',
#   'people',
#   'wouldnt'],
#  ['money',
#   'video',
#   'money',
#   'private',
#   'home',
#   'systematic',
#   'determination',
#   'data',
#   'bank',
#   'matter',
#   'personal',
#   'weakness',
#   'officer',
#   'soliders',
#   'let',
#   'write',
#   'mission',
#   'search',
#   'destroy',
#   'terror',
#   'read',
#   'money'],
#  ['ill',
#   'tell',
#   'whats',
#   'going',
#   'ill',
#   'tell',
#   'whats',
#   'going',
#   'ill',
#   'tell',
#   'whats',
#   'going',
#   'whats',
#   'matter'],
#  ['look',
#   'hard',
#   'knuckle',
#   'didnt',
#   'get',
#   'strength',
#   'kick',
#   'turned',
#   'head',
#   'looked',
#   'guy',
#   'socalled',
#   'madman',
#   'eye',
#   'ive',
#   'lot',
#   'experience',
#   'really',
#   'hard',
#   'place',
#   'avoid',
#   'guy',
#   'around',
#   'far',
#   'away',
#   'laughed',
#   'boy',
#   'went',
#   'away',
#   'got',
#   'cornered',
#   'guy',
#   'kicked',
#   'head',
#   'worked',
#   'year',
#   'get',
#   'little',
#   'bit',
#   'hand',
#   'take',
#   'revenge',
#   'kind',
#   'thing',
#   'going',
#   'around',
#   'long',
#   'way',
#   'maybe',
#   'get',
#   'couple',
#   'friend',
#   'shed',
#   'thing',
#   'happened',
#   'cant',
#   'seen'],
#  ['lot',
#   'people',
#   'would',
#   'happy',
#   'dont',
#   'think',
#   'black',
#   'wouldnt',
#   'cheap',
#   'rather',
#   'around',
#   'sometimes',
#   'itd',
#   'come',
#   'know',
#   'couple',
#   'familiar',
#   'russian',
#   'couple',
#   'hell',
#   'angel',
#   'could',
#   'feel',
#   'like',
#   'dont',
#   'think',
#   'worth',
#   'looking',
#   'like',
#   'get',
#   'loose',
#   'one',
#   'sure',
#   'ill',
#   'get',
#   'look',
#   'surveillance',
#   'tape',
#   'even',
#   'didnt',
#   'look',
#   'like',
#   'itt',
#   'look',
#   'like',
#   'going',
#   'guess',
#   'got',
#   'away',
#   'could',
#   'get',
#   'away',
#   'didnt',
#   'get',
#   'away'],
#  ['next',
#   'time',
#   'shoot',
#   'top',
#   'get',
#   'pepper',
#   'spray',
#   'something',
#   'like',
#   'hardly',
#   'sober'],
#  ['time',
#   'maybe',
#   'mild',
#   'one',
#   'public',
#   'prosecutor',
#   'job',
#   'really',
#   'shitty',
#   'job',
#   'youll',
#   'court',
#   'year',
#   'time',
#   'youll',
#   'see',
#   'guy',
#   'travel',
#   'pain',
#   'pain',
#   'pain',
#   'youll',
#   'able',
#   'claim',
#   'compensation',
#   'medical',
#   'expense',
#   'wont',
#   'matter',
#   'practice',
#   'youll',
#   'able',
#   'apply',
#   'restraining',
#   'judge',
#   'end',
#   'game',
#   'determine',
#   'otherwise',
#   'cant',
#   'say',
#   'anything',
#   'report',
#   'matter',
#   'police',
#   'considered',
#   'prosecutor',
#   'want',
#   'press',
#   'charge',
#   'cant',
#   'make',
#   'much',
#   'theret',
#   'much',
#   'protection',
#   'police',
#   'justice',
#   'case',
#   'need',
#   'doctor',
#   'certificate',
#   'injury',
#   'wouldnt',
#   'bad',
#   'witness',
#   'happened',
#   'youve',
#   'assaulted',
#   'public',
#   'place',
#   'youll',
#   'completely'],
#  ['threshold',
#   'pain',
#   'may',
#   'numb',
#   'gas',
#   'spray',
#   'effect',
#   'red',
#   'garment',
#   'bull',
#   'perhaps',
#   'personal',
#   'alarm',
#   'might',
#   'useful',
#   'keep',
#   'involved',
#   'best',
#   'thing',
#   'would',
#   'move',
#   'around',
#   'map',
#   'friend',
#   'take',
#   'foot',
#   'shout',
#   'devilishly',
#   'draw',
#   'attention',
#   'people',
#   'problem',
#   'use',
#   'handgun',
#   'gas',
#   'spray',
#   'reemerge',
#   'similar',
#   'situation',
#   'use',
#   'weapon',
#   'example',
#   'assault',
#   'bodily',
#   'injury',
#   'necessary',
#   'course',
#   'possession',
#   'first',
#   'influence',
#   'drug',
#   'killing',
#   'gas',
#   'spray',
#   'would',
#   'pawboard',
#   'exaggerating',
#   'emergency',
#   'guard',
#   'depending',
#   'situation'],
#  ['shortened', 'selfdefence', 'criminalized', 'finland'],
#  ['dont',
#   'think',
#   'going',
#   'bad',
#   'think',
#   'going',
#   'get',
#   'little',
#   'bit',
#   'even',
#   'dont',
#   'think',
#   'going',
#   'bad',
#   'guy',
#   'ought',
#   'able',
#   'get',
#   'line'],
#  ['youll',
#   'probably',
#   'try',
#   'settle',
#   'even',
#   'case',
#   'doesnt',
#   'youll',
#   'hardly',
#   'even',
#   'involved',
#   'investigation',
#   'least',
#   'next',
#   'time',
#   'youll',
#   'find',
#   'evidence',
#   'guy',
#   'complained',
#   'might',
#   'bit',
#   'question',
#   'boy',
#   'father',
#   'police',
#   'officer',
#   'always',
#   'leave',
#   'request',
#   'investigation',
#   'happens',
#   'well',
#   'going',
#   'cheap',
#   'start',
#   'taking',
#   'case',
#   'forward',
#   'want',
#   'move',
#   'forward',
#   'youd',
#   'like',
#   'report',
#   'police',
#   'might',
#   'protect',
#   'son',
#   'investigation',
#   'carried',
#   'painier',
#   'stand',
#   'way'],
#  ['funny',
#   'case',
#   'reflection',
#   'way',
#   'masa',
#   'took',
#   'neighbor',
#   'tire',
#   'garbage',
#   'explanation',
#   'style',
#   'seems',
#   'similar',
#   'liked',
#   'rubber',
#   'conversation',
#   'better'],
#  ['probably',
#   'something',
#   'get',
#   'trouble',
#   'done',
#   'also',
#   'say',
#   'thing',
#   'kind',
#   'interesting',
#   'mind',
#   'would',
#   'blackmail',
#   'nice',
#   'decision',
#   'boy',
#   'one',
#   'found',
#   'tire',
#   'let',
#   'blackmail',
#   'seems',
#   'reasonable',
#   'doubt',
#   'isnt',
#   'true',
#   'youre',
#   'wrong',
#   'yeah'],
#  ['abroad', 'dont', 'get', 'nose', 'easily'],
#  ['bilge',
#   'bilge',
#   'bilest',
#   'bilest',
#   'billy',
#   'bilest',
#   'bilest',
#   'billy',
#   'billy',
#   'bilest',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilest',
#   'bilge',
#   'bilge',
#   'daniel',
#   'took',
#   'away',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilge',
#   'bilest',
#   'bilest',
#   'bilest'],
#  ['youre',
#   'even',
#   'naive',
#   'stupid',
#   'expected',
#   'really',
#   'believe',
#   'urban',
#   'legend'],
#  ['mikkos', 'leaving', 'body'],
#  ['life', 'jesus', 'christ', 'yesterday', 'today', 'forever'],
#  ['christianity',
#   'saying',
#   'different',
#   'magic',
#   'mystic',
#   'strong',
#   'part',
#   'johan',
#   'steamheads',
#   'tried',
#   'refresh',
#   'boy',
#   'drowned',
#   'nokia',
#   'dont',
#   'know',
#   'one',
#   'could',
#   'expect',
#   'contributed',
#   'nnekas',
#   'stable',
#   'faith',
#   'daniel',
#   'come',
#   'life',
#   'whole',
#   'idea',
#   'seems',
#   'resisting',
#   'say',
#   'luckily',
#   'finland',
#   'trying',
#   'overturn',
#   'law',
#   'nature',
#   'original',
#   'religion',
#   'africa'],
#  ['example',
#   'medium',
#   'urban',
#   'legend',
#   'admissible',
#   'evidence',
#   'would',
#   'believe',
#   'awakening',
#   'dead',
#   'would',
#   'greater',
#   'interest',
#   'medium',
#   'evidence',
#   'story',
#   'mikko',
#   'death',
#   'certificate',
#   'breathed',
#   'old',
#   'man',
#   'story',
#   'given',
#   'greater',
#   'publicity',
#   'yes'],
#  ['terrible',
#   'time',
#   'different',
#   'alarm',
#   'placed',
#   'coffin',
#   'express',
#   'accident',
#   'body',
#   'dead',
#   'simply',
#   'medical',
#   'science',
#   'could',
#   'accurately',
#   'detect',
#   'death',
#   'wise',
#   'many',
#   'case',
#   'man',
#   'died',
#   'judgment',
#   'wrong'],
#  ['loan',
#   'olympus',
#   'camedia',
#   'cant',
#   'stupid',
#   'move',
#   'picture',
#   'machine',
#   'someone',
#   'give',
#   'advice',
#   'detail',
#   'quickly',
#   'really',
#   'grateful',
#   'even',
#   'little',
#   'tip',
#   'could',
#   'help',
#   'transfer',
#   'picture',
#   'take',
#   'place'],
#  ['power',
#   'camera',
#   'install',
#   'end',
#   'cable',
#   'camera',
#   'cfm',
#   'result',
#   'put',
#   'cable',
#   'machine',
#   'machine',
#   'first',
#   'install',
#   'program',
#   'open',
#   'program',
#   'image',
#   'appear',
#   'monitor',
#   'download',
#   'program',
#   'yet',
#   'httpcf',
#   'olympuseuropa'],
#  ['need',
#   'image',
#   'processing',
#   'feature',
#   'easy',
#   'download',
#   'image',
#   'digital',
#   'camera',
#   'computer',
#   'good',
#   'free',
#   'download',
#   'software',
#   'exists'],
#  ['get',
#   'driver',
#   'camera',
#   'home',
#   'page',
#   'tucows',
#   'get',
#   'downloaded',
#   'manufacturer',
#   'website',
#   'www',
#   'come',
#   'camera',
#   'window',
#   'also',
#   'recognizes',
#   'device',
#   'downloads',
#   'driver',
#   'camera',
#   'attached',
#   'machine',
#   'top',
#   'computer',
#   'good',
#   'convenient',
#   'viewing',
#   'program',
#   'irfanview',
#   'message'],
#  ['compact',
#   'flash',
#   'smartmedia',
#   'also',
#   'others',
#   'resource',
#   'management',
#   'drag',
#   'desired',
#   'image',
#   'machine',
#   'hard',
#   'drive',
#   'fit',
#   'different',
#   'card',
#   'jack',
#   'card',
#   'appears',
#   'hard',
#   'drive',
#   'easy',
#   'buy',
#   'card',
#   'reader',
#   'hybrid',
#   'reader'],
#  ['face',
#   'face',
#   'bof',
#   'unemployment',
#   'take',
#   'skill',
#   'arrogant',
#   'dare',
#   'claim',
#   'lazy',
#   'unemployed',
#   'people',
#   'bother',
#   'look',
#   'work',
#   'see',
#   'www',
#   'imf',
#   'report',
#   'pdfformaths',
#   'web',
#   'page',
#   'tyovoima',
#   'office',
#   'dare'],
#  ['head',
#   'delegation',
#   'finland',
#   'told',
#   'information',
#   'conference',
#   'imf',
#   'published',
#   'annual',
#   'country',
#   'report',
#   'finland',
#   'imf',
#   'concerned',
#   'rise',
#   'public',
#   'expenditure',
#   'finland',
#   'year',
#   'next',
#   'year',
#   'quickly',
#   'robert',
#   'feldman',
#   'monday',
#   'exacerbate',
#   'fiscal',
#   'policy',
#   'increase',
#   'expenditure',
#   'finland',
#   'return',
#   'strict',
#   'spending',
#   'policy',
#   'course',
#   'tax',
#   'reduction',
#   'mind',
#   'imf'],
#  ['part',
#   'statistic',
#   'statistic',
#   'statistic',
#   'development',
#   'cooperation',
#   'finland',
#   'finlandthe',
#   'article',
#   'consultation',
#   'written',
#   'copy',
#   'mail',
#   'mission',
#   'confucing',
#   'report',
#   'finland',
#   'imf',
#   'email',
#   'notification',
#   'subscribe',
#   'modify',
#   'subscription',
#   'discribes',
#   'preliminary',
#   'finding',
#   'imf',
#   'staff',
#   'understanding',
#   'certain',
#   'mission',
#   'official',
#   'staff',
#   'visit',
#   'member',
#   'country',
#   'mission',
#   'undertake',
#   'part',
#   'regular',
#   'usually',
#   'annual',
#   'consultation',
#   'article',
#   'imf',
#   'article',
#   'agreement',
#   'context',
#   'request',
#   'use',
#   'imf',
#   'resource',
#   'imf'],
#  ['exist',
#   'afford',
#   'phone',
#   'call',
#   'job',
#   'heh',
#   'imf',
#   'say',
#   'rich',
#   'unemployed',
#   'person',
#   'bother',
#   'look',
#   'job',
#   'rent',
#   'le',
#   'euro'],
#  ['take', 'labour', 'abroad', 'hehehe'],
#  ['poor',
#   'old',
#   'people',
#   'dying',
#   'young',
#   'likely',
#   'remain',
#   'rich',
#   'move',
#   'abroad',
#   'demand',
#   'fall',
#   'retire',
#   'le',
#   'worker',
#   'needed',
#   'production',
#   'product',
#   'service',
#   'unemployment',
#   'increasing',
#   'recession',
#   'deepening',
#   'country',
#   'bankrupting'],
#  ['true', 'working', 'party', 'sprayed'],
#  ['sdp',
#   'party',
#   'pyrists',
#   'even',
#   'short',
#   'term',
#   'child',
#   'care',
#   'long',
#   'accumulate',
#   'much',
#   'pocket',
#   'nothing',
#   'good',
#   'say',
#   'others',
#   'well',
#   'others',
#   'government',
#   'interested',
#   'power',
#   'personal',
#   'merit'],
#  ['cause',
#   'damage',
#   'spending',
#   'money',
#   'several',
#   'hundred',
#   'time',
#   'pay',
#   'even',
#   'several',
#   'hundred',
#   'time',
#   'superior',
#   'several',
#   'thousand',
#   'time',
#   'worker',
#   'state',
#   'municipality',
#   'even',
#   'work',
#   'much',
#   'unemployed'],
#  ['poor',
#   'wage',
#   'often',
#   'absurd',
#   'workload',
#   'true',
#   'worker',
#   'actually',
#   'working',
#   'result',
#   'municipal',
#   'consultant',
#   'expert',
#   'run',
#   'project',
#   'often',
#   'employ',
#   'many',
#   'people',
#   'long',
#   'time',
#   'tasan',
#   'yes',
#   'state',
#   'municipality'],
#  ['example',
#   'lot',
#   'work',
#   'municipality',
#   'need',
#   'done',
#   'distribution',
#   'social',
#   'security',
#   'money',
#   'everyone',
#   'exception',
#   'care',
#   'nurse',
#   'elderly',
#   'need',
#   'worker',
#   'visit',
#   'month',
#   'municipality',
#   'jep',
#   'connection',
#   'housing',
#   'allowance'],
#  ['real',
#   'unemployment',
#   'double',
#   'official',
#   'lie',
#   'would',
#   'paid',
#   'would',
#   'paid',
#   'unemployed',
#   'accordance',
#   'imf',
#   'financial',
#   'policy',
#   'also',
#   'taken',
#   'away',
#   'course',
#   'monetary',
#   'fund',
#   'forced',
#   'training',
#   'unemployed',
#   'emptyday',
#   'school',
#   'teacher',
#   'cant',
#   'stay',
#   'sober',
#   'hour',
#   'instruction',
#   'owner',
#   'make',
#   'large',
#   'sum',
#   'state',
#   'money',
#   'pocket',
#   'unpaid',
#   'forced',
#   'labour'],
#  ['part',
#   'statistic',
#   'statistic',
#   'statistic',
#   'development',
#   'cooperation',
#   'finland',
#   'finlandthe',
#   'article',
#   'consultation',
#   'written',
#   'copy',
#   'mail',
#   'mission',
#   'confucing',
#   'report',
#   'finland',
#   'imf',
#   'email',
#   'notification',
#   'subscribe',
#   'modify',
#   'subscription',
#   'discribes',
#   'preliminary',
#   'finding',
#   'imf',
#   'staff',
#   'understanding',
#   'certain',
#   'mission',
#   'official',
#   'staff',
#   'visit',
#   'member',
#   'country',
#   'mission',
#   'undertake',
#   'part',
#   'regular',
#   'usually',
#   'annual',
#   'consultation',
#   'article',
#   'imf',
#   'article',
#   'agreement',
#   'context',
#   'request',
#   'use',
#   'imf',
#   'resource',
#   'imf'],
#  ['sudden',
#   'forgotten',
#   'without',
#   'getting',
#   'increase',
#   'pension',
#   'interest',
#   'follow',
#   'missing',
#   'part',
#   'putter',
#   'emerges',
#   'lahti',
#   'however',
#   'wonderful',
#   'saving',
#   'line',
#   'necessary',
#   'benefit',
#   'law',
#   'given',
#   'denied',
#   'one',
#   'watch',
#   'care',
#   'city',
#   'save',
#   'completely',
#   'ridiculous',
#   'arbitrariness',
#   'based',
#   'social',
#   'benefit',
#   'faceass',
#   'licking',
#   'coefficient',
#   'example'],
#  ['would',
#   'made',
#   'would',
#   'paid',
#   'according',
#   'international',
#   'monetary',
#   'school',
#   'according',
#   'imf',
#   'financial',
#   'policy',
#   'finland',
#   'going',
#   'sucking',
#   'away',
#   'course',
#   'current',
#   'financial',
#   'year',
#   'increase',
#   'amount',
#   'money',
#   'spent',
#   'imf',
#   'would',
#   'reported',
#   'huge',
#   'increase',
#   'amount',
#   'money',
#   'spent',
#   'government',
#   'pocket',
#   'unpaid',
#   'forced',
#   'labour'],
#  ...]

# %%
# Applying Bigrams and trigrams 
bigram=gensim.models.Phrases(data_words_nostops,min_count=5,threshold=80)
trigram=gensim.models.Phrases(bigram[data_words_nostops],threshold=80)

bigram_mod=gensim.models.phrases.Phraser(bigram)
trigram_mod=gensim.models.phrases.Phraser(trigram)

def make_bigram(texts):
    return [bigram_mod[doc] for doc in texts]

def make_trigram(texts):
    return [trigram_mod[doc] for doc in texts]

data_words_nostops_bigrams=make_bigram(data_words_nostops)
data_words_nostops_trigrams=make_bigram(data_words_nostops_bigrams)

# %%
bigram_phrases = [phrase for phrase, score in bigram.vocab.items() if '_' in phrase]

# %%
bigram_phrases
# Out:
# ['important_piece',
#  'piece_evidence',
#  'evidence_front',
#  'front_gate',
#  'gate_fall',
#  'fall_depth',
#  'depth_sea',
#  'sea_helicopter',
#  'helicopter_carried',
#  'carried_question',
#  'question_estonia',
#  'estonia_isnt',
#  'isnt_estonia',
#  'estonia_ship',
#  'ship_world',
#  'world_immediately',
#  'immediately_held',
#  'held_peace',
#  'peace_grave',
#  'grave_border',
#  'border_guard',
#  'guard_prevent',
#  'prevent_investigation',
#  'investigation_independent',
#  'independent_company',
#  'company_area',
#  'area_protected',
#  'protected_socalled',
#  'socalled_burial',
#  'burial_peace',
#  'peace_repeatedly',
#  'repeatedly_invoked',
#  'invoked_even',
#  'even_though',
#  'though_relative',
#  'relative_wanted',
#  'wanted_study',
#  'study_matter',
#  'matter_one',
#  'one_theory',
#  'theory_sinking',
#  'sinking_even',
#  'though_controversial',
#  'controversial_flashed',
#  'flashed_public',
#  'public_domain',
#  'domain_truth',
#  'truth_didnt',
#  'didnt_anyone',
#  'anyone_get',
#  'get_saved',
#  'saved_bridge',
#  'bridge_command',
#  'command_even',
#  'though_advantage',
#  'advantage_image',
#  'image_given',
#  'given_public',
#  'public_couple',
#  'couple_stormy',
#  'stormy_image',
#  'think_thing',
#  'thing_first',
#  'first_kin',
#  'kin_demanded',
#  'demanded_sepulchre',
#  'sepulchre_would',
#  'would_rejected',
#  'rejected_independent',
#  'independent_picture',
#  'picture_bottom',
#  'bottom_wreck',
#  'wreck_taken',
#  'taken_lightning',
#  'lightning_light',
#  'light_fear',
#  'fear_scuba',
#  'scuba_dive',
#  'dive_invasion',
#  'invasion_wreckage',
#  'wreckage_would',
#  'would_able',
#  'able_save',
#  'save_accident',
#  'accident_first',
#  'first_investigating',
#  'investigating_authority',
#  'authority_television',
#  'television_company',
#  'company_dont',
#  'dont_wonder',
#  'wonder_gate',
#  'gate_raised',
#  'raised_thing',
#  'thing_stormy',
#  'stormy_thing',
#  'thing_thing',
#  'thing_small',
#  'small_group',
#  'group_would',
#  'would_keep',
#  'keep_sound',
#  'sound_suggest',
#  'suggest_amazing',
#  'amazing_theory',
#  'theory_thing',
#  'thing_argument',
#  'argument_thing',
#  'thing_many',
#  'many_night',
#  'night_excited',
#  'excited_describe',
#  'describe_would',
#  'would_still',
#  'still_continue',
#  'continue_part',
#  'part_addition',
#  'bow_gate',
#  'gate_sarana',
#  'sarana_strange',
#  'strange_coincidence',
#  'coincidence_fell',
#  'fell_research',
#  'research_helicopter',
#  'helicopter_deep',
#  'deep_sea',
#  'sea_couldnt',
#  'couldnt_saved',
#  'saved_reason',
#  'reason_thing',
#  'thing_storm',
#  'storm_world',
#  'world_reason',
#  'reason_ordeal',
#  'ordeal_reason',
#  'ordeal_loved',
#  'loved_one',
#  'one_wanted',
#  'wanted_proper',
#  'proper_burial',
#  'peace_per',
#  'per_cent',
#  'cent_want',
#  'want_proper',
#  'proper_study',
#  'study_wanted',
#  'wanted_first',
#  'first_body',
#  'body_hyly',
#  'hyly_lifting',
#  'lifting_holding',
#  'holding_small',
#  'small_river',
#  'river_actually',
#  'actually_per',
#  'per_caput',
#  'caput_look',
#  'look_leaf',
#  'leaf_without',
#  'without_chewing',
#  'chewing_touch',
#  'touch_want',
#  'want_believe',
#  'believe_mus',
#  'mus_wanted',
#  'wanted_believe',
#  'believe_grave',
#  'grave_peace',
#  'peace_several',
#  'several_oath',
#  'oath_staff',
#  'staff_tell',
#  'tell_reason',
#  'storm_reason',
#  'storm_middle',
#  'middle_year',
#  'year_didnt',
#  'didnt_give',
#  'give_good',
#  'good_picture',
#  'picture_happened',
#  'ill_tell',
#  'tell_whats',
#  'whats_going',
#  'going_ill',
#  'tell_whatll',
#  'whatll_news',
#  'let_cause',
#  'cause_sinking',
#  'sinking_ship',
#  'ship_lifted',
#  'lifted_away',
#  'away_wreckage',
#  'wreckage_left',
#  'left_sea',
#  'therell_lot',
#  'lot_ill',
#  'ill_bet',
#  'bet_youll',
#  'youll_bet',
#  'bet_concrete',
#  'concrete_thats',
#  'thats_going',
#  'going_look',
#  'look_ill',
#  'ill_lot',
#  'lot_therell',
#  'lot_said',
#  'said_ill',
#  'tell_ill',
#  'youll_lot',
#  'lot_itll',
#  'itll_lot',
#  'reason_ill',
#  'bet_nothing',
#  'nothing_else',
#  'else_ill',
#  'bet_therell',
#  'therell_ill',
#  'lot_thing',
#  'thing_ill',
#  'ill_betll',
#  'betll_bet',
#  'bet_ill',
#  'whats_big',
#  'big_deal',
#  'reason_going',
#  'going_lot',
#  'lot_thats',
#  'going_happen',
#  'happen_like',
#  'like_thats',
#  'happen_reason',
#  'look_look',
#  'look_road',
#  'road_look',
#  'look_much',
#  'much_look',
#  'look_going',
#  'look_whats',
#  'going_front',
#  'front_look',
#  'front_short',
#  'short_ago',
#  'ago_thats',
#  'thats_look',
#  'look_bit',
#  'bit_accident',
#  'accident_look',
#  'dont_know',
#  'know_lehtola',
#  'lehtola_missed',
#  'missed_fact',
#  'fact_estonia',
#  'estonia_built',
#  'built_iron',
#  'iron_filled',
#  'filled_water',
#  'water_model',
#  'model_carpenter',
#  'carpenter_wood',
#  'wood_soaking',
#  'soaking_water',
#  'water_long',
#  'long_time',
#  'time_went',
#  'went_bottom',
#  'bottom_lehtola',
#  'lehtola_told',
#  'told_made',
#  'made_model',
#  'model_wood',
#  'wood_estonia',
#  'estonia_prove',
#  'prove_suspicion',
#  'suspicion_reason',
#  'reason_estonia',
#  'estonia_sinking',
#  'sinking_least',
#  'least_dont',
#  'dont_believe',
#  'believe_trust',
#  'trust_result',
#  'result_research',
#  'research_group',
#  'group_lehtola',
#  'lehtola_leader',
#  'leader_old',
#  'old_man',
#  'man_full',
#  'full_toilet',
#  'give_right',
#  'right_idea',
#  'idea_perspective',
#  'perspective_might',
#  'might_want',
#  'want_vtt',
#  'vtt_laugh',
#  'laugh_theyre',
#  'theyre_going',
#  'going_ashamed',
#  'ashamed_planning',
#  'planning_research',
#  'research_also',
#  'also_excellent',
#  'excellent_idea',
#  'idea_knock',
#  'knock_everyone',
#  'everyone_doesnt',
#  'doesnt_like',
#  'like_face',
#  'would_point',
#  'point_accident',
#  'accident_would',
#  'would_result',
#  'result_accident',
#  'accident_read',
#  'read_read',
#  'read_exciting',
#  'exciting_thing',
#  'thing_believe',
#  'believe_however',
#  'however_many',
#  'many_rabe',
#  'rabe_activity',
#  'activity_following',
#  'following_small',
#  'small_boat',
#  'boat_think',
#  'think_telakka',
#  'telakka_official',
#  'official_matter',
#  'matter_million',
#  'million_people',
#  'people_already',
#  'already_read',
#  'read_perhaps',
#  'perhaps_want',
#  'want_hide',
#  'hide_would',
#  'result_would',
#  'would_happened',
#  'happened_panic',
#  'panic_point',
#  'point_sinking',
#  'sinking_estonia',
#  'estonia_nothing',
#  'nothing_ashamed',
#  'ashamed_lie',
#  'lie_wall',
#  'wall_would',
#  'point_would',
#  'happened_tour',
#  'tour_trip',
#  'trip_away',
#  'away_one',
#  'one_far',
#  'far_made',
#  'made_guess',
#  'guess_various',
#  'various_interest',
#  'interest_group',
#  'group_evidence',
#  'evidence_would',
#  'would_investigated',
#  'investigated_already',
#  'already_germany',
#  'germany_official',
#  'official_position',
#  'etc_believe',
#  'believe_explanation',
#  'explanation_much',
#  'much_simpler',
#  'simpler_could',
#  'could_short',
#  'short_time',
#  'time_could',
#  'could_developed',
#  'developed_decaying',
#  'decaying_gas',
#  'gas_odor',
#  'odor_explosion',
#  'explosion_silenced',
#  'silenced_way',
#  'way_bomber',
#  'bomber_fence',
#  'fence_bomber',
#  'bomber_car',
#  'car_still',
#  'still_way',
#  'way_could',
#  'could_even',
#  'even_something',
#  'something_would',
#  'would_happen',
#  'happen_thing',
#  'thing_bomber',
#  'bomber_nothing',
#  'nothing_look',
#  'look_several',
#  'several_passenger',
#  'passenger_crew',
#  'crew_member',
#  'member_saved',
#  'saved_mentioned',
#  'mentioned_psychological',
#  'psychological_crisis',
#  'crisis_group',
#  'group_sinking',
#  'sinking_spot',
#  'spot_dark',
#  'dark_smell',
#  'smell_terrorism',
#  'terrorism_terrorist',
#  'terrorist_even',
#  'even_single',
#  'single_madman',
#  'madman_blew',
#  'blew_bomb',
#  'bomb_car',
#  'car_deck',
#  'deck_many',
#  'many_people',
#  'people_claimed',
#  'claimed_nuclear',
#  'nuclear_weapon',
#  'weapon_plutonium',
#  'plutonium_agent',
#  'agent_large',
#  'large_drug',
#  'drug_load',
#  'load_sunk',
#  'look_saying',
#  'saying_nothing',
#  'look_big',
#  'deal_whats',
#  'going_mean',
#  'mean_million',
#  'people_would',
#  'would_come',
#  'come_long',
#  'time_evidence',
#  'evidence_far',
#  'far_point',
#  'point_view',
#  'view_would',
#  'investigated_sure',
#  'sure_whats',
#  'going_big',
#  'going_rabens',
#  'rabens_activity',
#  'activity_followed',
#  'followed_water',
#  'water_sure',
#  'going_whats',
#  'going_already',
#  'already_million',
#  'people_read',
#  'read_big',
#  'deal_maybe',
#  'maybe_theyre',
#  'theyre_wanting',
#  'wanting_keep',
#  'keep_matter',
#  'matter_holding',
#  'estonia_file',
#  'file_report',
#  'report_downloaded',
#  'downloaded_pdf',
#  'pdf_finnish',
#  'finnish_safety',
#  'safety_investigation',
#  'investigation_authority',
#  'authority_website',
#  'website_attachment',
#  'attachment_missing',
#  'missing_www',
#  'www_unfortunately',
#  'unfortunately_also',
#  'also_obtained',
#  'obtained_location',
#  'location_ask',
#  'charge_commission',
#  'commission_remainder',
#  'remainder_uno',
#  'uno_laur',
#  'laur_finnish',
#  'finnish_member',
#  'member_commission',
#  'commission_kari',
#  'kari_lehtola',
#  'lehtola_director',
#  'director_accident',
#  'accident_investigation',
#  'investigation_centre',
#  'centre_whose',
#  'whose_madness',
#  'madness_cannot',
#  'cannot_say',
#  'say_anything',
#  'anything_estonian',
#  'estonian_initially',
#  'initially_andi',
#  'andi_meister',
#  'meister_second',
#  'telling_youm',
#  'youm_telling',
#  'telling_telling',
#  'telling_itm',
#  'itm_telling',
#  'telling_itre',
#  'itre_gonna',
#  'gonna_telling',
#  'telling_youre',
#  'youre_gonna',
#  'gonna_itre',
#  'gonna_something',
#  'something_gonna',
#  'gonna_gonna',
#  'something_thats',
#  'thats_gonna',
#  'gonna_going',
#  'happen_something',
#  'something_something',
#  'happen_going',
#  'going_get',
#  'get_going',
#  'going_going',
#  'going_something',
#  'something_else',
#  'else_going',
#  'something_going',
#  'something_thing',
#  'thing_saying',
#  'saying_telling',
#  'evidence_found',
#  'found_sense',
#  'sense_estonia',
#  'estonia_leaf',
#  'leaf_sea',
#  'sea_pressure',
#  'pressure_left',
#  'left_behind',
#  'behind_ramp',
#  'ramp_broke',
#  'broke_bow',
#  'gate_behind',
#  'behind_smell',
#  'smell_brittle',
#  'brittle_stuff',
#  'stuff_also',
#  'also_worth',
#  'worth_noting',
#  'noting_experience',
#  'experience_narrator',
#  'narrator_brittle',
#  'brittle_smell',
#  'smell_ship',
#  'ship_corsts',
#  'corsts_still',
#  'still_long',
#  'long_main',
#  'main_engine',
#  'engine_stopped',
#  'stopped_really',
#  'really_strange',
#  'strange_bomb',
#  'bomb_ive',
#  'ive_said',
#  'said_hand',
#  'hand_knowledge',
#  'knowledge_youth',
#  'youth_year',
#  'year_came',
#  'came_smell',
#  'smell_smelled',
#  'smelled_corstene',
#  'corstene_painting',
#  'painting_blast',
#  'blast_vest',
#  'vest_manual',
#  'manual_lock',
#  'lock_left',
#  'behind_would',
#  'would_blown',
#  'blown_keulaport',
#  'keulaport_closed',
#  'closed_left',
#  'behind_hydraulics',
#  'hydraulics_locking',
#  'locking_hook',
#  'good_tip',
#  'tip_interested',
#  'interested_people',
#  'telling_something',
#  'something_telling',
#  'else_telling',
#  'reference_evidence',
#  'evidence_thing',
#  'thing_could',
#  'could_different',
#  'different_report',
#  'report_youre',
#  'youre_going',
#  'going_youre',
#  'going_long',
#  'time_basic',
#  'basic_concept',
#  'concept_investigation',
#  'investigation_court',
#  'court_based',
#  'based_event',
#  'event_reliably',
#  'reliably_explained',
#  'explained_lot',
#  'lot_report',
#  'report_contrast',
#  'contrast_theory',
#  'theory_thrown',
#  'thrown_way',
#  'way_youve',
#  'youve_read',
#  'read_report',
#  'report_already',
#  'already_mentioned',
#  'mentioned_strange',
#  'bomb_breaking',
#  'breaking_front',
#  'front_door',
#  'door_ramp',
#  'ramp_front',
#  'front_komporomist',
#  'komporomist_report',
#  'report_dont',
#  'dont_comment',
#  'comment_staff',
#  'staff_say',
#  'say_comment',
#  'comment_nice',
#  'nice_laugh',
#  'laugh_first',
#  'first_look',
#  'look_guilty',
#  'guilty_youre',
#  'youre_looking',
#  'looking_something',
#  'believe_organization',
#  'organization_behind',
#  'behind_thats',
#  'thats_taken',
#  'taken_reference',
#  'evidence_could',
#  'dont_sink',
#  'sink_truck',
#  'truck_stamp',
#  'stamp_participant',
#  'participant_secretor',
#  'secretor_information',
#  'information_lot',
#  'lot_done',
#  'done_long',
#  'time_indiscretion',
#  'indiscretion_youre',
#  'looking_guilty',
#  'youre_today',
#  'today_theyve',
#  'theyve_sunk',
#  'sunk_inconceivable',
#  'inconceivable_reason',
#  'reason_hey',
#  'hey_boy',
#  'boy_yes',
#  'yes_evidence',
#  'evidence_report',
#  'report_tiij',
#  'wonder_many',
#  'many_explosive',
#  'explosive_use',
#  'use_sulfur',
#  'sulfur_make',
#  'make_bow',
#  'bow_port',
#  'port_fail',
#  'fail_truckloads',
#  'truckloads_black',
#  'black_powder',
#  'powder_driven',
#  'driven_car',
#  'deck_smell',
#  'smell_rotten',
#  'rotten_egg',
#  'egg_theory',
#  'theory_suggests',
#  'suggests_bowgate',
#  'bowgate_blown',
#  'blown_black',
#  'yes_dirt',
#  'dirt_thrown',
#  'thrown_side',
#  'side_way',
#  'way_around',
#  'around_win',
#  'thing_ostststre',
#  'ostststre_ostrich',
#  'ostrich_thing',
#  'thing_ostrich',
#  'ostrich_therest',
#  'therest_ost',
#  'ost_thing',
#  'ostrich_ostrich',
#  'car_thief',
#  'thief_speed',
#  'speed_restriction',
#  'restriction_calculated',
#  'calculated_tolerance',
#  'tolerance_tightened',
#  'tightened_need',
#  'need_car',
#  'car_model',
#  'model_speeding',
#  'speeding_driver',
#  'driver_able',
#  'able_catch',
#  'catch_lot',
#  'lot_drunk',
#  'drunk_driver',
#  'driver_majority',
#  'majority_road',
#  'road_user',
#  'user_think',
#  'think_meaningful',
#  'meaningful_anymore',
#  'anymore_honest',
#  'honest_control',
#  'control_preferably',
#  'preferably_visibly',
#  'visibly_another',
#  'another_thing',
#  'thing_automatic',
#  'automatic_control',
#  'control_cashing',
#  'cashing_automatic',
#  'automatic_speed',
#  'speed_control',
#  'control_contribute',
#  'contribute_road',
#  'road_safety',
#  'safety_extent',
#  'extent_acceptable',
#  'acceptable_noticed',
#  'noticed_police',
#  'police_even',
#  'even_look',
#  'look_reasonable',
#  'reasonable_speed',
#  'speed_see',
#  'see_situation',
#  'situation_allowing',
#  'allowing_without',
#  'without_risk',
#  'risk_remember',
#  'remember_counterfeit',
#  'counterfeit_dollar',
#  'dollar_thing',
#  'thing_went',
#  'went_year',
#  'year_ago',
#  'ago_villain',
#  'villain_ran',
#  'ran_radar',
#  'radar_car',
#  'car_load',
#  'load_fake',
#  'fake_police',
#  'police_enough',
#  'enough_fine',
#  'fine_large',
#  'large_number',
#  'number_road',
#  'user_personally',
#  'teach_child',
#  'child_walk',
#  'walk_traffic',
#  'traffic_light',
#  'light_anymore',
#  'anymore_automonitoring',
#  'automonitoring_increased',
#  'increased_urban',
#  'urban_area',
#  'area_road',
#  'road_especially',
#  'especially_necessary',
#  'necessary_useful',
#  'useful_would',
#  'would_traffic',
#  'light_driving',
#  'driving_red',
#  'red_become',
#  'become_way',
#  'way_country',
#  'risk_speeding',
#  'speeding_ticket',
#  'ticket_minimized',
#  'minimized_course',
#  'course_automatic',
#  'control_addition',
#  'addition_dangerous',
#  'dangerous_unnecessary',
#  'unnecessary_constant',
#  'constant_speed',
#  'control_safe',
#  'safe_well',
#  'well_run',
#  'run_legal',
#  'legal_every',
#  'every_pas',
#  'pas_requires',
#  'requires_speeding',
#  'speeding_succeed',
#  'succeed_safely',
#  'safely_unnecessary',
#  'unnecessary_many',
#  'many_marmattatas',
#  'marmattatas_fact',
#  'fact_range',
#  'range_run',
#  'run_illegal',
#  'afford_drive',
#  'drive_speeding',
#  'speeding_would',
#  'would_lead',
#  'lead_fine',
#  'fine_kmh',
#  'kmh_speed',
#  'speed_limit',
#  'limit_nobody',
#  'nobody_drive',
#  'drive_kmh',
#  'kmh_time',
#  'time_difference',
#  'difference_distance',
#  'distance_minute',
#  'minute_exactly',
#  'exactly_time',
#  'time_kmh',
#  'kmh_kmh',
#  'kmh_really',
#  'really_understand',
#  'understand_current',
#  'current_speed',
#  'control_tax',
#  'tax_burden',
#  'burden_others',
#  'others_reduced',
#  'reduced_accordingly',
#  'accordingly_even',
#  'even_small',
#  'small_speeding',
#  'speeding_fuel',
#  'fuel_saved',
#  'saved_cost',
#  'cost_safer',
#  'safer_everyone',
#  'everyone_studied',
#  'studied_zero',
#  'zero_tolerance',
#  'tolerance_afford',
#  'afford_pay',
#  'pay_fine',
#  'though_dont',
#  'dont_radar',
#  'radar_detector',
#  'detector_even',
#  'even_scanner',
#  'scanner_otherwise',
#  'otherwise_know',
#  'know_way',
#  'way_cop',
#  'cop_cost',
#  'cost_nice',
#  'nice_feeling',
#  'feeling_get',
#  'get_little',
#  'little_bit',
#  'bit_dim',
#  'dim_camera',
#  'camera_tear',
#  'tear_slowly',
#  'slowly_case',
#  'case_cross',
#  'cross_get',
#  'get_least',
#  'least_kmh',
#  'kmh_high',
#  'high_speed',
#  'see_red',
#  'red_lower',
#  'lower_lens',
#  'lens_know',
#  'know_camera',
#  'camera_place',
#  'place_change',
#  'change_place',
#  'place_least',
#  'least_expense',
#  'expense_surveillance',
#  'surveillance_dont',
#  'dont_get',
#  'get_many',
#  'many_speeding',
#  'ticket_cant',
#  'cant_easily',
#  'easily_let',
#  'let_dont',
#  'dont_drive',
#  'drive_much',
#  'much_away',
#  'away_know',
#  'camera_could',
#  'could_add',
#  'add_camera',
#  'camera_every',
#  'every_case',
#  'real_apig',
#  'apig_expert',
#  'expert_funny',
#  'funny_thing',
#  'else_wheel',
#  'wheel_look',
#  'look_meter',
#  'meter_youre',
#  'youre_ride',
#  'ride_force',
#  'force_look',
#  'meter_scream',
#  'scream_start',
#  'start_going',
#  'going_limit',
#  'limit_mean',
#  'comment_fuck',
#  'fuck_youll',
#  'youll_get',
#  'get_kicked',
#  'kicked_walk',
#  'pay_driver',
#  'driver_made',
#  'made_commitment',
#  'commitment_traffic',
#  'traffic_offence',
#  'offence_signing',
#  'signing_licence',
#  'licence_application',
#  'application_got',
#  'got_automatic',
#  'automatic_fine',
#  'fine_police',
#  'police_officer',
#  'officer_every',
#  'every_villain',
#  'villain_long',
#  'long_demand',
#  'demand_harm',
#  'harm_would',
#  'would_automatic',
#  'control_money',
#  'money_probably',
#  'probably_bad',
#  'bad_guy',
#  'guy_would',
#  'would_caught',
#  'caught_faster',
#  'faster_speed',
#  'control_much',
#  'much_know',
#  'know_automatic',
#  'control_improve',
#  'improve_road',
#  'safety_enough',
#  'enough_scarce',
#  'scarce_resource',
#  'resource_company',
#  'company_handicrafted',
#  'handicrafted_extreme',
#  'extreme_end',
#  'end_day',
#  'day_automatic',
#  'fine_also',
#  'also_offered',
#  'offered_agreed',
#  'agreed_rule',
#  'rule_game',
#  'game_cannot',
#  'cannot_complied',
#  'mostly_due',
#  'due_heavy',
#  'heavy_hop',
#  'hop_time',
#  'time_got',
#  'got_ticket',
#  'ticket_driving',
#  ...]

# %%
trigram_phrases = [phrase for phrase, score in trigram.vocab.items() if '_' in phrase]

# %%
trigram_phrases
# Out:
# ['important_piece',
#  'piece_evidence',
#  'evidence_front',
#  'front_gate',
#  'gate_fall',
#  'fall_depth',
#  'depth_sea',
#  'sea_helicopter',
#  'helicopter_carried',
#  'carried_question',
#  'question_estonia',
#  'estonia_isnt',
#  'isnt_estonia',
#  'estonia_ship',
#  'ship_world',
#  'world_immediately',
#  'immediately_held',
#  'held_peace',
#  'peace_grave',
#  'grave_border',
#  'border_guard',
#  'guard_prevent',
#  'prevent_investigation',
#  'investigation_independent',
#  'independent_company',
#  'company_area',
#  'area_protected',
#  'protected_socalled',
#  'burial_peace',
#  'socalled_burial_peace',
#  'burial_peace_repeatedly',
#  'repeatedly_invoked',
#  'invoked_even',
#  'even_though',
#  'though_relative',
#  'relative_wanted',
#  'wanted_study',
#  'study_matter',
#  'matter_one',
#  'one_theory',
#  'theory_sinking',
#  'sinking_even',
#  'though_controversial',
#  'controversial_flashed',
#  'public_domain',
#  'flashed_public_domain',
#  'public_domain_truth',
#  'truth_didnt',
#  'didnt_anyone',
#  'anyone_get',
#  'get_saved',
#  'saved_bridge',
#  'bridge_command',
#  'command_even',
#  'though_advantage',
#  'advantage_image',
#  'image_given',
#  'given_public',
#  'public_couple',
#  'couple_stormy',
#  'stormy_image',
#  'think_thing',
#  'thing_first',
#  'first_kin',
#  'kin_demanded',
#  'demanded_sepulchre',
#  'sepulchre_would',
#  'would_rejected',
#  'rejected_independent',
#  'independent_picture',
#  'picture_bottom',
#  'bottom_wreck',
#  'wreck_taken',
#  'taken_lightning',
#  'lightning_light',
#  'light_fear',
#  'fear_scuba',
#  'scuba_dive',
#  'dive_invasion',
#  'invasion_wreckage',
#  'wreckage_would',
#  'would_able',
#  'able_save',
#  'save_accident',
#  'accident_first',
#  'first_investigating',
#  'investigating_authority',
#  'authority_television',
#  'television_company',
#  'company_dont',
#  'dont_wonder',
#  'wonder_gate',
#  'gate_raised',
#  'raised_thing',
#  'thing_stormy',
#  'stormy_thing',
#  'thing_thing',
#  'thing_small',
#  'small_group',
#  'group_would',
#  'would_keep',
#  'keep_sound',
#  'sound_suggest',
#  'suggest_amazing',
#  'amazing_theory',
#  'theory_thing',
#  'thing_argument',
#  'argument_thing',
#  'thing_many',
#  'many_night',
#  'night_excited',
#  'excited_describe',
#  'describe_would',
#  'would_still',
#  'still_continue',
#  'continue_part',
#  'part_addition',
#  'bow_gate',
#  'gate_sarana',
#  'sarana_strange',
#  'strange_coincidence',
#  'coincidence_fell',
#  'fell_research',
#  'research_helicopter',
#  'helicopter_deep',
#  'deep_sea',
#  'sea_couldnt',
#  'couldnt_saved',
#  'saved_reason',
#  'reason_thing',
#  'thing_storm',
#  'storm_world',
#  'world_reason',
#  'reason_ordeal',
#  'ordeal_reason',
#  'ordeal_loved',
#  'loved_one',
#  'one_wanted',
#  'wanted_proper',
#  'proper_burial_peace',
#  'per_cent',
#  'burial_peace_per_cent',
#  'per_cent_want',
#  'want_proper',
#  'proper_study',
#  'study_wanted',
#  'wanted_first',
#  'first_body',
#  'body_hyly',
#  'hyly_lifting',
#  'lifting_holding',
#  'holding_small',
#  'small_river',
#  'river_actually',
#  'per_caput',
#  'actually_per_caput',
#  'per_caput_look',
#  'look_leaf',
#  'leaf_without',
#  'without_chewing',
#  'chewing_touch',
#  'touch_want',
#  'want_believe',
#  'believe_mus',
#  'mus_wanted',
#  'wanted_believe',
#  'believe_grave',
#  'grave_peace',
#  'peace_several',
#  'several_oath',
#  'oath_staff',
#  'staff_tell',
#  'tell_reason',
#  'storm_reason',
#  'storm_middle',
#  'middle_year',
#  'year_didnt',
#  'didnt_give',
#  'give_good',
#  'good_picture',
#  'picture_happened',
#  'ill_tell',
#  'tell_whats',
#  'whats_going',
#  'going_ill',
#  'tell_whatll',
#  'ill_tell_whatll',
#  'tell_whatll_news',
#  'let_cause',
#  'sinking_ship',
#  'cause_sinking_ship',
#  'sinking_ship_lifted',
#  'lifted_away',
#  'away_wreckage',
#  'wreckage_left',
#  'left_sea',
#  'therell_lot',
#  'lot_ill',
#  'ill_bet',
#  'bet_youll',
#  'youll_bet',
#  'bet_concrete',
#  'concrete_thats',
#  'thats_going',
#  'going_look',
#  'look_ill',
#  'ill_lot',
#  'lot_therell',
#  'lot_said',
#  'said_ill',
#  'tell_ill',
#  'youll_lot',
#  'lot_itll',
#  'itll_lot',
#  'reason_ill',
#  'bet_nothing',
#  'nothing_else',
#  'else_ill',
#  'bet_therell',
#  'therell_ill',
#  'lot_thing',
#  'thing_ill',
#  'betll_bet',
#  'ill_betll_bet',
#  'betll_bet_therell',
#  'bet_ill',
#  'big_deal',
#  'whats_big_deal',
#  'reason_going',
#  'going_lot',
#  'lot_thats',
#  'going_happen',
#  'happen_like',
#  'like_thats',
#  'happen_reason',
#  'look_look',
#  'look_road',
#  'road_look',
#  'look_much',
#  'much_look',
#  'look_going',
#  'look_whats',
#  'going_front',
#  'front_look',
#  'front_short',
#  'short_ago',
#  'ago_thats',
#  'thats_look',
#  'look_bit',
#  'bit_accident',
#  'accident_look',
#  'dont_know',
#  'know_lehtola',
#  'lehtola_missed',
#  'missed_fact',
#  'fact_estonia',
#  'estonia_built',
#  'built_iron',
#  'iron_filled',
#  'filled_water',
#  'water_model',
#  'model_carpenter',
#  'carpenter_wood',
#  'wood_soaking',
#  'soaking_water',
#  'water_long',
#  'long_time',
#  'time_went',
#  'went_bottom',
#  'bottom_lehtola',
#  'lehtola_told',
#  'told_made',
#  'made_model',
#  'model_wood',
#  'wood_estonia',
#  'estonia_prove',
#  'prove_suspicion',
#  'suspicion_reason',
#  'estonia_sinking',
#  'reason_estonia_sinking',
#  'estonia_sinking_least',
#  'least_dont',
#  'dont_believe',
#  'believe_trust',
#  'trust_result',
#  'result_research',
#  'research_group',
#  'group_lehtola',
#  'lehtola_leader',
#  'leader_old',
#  'old_man',
#  'man_full',
#  'full_toilet',
#  'give_right',
#  'right_idea',
#  'idea_perspective',
#  'perspective_might',
#  'might_want',
#  'want_vtt',
#  'vtt_laugh',
#  'laugh_theyre',
#  'theyre_going',
#  'going_ashamed',
#  'ashamed_planning',
#  'planning_research',
#  'research_also',
#  'also_excellent',
#  'excellent_idea',
#  'idea_knock',
#  'knock_everyone',
#  'everyone_doesnt',
#  'doesnt_like',
#  'like_face',
#  'would_point',
#  'point_accident',
#  'accident_would',
#  'would_result',
#  'result_accident',
#  'accident_read',
#  'read_read',
#  'read_exciting',
#  'exciting_thing',
#  'thing_believe',
#  'believe_however',
#  'however_many',
#  'many_rabe',
#  'rabe_activity',
#  'activity_following',
#  'following_small',
#  'small_boat',
#  'boat_think',
#  'think_telakka',
#  'telakka_official',
#  'official_matter',
#  'matter_million',
#  'million_people',
#  'people_already',
#  'already_read',
#  'read_perhaps',
#  'perhaps_want',
#  'want_hide',
#  'hide_would',
#  'result_would',
#  'would_happened',
#  'happened_panic',
#  'panic_point',
#  'sinking_estonia',
#  'point_sinking_estonia',
#  'sinking_estonia_nothing',
#  'nothing_ashamed',
#  'ashamed_lie',
#  'lie_wall',
#  'wall_would',
#  'point_would',
#  'happened_tour',
#  'tour_trip',
#  'trip_away',
#  'away_one',
#  'one_far',
#  'far_made',
#  'made_guess',
#  'guess_various',
#  'various_interest',
#  'interest_group',
#  'group_evidence',
#  'evidence_would',
#  'would_investigated',
#  'investigated_already',
#  'already_germany',
#  'germany_official',
#  'official_position',
#  'etc_believe',
#  'believe_explanation',
#  'explanation_much',
#  'much_simpler',
#  'simpler_could',
#  'could_short',
#  'short_time',
#  'time_could',
#  'could_developed',
#  'developed_decaying',
#  'decaying_gas',
#  'gas_odor',
#  'odor_explosion',
#  'explosion_silenced',
#  'silenced_way',
#  'way_bomber',
#  'bomber_fence',
#  'fence_bomber',
#  'bomber_car',
#  'car_still',
#  'still_way',
#  'way_could',
#  'could_even',
#  'even_something',
#  'something_would',
#  'would_happen',
#  'happen_thing',
#  'thing_bomber',
#  'bomber_nothing',
#  'nothing_look',
#  'look_several',
#  'several_passenger',
#  'passenger_crew',
#  'crew_member',
#  'member_saved',
#  'saved_mentioned',
#  'mentioned_psychological',
#  'psychological_crisis',
#  'crisis_group',
#  'group_sinking',
#  'sinking_spot',
#  'spot_dark',
#  'dark_smell',
#  'smell_terrorism',
#  'terrorism_terrorist',
#  'terrorist_even',
#  'even_single',
#  'single_madman',
#  'madman_blew',
#  'blew_bomb',
#  'bomb_car',
#  'car_deck',
#  'deck_many',
#  'many_people',
#  'people_claimed',
#  'nuclear_weapon',
#  'claimed_nuclear_weapon',
#  'nuclear_weapon_plutonium',
#  'plutonium_agent',
#  'agent_large',
#  'large_drug',
#  'drug_load',
#  'load_sunk',
#  'look_saying',
#  'saying_nothing',
#  'look_big_deal',
#  'big_deal_whats',
#  'going_mean',
#  'mean_million',
#  'people_would',
#  'would_come',
#  'come_long',
#  'time_evidence',
#  'evidence_far',
#  'far_point',
#  'point_view',
#  'view_would',
#  'investigated_sure',
#  'sure_whats',
#  'going_big_deal',
#  'going_rabens',
#  'rabens_activity',
#  'activity_followed',
#  'followed_water',
#  'water_sure',
#  'going_whats',
#  'going_already',
#  'already_million',
#  'people_read',
#  'read_big_deal',
#  'big_deal_maybe',
#  'maybe_theyre',
#  'theyre_wanting',
#  'wanting_keep',
#  'keep_matter',
#  'matter_holding',
#  'estonia_file',
#  'file_report',
#  'report_downloaded',
#  'downloaded_pdf',
#  'pdf_finnish',
#  'finnish_safety',
#  'safety_investigation',
#  'investigation_authority',
#  'authority_website',
#  'website_attachment',
#  'attachment_missing',
#  'missing_www',
#  'www_unfortunately',
#  'unfortunately_also',
#  'also_obtained',
#  'obtained_location',
#  'location_ask',
#  'charge_commission',
#  'commission_remainder',
#  'remainder_uno',
#  'uno_laur',
#  'laur_finnish',
#  'finnish_member',
#  'member_commission',
#  'commission_kari',
#  'kari_lehtola',
#  'lehtola_director',
#  'director_accident',
#  'accident_investigation',
#  'investigation_centre',
#  'centre_whose',
#  'whose_madness',
#  'madness_cannot',
#  'cannot_say',
#  'say_anything',
#  'anything_estonian',
#  'estonian_initially',
#  'initially_andi',
#  'andi_meister',
#  'meister_second',
#  'telling_youm',
#  'telling_telling',
#  'telling_youm_telling_telling',
#  'youm_telling',
#  'telling_telling_youm_telling',
#  'youm_telling_youm_telling',
#  'youm_telling_itm',
#  'itm_telling',
#  'telling_itre',
#  'itre_gonna',
#  'gonna_telling_telling',
#  'telling_telling_telling_telling',
#  'telling_telling_youre',
#  'youre_gonna',
#  'gonna_itre',
#  'gonna_something',
#  'something_gonna',
#  'gonna_gonna',
#  'something_thats',
#  'thats_gonna',
#  'gonna_going',
#  'happen_something',
#  'something_something',
#  'happen_going',
#  'going_get',
#  'get_going',
#  'going_going',
#  'going_something',
#  'something_else',
#  'else_going',
#  'something_going',
#  'something_thing',
#  'thing_saying',
#  'saying_telling_telling',
#  'telling_telling_telling',
#  'evidence_found',
#  'found_sense',
#  'sense_estonia',
#  'estonia_leaf',
#  'leaf_sea',
#  'sea_pressure',
#  'pressure_left',
#  'left_behind',
#  'behind_ramp',
#  'ramp_broke',
#  'broke_bow',
#  'gate_behind',
#  'behind_smell',
#  'smell_brittle',
#  'brittle_stuff',
#  'stuff_also',
#  'worth_noting',
#  'also_worth_noting',
#  'worth_noting_experience',
#  'experience_narrator',
#  'narrator_brittle',
#  'brittle_smell',
#  'smell_ship',
#  'ship_corsts',
#  'corsts_still',
#  'still_long',
#  'long_main',
#  'main_engine',
#  'engine_stopped',
#  'stopped_really',
#  'really_strange',
#  'strange_bomb',
#  'bomb_ive',
#  'ive_said',
#  'said_hand',
#  'hand_knowledge',
#  'knowledge_youth',
#  'youth_year',
#  'year_came',
#  'came_smell',
#  'smell_smelled',
#  'smelled_corstene',
#  'corstene_painting',
#  'painting_blast',
#  'blast_vest',
#  'vest_manual',
#  'manual_lock',
#  'lock_left',
#  'behind_would',
#  'would_blown',
#  'blown_keulaport',
#  'keulaport_closed',
#  'closed_left',
#  'behind_hydraulics',
#  'hydraulics_locking',
#  'locking_hook',
#  'good_tip',
#  'tip_interested',
#  'interested_people',
#  'telling_something',
#  'something_telling',
#  'else_telling',
#  'something_telling_telling',
#  'reference_evidence',
#  'evidence_thing',
#  'thing_could',
#  'could_different',
#  'different_report',
#  'report_youre',
#  'youre_going',
#  'going_youre',
#  'going_long',
#  'time_basic',
#  'basic_concept',
#  'concept_investigation',
#  'investigation_court',
#  'court_based',
#  'based_event',
#  'event_reliably',
#  'reliably_explained',
#  'explained_lot',
#  'lot_report',
#  'report_contrast',
#  'contrast_theory',
#  'theory_thrown',
#  'thrown_way',
#  'way_youve',
#  'youve_read',
#  'read_report',
#  'report_already',
#  'already_mentioned',
#  'mentioned_strange',
#  'bomb_breaking',
#  'breaking_front',
#  'front_door',
#  'door_ramp',
#  'ramp_front',
#  'front_komporomist',
#  'komporomist_report',
#  'report_dont',
#  'dont_comment',
#  'comment_staff',
#  'staff_say',
#  'say_comment',
#  'comment_nice',
#  'nice_laugh',
#  'laugh_first',
#  'first_look',
#  'look_guilty',
#  'guilty_youre',
#  'youre_looking',
#  'looking_something',
#  'believe_organization',
#  'organization_behind',
#  'behind_thats',
#  'thats_taken',
#  'taken_reference',
#  'evidence_could',
#  'dont_sink',
#  'sink_truck',
#  'truck_stamp',
#  'stamp_participant',
#  'participant_secretor',
#  'secretor_information',
#  'information_lot',
#  'lot_done',
#  'done_long',
#  'time_indiscretion',
#  'indiscretion_youre',
#  'looking_guilty',
#  'youre_today',
#  'today_theyve',
#  'theyve_sunk',
#  'sunk_inconceivable',
#  'inconceivable_reason',
#  'reason_hey',
#  'hey_boy',
#  'boy_yes',
#  'yes_evidence',
#  'evidence_report',
#  'report_tiij',
#  'wonder_many',
#  'many_explosive',
#  'explosive_use',
#  'use_sulfur',
#  'sulfur_make',
#  'make_bow',
#  'bow_port',
#  'port_fail',
#  'fail_truckloads',
#  'truckloads_black',
#  'black_powder',
#  'powder_driven',
#  'driven_car',
#  'deck_smell',
#  'rotten_egg',
#  'smell_rotten_egg',
#  'rotten_egg_theory',
#  'theory_suggests',
#  'suggests_bowgate',
#  'bowgate_blown',
#  'blown_black',
#  'yes_dirt',
#  'dirt_thrown',
#  'thrown_side',
#  'side_way',
#  'way_around',
#  'around_win',
#  'thing_ostststre',
#  'ostststre_ostrich',
#  'ostrich_thing',
#  'thing_ostrich',
#  'ostrich_therest',
#  'therest_ost',
#  'ost_thing',
#  'ostrich_ostrich',
#  'thing_ostrich_ostrich',
#  'ostrich_ostrich_thing',
#  'car_thief',
#  'thief_speed',
#  'speed_restriction',
#  'restriction_calculated',
#  'calculated_tolerance',
#  'tolerance_tightened',
#  'tightened_need',
#  'need_car',
#  'car_model',
#  'model_speeding',
#  'speeding_driver',
#  'driver_able',
#  'able_catch',
#  'catch_lot',
#  'lot_drunk',
#  'drunk_driver',
#  'driver_majority',
#  'majority_road',
#  'road_user',
#  'user_think',
#  'think_meaningful',
#  'meaningful_anymore',
#  'anymore_honest',
#  'honest_control',
#  'control_preferably',
#  'preferably_visibly',
#  'visibly_another',
#  'another_thing',
#  'thing_automatic',
#  'automatic_control',
#  'control_cashing',
#  'cashing_automatic',
#  'automatic_speed',
#  'speed_control',
#  'control_contribute',
#  'contribute_road',
#  'road_safety',
#  'safety_extent',
#  'extent_acceptable',
#  'acceptable_noticed',
#  'noticed_police',
#  'police_even',
#  'even_look',
#  'look_reasonable',
#  'reasonable_speed',
#  'speed_see',
#  'see_situation',
#  'situation_allowing',
#  'allowing_without',
#  'without_risk',
#  'risk_remember',
#  'remember_counterfeit',
#  'counterfeit_dollar',
#  'dollar_thing',
#  'thing_went',
#  'went_year',
#  'year_ago',
#  'ago_villain',
#  'villain_ran',
#  'ran_radar',
#  'radar_car',
#  'car_load',
#  'load_fake',
#  'fake_police',
#  'police_enough',
#  'enough_fine',
#  'fine_large',
#  'large_number',
#  'number_road',
#  'user_personally',
#  'teach_child',
#  'child_walk',
#  'walk_traffic',
#  'traffic_light',
#  'light_anymore',
#  'anymore_automonitoring',
#  'automonitoring_increased',
#  'urban_area',
#  'increased_urban_area',
#  'urban_area_road',
#  'road_especially',
#  'especially_necessary',
#  'necessary_useful',
#  'useful_would',
#  'would_traffic',
#  'light_driving',
#  'driving_red',
#  'red_become',
#  'become_way',
#  'way_country',
#  'speeding_ticket',
#  'risk_speeding_ticket',
#  'speeding_ticket_minimized',
#  'minimized_course',
#  'course_automatic',
#  'control_addition',
#  'addition_dangerous',
#  'dangerous_unnecessary',
#  'unnecessary_constant',
#  'constant_speed',
#  'control_safe',
#  'safe_well',
#  'well_run',
#  'run_legal',
#  'legal_every',
#  'every_pas',
#  'pas_requires',
#  'requires_speeding',
#  'speeding_succeed',
#  'succeed_safely',
#  'safely_unnecessary',
#  'unnecessary_many',
#  'many_marmattatas',
#  'marmattatas_fact',
#  'fact_range',
#  'range_run',
#  'run_illegal',
#  'afford_drive',
#  'drive_speeding',
#  'speeding_would',
#  'would_lead',
#  'lead_fine',
#  'fine_kmh',
#  'kmh_speed',
#  'speed_limit',
#  'limit_nobody',
#  'nobody_drive',
#  'drive_kmh',
#  'kmh_time',
#  'time_difference',
#  'difference_distance',
#  'distance_minute',
#  'minute_exactly',
#  'exactly_time',
#  'time_kmh',
#  'kmh_kmh',
#  'kmh_really',
#  'really_understand',
#  'understand_current',
#  'current_speed',
#  'control_tax',
#  'tax_burden',
#  'burden_others',
#  'others_reduced',
#  'reduced_accordingly',
#  'accordingly_even',
#  'even_small',
#  'small_speeding',
#  'speeding_fuel',
#  'fuel_saved',
#  'saved_cost',
#  'cost_safer',
#  'safer_everyone',
#  'everyone_studied',
#  'zero_tolerance',
#  'studied_zero_tolerance',
#  'zero_tolerance_afford',
#  'afford_pay',
#  'pay_fine',
#  'though_dont',
#  'radar_detector',
#  'dont_radar_detector',
#  'radar_detector_even',
#  'even_scanner',
#  'scanner_otherwise',
#  'otherwise_know',
#  'know_way',
#  'way_cop',
#  'cop_cost',
#  'cost_nice',
#  'nice_feeling',
#  'feeling_get',
#  'get_little',
#  'little_bit',
#  'bit_dim',
#  'dim_camera',
#  'camera_tear',
#  'tear_slowly',
#  'slowly_case',
#  'case_cross',
#  'cross_get',
#  'get_least',
#  'least_kmh',
#  'kmh_high',
#  'high_speed',
#  'see_red',
#  'red_lower',
#  'lower_lens',
#  'lens_know',
#  'know_camera',
#  'camera_place',
#  'place_change',
#  'change_place',
#  'place_least',
#  'least_expense',
#  'expense_surveillance',
#  'surveillance_dont',
#  'dont_get',
#  'get_many',
#  'many_speeding_ticket',
#  'speeding_ticket_cant',
#  'cant_easily',
#  'easily_let',
#  'let_dont',
#  'dont_drive',
#  'drive_much',
#  'much_away',
#  'away_know',
#  'camera_could',
#  'could_add',
#  'add_camera',
#  'camera_every',
#  'every_case',
#  'real_apig',
#  'apig_expert',
#  'expert_funny',
#  'funny_thing',
#  'else_wheel',
#  'wheel_look',
#  'look_meter',
#  'meter_youre',
#  'youre_ride',
#  'ride_force',
#  'force_look',
#  'meter_scream',
#  'scream_start',
#  'start_going',
#  'going_limit',
#  'limit_mean',
#  'comment_fuck',
#  'fuck_youll',
#  'youll_get',
#  'get_kicked',
#  'kicked_walk',
#  'pay_driver',
#  'driver_made',
#  'made_commitment',
#  'commitment_traffic',
#  'traffic_offence',
#  'offence_signing',
#  'signing_licence',
#  'licence_application',
#  'application_got',
#  'got_automatic',
#  'automatic_fine',
#  'police_officer',
#  'fine_police_officer',
#  'police_officer_every',
#  'every_villain',
#  'villain_long',
#  'long_demand',
#  'demand_harm',
#  'harm_would',
#  'would_automatic',
#  'control_money',
#  'money_probably',
#  'probably_bad',
#  'bad_guy',
#  'guy_would',
#  'would_caught',
#  'caught_faster',
#  'faster_speed',
#  'control_much',
#  'much_know',
#  'know_automatic',
#  'control_improve',
#  'improve_road',
#  'safety_enough',
#  'scarce_resource',
#  'enough_scarce_resource',
#  'scarce_resource_company',
#  'company_handicrafted',
#  'handicrafted_extreme',
#  'extreme_end',
#  'end_day',
#  'day_automatic',
#  'fine_also',
#  'also_offered',
#  'offered_agreed',
#  'agreed_rule',
#  ...]

# %%
len(data_words_nostops_bigrams)
# Out:
# 273304

# %%
len(data_words_nostops_trigrams)
# Out:
# 273304

# %%
data_words_nostops_bigrams

# %%
nlp=spacy.load('en_core_web_sm',disable=['parser','ner'])

def lemmatize(texts,allowed_postags=['NOUN','ADJ','VERB','ADV']):
    texts_out=[]
    for sent in texts:
        doc=nlp(" ".join(sent))
        texts_out.append([token.lemma_ for token in doc if token.pos_ in allowed_postags])
        
    return texts_out

# %%
data_lemmatized=lemmatize(data_words_nostops_bigrams,allowed_postags=['NOUN','ADJ','VERB','ADV'] )

# %%
data_lemmatized

# %%
id2word=corpora.Dictionary(data_lemmatized)
texts=data_lemmatized  # list of list of tokens
corpus=[id2word.doc2bow(text) for text in texts]
print(corpus[:1])   #first document

# %%
id2word[0]

# %%
print([[(id2word[id],freq) for (id,freq) in cp]for cp in corpus[:2]])

# %%
# building LDA Model
lda_model=gensim.models.ldamodel.LdaModel(corpus=corpus,id2word=id2word,num_topics=3,random_state=100,update_every=0,
                                         chunksize=500,passes=20,alpha='auto',per_word_topics=True)

# %%
print(lda_model.print_topics())

# %%
doc_lda=lda_model[corpus]
print(list(doc_lda)[0])

# %%
#LDA Model Perfromance check
print("Perplexity: ",lda_model.log_perplexity(corpus))

#compute coherence score
coherence_model_lda=CoherenceModel(model=lda_model,texts=data_lemmatized,dictionary=id2word,coherence='c_v')

coherence_lda=coherence_model_lda.get_coherence()
print('Coherence Score: ',coherence_lda)

# %%
warnings.filterwarnings('ignore',category=FutureWarning)

pyLDAvis.enable_notebook()
vis=pyLDAvis.gensim.prepare(lda_model,corpus,id2word)
vis
