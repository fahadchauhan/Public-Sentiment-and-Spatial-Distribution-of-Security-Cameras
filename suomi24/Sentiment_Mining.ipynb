# %%
text = "i am f-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-b-c! man"
text = re.sub(r'\b\w*(-\w*)+\b', '', text)
text
# Out:
# 'i am ! man'

# %%
import pandas as pd
import torch
import re

from transformers import AutoTokenizer

# %%
# Check if GPU is available
'cuda' if torch.cuda.is_available() else 'cpu'
# Out:
# 'cuda'

# %%
# Load your data
file_path = 'C:/Users/fahad/OneDrive - Oulun yliopisto/Documents/suomi24/Data/suomi24.csv'
df = pd.read_csv(file_path)

# %%
# Load your data
file_path = 'suomi24_bertweet_processed.csv'
df = pd.read_csv(file_path)
df
# Out:
#             msg_type          datetime                                 title  \
# 0       thread_start  10/21/2008 15:10                                  2008
# 1            comment  10/21/2008 16:34                                  2008
# 2            comment    3/19/2016 9:40  - I don't know. - What's the payoff?
# 3            comment   3/25/2016 23:48  - I don't know. - What's the payoff?
# 4            comment   4/11/2016 23:06  - I don't know. - What's the payoff?
# ...              ...               ...                                   ...
# 217996       comment   3/16/2013 11:54                            Localities
# 217997       comment   1/16/2015 15:03                Vehicles and transport
# 217998       comment   3/18/2013 13:55                            Localities
# 217999       comment    3/30/2006 8:55                            Localities
# 218000       comment   1/23/2015 23:59                Vehicles and transport
#
#         thread_id  comment_id          topic_name_top   topic_name_leaf  \
# 0         6382354           0                  Groups           40 plus
# 1         6382354    33460404                  Groups           40 plus
# 2        14185813    83782764                 Hobbies       Electronics
# 3        14185813    83896363                 Hobbies       Electronics
# 4        14185813    84156873                 Hobbies       Electronics
# ...           ...         ...                     ...               ...
# 217996   11340784    60550054              Localities            Nickel
# 217997   13305552    77069109  Vehicles and transport  Public transport
# 217998   11340784    60588127              Localities            Nickel
# 217999    2778360    14276358              Localities         Rovaniemi
# 218000   13305552    77526327  Vehicles and transport  Public transport
#
#                                               thread_text  \
# 0       but despised and questioned yes. 2008 Well, we...
# 1       Orwell was a seer. In '84 the world didn't exa...
# 2       which did not protect the car owner from the r...
# 3       the cashier will have a "card reported as miss...
# 4       but do those only Mastercard Kredit cards with...
# ...                                                   ...
# 217996  thank you. Who could make it happen? Camera St...
# 217997  This rave junta now put the lives of possibly ...
# 217998  It would be nice to see what's going on there ...
# 217999  did not prevent our table from stealing. Its a...
# 218000  For Reiman Reindeerella all over 60 km per hou...
#
#                        title_processed topic_name_top_processed  \
# 0                                  NaN                   groups
# 1                                  NaN                   groups
# 2       i do not know whats the payoff                  hobbies
# 3       i do not know whats the payoff                  hobbies
# 4       i do not know whats the payoff                  hobbies
# ...                                ...                      ...
# 217996                      localities               localities
# 217997          vehicles and transport   vehicles and transport
# 217998                      localities               localities
# 217999                      localities               localities
# 218000          vehicles and transport   vehicles and transport
#
#        topic_name_leaf_processed  \
# 0                           plus
# 1                           plus
# 2                    electronics
# 3                    electronics
# 4                    electronics
# ...                          ...
# 217996                    nickel
# 217997          public transport
# 217998                    nickel
# 217999                 rovaniemi
# 218000          public transport
#
#                                     thread_text_processed  unique_word_ratio  \
# 0       but despised and questioned yes well we though...           0.768293
# 1       orwell was a seer in the world did not exactly...           0.928571
# 2       which did not protect the car owner from the r...           0.537879
# 3       the cashier will have a card reported as missi...           0.554054
# 4       but do those only mastercard kredit cards with...           0.562500
# ...                                                   ...                ...
# 217996  thank you who could make it happen camera stel...           1.000000
# 217997  this rave junta now put the lives of possibly ...           1.000000
# 217998  it would be nice to see what is going on there...           1.000000
# 217999  did not prevent our table from stealing its a ...           1.000000
# 218000  for reiman reindeerella all over km per hour a...           1.000000
#
#         word_count
# 0               82
# 1               14
# 2              132
# 3              148
# 4               96
# ...            ...
# 217996          14
# 217997          15
# 217998          16
# 217999          17
# 218000          17
#
# [218001 rows x 14 columns]

# %%
# df = df.drop(['word_count', 'unique_word_ratio', 'bertweet_processed', 'processed_text'], axis=1)

# %%
df

# %%
# Dictionary for contractions
contraction_dict = {
    "it's": "it is", "aren't": "are not", "can't": "cannot", "couldn't": "could not",
    "didn't": "did not", "doesn't": "does not", "don't": "do not", "hadn't": "had not",
    "hasn't": "has not", "haven't": "have not", "he'd": "he would", "he'll": "he will",
    "he's": "he is", "I'd": "I would", "I'll": "I will", "I'm": "I am", "I've": "I have",
    "isn't": "is not", "it's": "it is", "let's": "let us", "might've": "might have",
    "must've": "must have", "mustn't": "must not", "shan't": "shall not", "she'd": "she would",
    "she'll": "she will", "she's": "she is", "should've": "should have", "shouldn't": "should not",
    "that's": "that is", "there's": "there is", "they'd": "they would", "they'll": "they will",
    "they're": "they are", "they've": "they have", "we'd": "we would", "we're": "we are",
    "we've": "we have", "weren't": "were not", "what'll": "what will", "what're": "what are",
    "what's": "what is", "what've": "what have", "where's": "where is", "who'd": "who would",
    "who'll": "who will", "who's": "who is", "who've": "who have", "won't": "will not",
    "wouldn't": "would not", "you'd": "you would", "you'll": "you will", "you're": "you are",
    "you've": "you have"
}

def preprocess_text(text):
    # Regex to match:
    # 1. Any possible email address format
    # 2. URLs starting with http/https and ending with .com or .fi (with optional spaces)
    # 3. Any string that includes a slash (assumed to be a path or URL)
    # 4. Domain-like strings that end with .com or .fi, including spaces before the extensions
    patterns = [
        r'\b[A-Za-z0-9._%+-]+@[A-Za-z0-9.-]+\b',  # Email addresses, more inclusive to capture 'username@hostname'
        r'https?://[^ ]*\.(com|fi)\b',             # Full URLs
        r'\b[^ ]+/[^ ]+\b',                        # Paths with slashes
        r'\b[^ ]*\.\s*(com|fi)\b'                  # Domains with optional spaces
    ]
    combined_pattern = r'|'.join(patterns)
    text = re.sub(combined_pattern, '', text)
    words = text.split()
    text = " ".join([contraction_dict.get(word, word) for word in words]) # replace contractions
    text = re.sub(r'\b\w*(-\w*)+\b', '', text)
    text = re.sub(r'[^a-zA-Z\s]', '', text) # remove non-letter characters
    text = re.sub(r'&[^;\s]*', '', text)
    text = re.sub(r'\s+', ' ', text).strip()
    text = text.lower()  # Convert to lower case
    return text

df['title_processed'] = df['title'].apply(preprocess_text)
df['topic_name_top_processed'] = df['topic_name_top'].apply(preprocess_text)
df['topic_name_leaf_processed'] = df['topic_name_leaf'].apply(preprocess_text)
df['thread_text_processed'] = df['thread_text'].apply(preprocess_text)

df['combined_processed'] = df[['title_processed', 'topic_name_top_processed', 'topic_name_leaf_processed', 'thread_text_processed']].apply(lambda x: ' '.join(x.dropna().astype(str)), axis=1)

# df.to_csv('suomi24_bertweet_processed.csv', index=False)

# %%
# Function to calculate the ratio of unique words to total words
def unique_word_ratio(text):
    words = text.split()
    unique_words = set(words)
    if len(words) == 0:  # Avoid division by zero
        return 0
    return len(unique_words) / len(words)

# Apply the function to the 'processed_text' column
df['unique_word_ratio'] = df['thread_text_processed'].apply(unique_word_ratio)

# Add a column for word count
df['word_count'] = df['thread_text_processed'].apply(lambda text: len(text.split()))

# Filter rows where 'unique_word_ratio' is less than or equal to 0.4 and word count is less than 7
df = df[(df['unique_word_ratio'] > 0.4) & (df['word_count'] >= 7)]
# Filter rows where 'unique_word_ratio' is less than or equal to 0.4
# df = df[df['unique_word_ratio'] >= 0.4]

# Define a new order of columns where 'bertweet_processed' is at the end
# column_order = [col for col in df.columns if col not in ['bertweet_processed', 'unique_word_ratio', 'word_count']]
# column_order += ['unique_word_ratio', 'word_count', 'bertweet_processed']
# df = df[column_order]

# Save the DataFrame with the new information
df.to_csv('suomi24_bertweet_processed.csv', index=False)

# %%
df
# Out:
#             msg_type          datetime                                 title  \
# 0       thread_start  10/21/2008 15:10                                  2008
# 1            comment  10/21/2008 16:34                                  2008
# 2            comment    3/19/2016 9:40  - I don't know. - What's the payoff?
# 3            comment   3/25/2016 23:48  - I don't know. - What's the payoff?
# 4            comment   4/11/2016 23:06  - I don't know. - What's the payoff?
# ...              ...               ...                                   ...
# 217996       comment   3/16/2013 11:54                            Localities
# 217997       comment   1/16/2015 15:03                Vehicles and transport
# 217998       comment   3/18/2013 13:55                            Localities
# 217999       comment    3/30/2006 8:55                            Localities
# 218000       comment   1/23/2015 23:59                Vehicles and transport
#
#         thread_id  comment_id          topic_name_top   topic_name_leaf  \
# 0         6382354           0                  Groups           40 plus
# 1         6382354    33460404                  Groups           40 plus
# 2        14185813    83782764                 Hobbies       Electronics
# 3        14185813    83896363                 Hobbies       Electronics
# 4        14185813    84156873                 Hobbies       Electronics
# ...           ...         ...                     ...               ...
# 217996   11340784    60550054              Localities            Nickel
# 217997   13305552    77069109  Vehicles and transport  Public transport
# 217998   11340784    60588127              Localities            Nickel
# 217999    2778360    14276358              Localities         Rovaniemi
# 218000   13305552    77526327  Vehicles and transport  Public transport
#
#                                               thread_text  \
# 0       but despised and questioned yes. 2008 Well, we...
# 1       Orwell was a seer. In '84 the world didn't exa...
# 2       which did not protect the car owner from the r...
# 3       the cashier will have a "card reported as miss...
# 4       but do those only Mastercard Kredit cards with...
# ...                                                   ...
# 217996  thank you. Who could make it happen? Camera St...
# 217997  This rave junta now put the lives of possibly ...
# 217998  It would be nice to see what's going on there ...
# 217999  did not prevent our table from stealing. Its a...
# 218000  For Reiman Reindeerella all over 60 km per hou...
#
#                        title_processed topic_name_top_processed  \
# 0                                                        groups
# 1                                                        groups
# 2       i do not know whats the payoff                  hobbies
# 3       i do not know whats the payoff                  hobbies
# 4       i do not know whats the payoff                  hobbies
# ...                                ...                      ...
# 217996                      localities               localities
# 217997          vehicles and transport   vehicles and transport
# 217998                      localities               localities
# 217999                      localities               localities
# 218000          vehicles and transport   vehicles and transport
#
#        topic_name_leaf_processed  \
# 0                           plus
# 1                           plus
# 2                    electronics
# 3                    electronics
# 4                    electronics
# ...                          ...
# 217996                    nickel
# 217997          public transport
# 217998                    nickel
# 217999                 rovaniemi
# 218000          public transport
#
#                                     thread_text_processed  unique_word_ratio  \
# 0       but despised and questioned yes well we though...           0.768293
# 1       orwell was a seer in the world did not exactly...           0.928571
# 2       which did not protect the car owner from the r...           0.537879
# 3       the cashier will have a card reported as missi...           0.554054
# 4       but do those only mastercard kredit cards with...           0.562500
# ...                                                   ...                ...
# 217996  thank you who could make it happen camera stel...           1.000000
# 217997  this rave junta now put the lives of possibly ...           1.000000
# 217998  it would be nice to see what is going on there...           1.000000
# 217999  did not prevent our table from stealing its a ...           1.000000
# 218000  for reiman reindeerella all over km per hour a...           1.000000
#
#         word_count                                 combined_processed
# 0               82   groups plus but despised and questioned yes w...
# 1               14   groups plus orwell was a seer in the world di...
# 2              132  i do not know whats the payoff hobbies electro...
# 3              148  i do not know whats the payoff hobbies electro...
# 4               96  i do not know whats the payoff hobbies electro...
# ...            ...                                                ...
# 217996          14  localities localities nickel thank you who cou...
# 217997          15  vehicles and transport vehicles and transport ...
# 217998          16  localities localities nickel it would be nice ...
# 217999          17  localities localities rovaniemi did not preven...
# 218000          17  vehicles and transport vehicles and transport ...
#
# [218001 rows x 15 columns]

# %%
df.to_csv('suomi24_bertweet_processed.csv', index=False)

# %%
# Basic text preprocessing function
stop_words = set(stopwords.words('english'))
stop_words.add('s')
stop_words.add('ve')
stop_words.add('re')
stop_words.add('m')
lemmatizer = WordNetLemmatizer()

def preprocess_text(text):
    text = text.lower()  # Convert to lower case
    text = re.sub(r'\d+', '', text)  # Remove numbers
    text = re.sub(r'\s+', ' ', text)  # Replace multiple spaces with single space
    text = re.sub(r'[^\w\s]', '', text)  # Remove punctuation
    text = re.sub(r'\b\w{1,2}\b', '', text) # Remove single and double character words
    text = text.lower()  # Convert to lower case
    tokens = text.split()
    tokens = [lemmatizer.lemmatize(token) for token in tokens if token not in stop_words]
    return ' '.join(tokens)

# Apply preprocessing to the 'thread_text' column
df['processed_text'] = df['thread_text'].astype(str).apply(preprocess_text)

# %%
# Load the tokenizer for BERTweet
tokenizer = AutoTokenizer.from_pretrained('vinai/bertweet-large')

# Tokenize the 'processed_text' column and check their lengths
token_lengths = df['combined_processed'].apply(lambda text: len(tokenizer.encode(text, add_special_tokens=True)))

# Display some basic statistics about token lengths
print("Token Lengths Statistics:")
print(token_lengths.describe())

# Find if any text exceeds BERTweet's max length (typically 128 for BERTweet Base)
max_length = 512
exceeds = (token_lengths > max_length).sum()
print(f"\nNumber of texts exceeding {max_length} tokens: {exceeds}")

# Display specific rows that exceed the maximum length
if exceeds > 0:
    print("\nTexts exceeding the maximum token length:")
    print(df.loc[token_lengths > max_length, 'combined_processed'])
# Out:
# Token Lengths Statistics:
# count    218001.000000
# mean         74.516947
# std          39.961957
# min          14.000000
# 25%          42.000000
# 50%          63.000000
# 75%         100.000000
# max         371.000000
# Name: combined_processed, dtype: float64
#
# Number of texts exceeding 512 tokens: 0

# %%
# Load the tokenizer for BERTweet
tokenizer = AutoTokenizer.from_pretrained('vinai/bertweet-large')

# Tokenize the 'processed_text' column and check their lengths
token_lengths = df['thread_text_processed'].apply(lambda text: len(tokenizer.encode(text, add_special_tokens=True)))

# Display some basic statistics about token lengths
print("Token Lengths Statistics:")
print(token_lengths.describe())

# Find if any text exceeds BERTweet's max length (typically 128 for BERTweet Base)
max_length = 512
exceeds = (token_lengths > max_length).sum()
print(f"\nNumber of texts exceeding {max_length} tokens: {exceeds}")

# Display specific rows that exceed the maximum length
if exceeds > 0:
    print("\nTexts exceeding the maximum token length:")
    print(df.loc[token_lengths > max_length, 'thread_text_processed'])
# Out:
# Token Lengths Statistics:
# count    218001.000000
# mean         63.979615
# std          40.061274
# min           9.000000
# 25%          31.000000
# 50%          53.000000
# 75%          90.000000
# max         359.000000
# Name: thread_text_processed, dtype: float64
#
# Number of texts exceeding 512 tokens: 0
